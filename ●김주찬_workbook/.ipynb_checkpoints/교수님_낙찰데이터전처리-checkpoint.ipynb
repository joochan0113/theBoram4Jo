# %% [markdown]
# ### MySQL 연동

# %%
import numpy as np
import pandas as pd
import pymysql
from sqlalchemy import create_engine

# %% [markdown]
# #### cp949 형식의 csv 파일을 읽어 utf-8형식의 csv파일로 저장

# %%
df = pd.read_csv('bidResCategorizedCP949_armyClassified.csv',encoding='cp949', low_memory=False)
df.head(2)
# Out:
#    bidID  참가수     공고번호  공고차수   판단번호 항목번호                 입찰명 업무구분 발주기관코드  \
# 0      1   81  SFL0160     1  47669  ***       임시명찰 등 2품목 구매   물품    SFL
# 1      2    1  LFC0043     1  45002    1  장거리 이동 신병 도시락 제조납품   물품    LFC
#
#       발주기관  ...          낙찰자(영문상호) 낙찰자(대표자)   낙찰자(연락처)    낙찰자(연락처).1  \
# 0  제3283부대  ...  Jung woo military      이정구  222730487  02-2273-0487
# 1    육군훈련소  ...                LNF      이용환  437318109  043-731-8109
#
#                                              낙찰자(주소)      낙찰률       낙찰금액   \
# 0  경기도 고양시 덕양구 통일로140, 1층 에이143호, 2층 에이261호,지하1층 ...  88.0062  23,689,950
# 1                              충청북도 옥천군 옥천읍 삼청리877-1  96.8333       5,810
#
#   카테고리  pick_keywords 군 분류
# 0   2종             명찰   육군
# 1   1종            도시락  미분류
#
# [2 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74732 entries, 0 to 74731
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   bidID          74732 non-null  int64
#  1   참가수            74732 non-null  int64
#  2   공고번호           74732 non-null  object
#  3   공고차수           74732 non-null  int64
#  4   판단번호           74732 non-null  object
#  5   항목번호           74732 non-null  object
#  6   입찰명            74732 non-null  object
#  7   업무구분           74732 non-null  object
#  8   발주기관코드         74732 non-null  object
#  9   발주기관           74732 non-null  object
#  10  개찰일시           74732 non-null  object
#  11  낙찰자(업체코드)      74732 non-null  object
#  12  낙찰자(상호)        74732 non-null  object
#  13  낙찰자(영문상호)      53075 non-null  object
#  14  낙찰자(대표자)       74732 non-null  object
#  15  낙찰자(연락처)       74732 non-null  object
#  16  낙찰자(연락처).1     74732 non-null  object
# ...

# %% [markdown]
# - 결측치 확인

# %%
df.isna().sum()
# Out:
# bidID                0
# 참가수                  0
# 공고번호                 0
# 공고차수                 0
# 판단번호                 0
# 항목번호                 0
# 입찰명                  0
# 업무구분                 0
# 발주기관코드               0
# 발주기관                 0
# 개찰일시                 0
# 낙찰업체코드               0
# 낙찰업체상호               0
# 영문상호             21657
# 대표자                  0
# 연락처                  0
# 연락처2                 0
# 업체주소                 0
# 낙찰률                133
# 낙찰금액                 2
# 카테고리                 0
# pick_keywords    20014
# 군 분류                 0
# dtype: int64

# %% [markdown]
# #### 데이터 전처리

# %%
cols = df.columns
print(cols)
# Out:
# Index(['bidID', '참가수', '공고번호', '공고차수', '판단번호', '항목번호', '입찰명', '업무구분', '발주기관코드',
#        '발주기관', '개찰일시', '낙찰자(업체코드)', '낙찰자(상호)', '낙찰자(영문상호)', '낙찰자(대표자)',
#        '낙찰자(연락처)', '낙찰자(연락처).1', '낙찰자(주소)', '낙찰률', ' 낙찰금액 ', '카테고리',
#        'pick_keywords', '군 분류'],
#       dtype='object')

# %% [markdown]
# - 컬럼명 변경

# %%
columns=['bidID', '참가수', '공고번호', '공고차수', '판단번호', '항목번호', '입찰명', '업무구분',
       '발주기관코드', '발주기관', '개찰일시', '낙찰업체코드', '낙찰업체상호', '영문상호',
       '대표자', '연락처', '연락처2', '업체주소', '낙찰률', '낙찰금액','카테고리', 'pick_keywords', '군 분류']

# %%
df.columns = columns

# %% [markdown]
# - 각 행 구분을 위한 ID 컬럼의 값을 1부터 시작하도록

# %%
# df['ID'] =df['ID'] + 1

# %%
df['bidID'].describe()
# Out:
# count    74732.000000
# mean     37366.500000
# std      21573.414496
# min          1.000000
# 25%      18683.750000
# 50%      37366.500000
# 75%      56049.250000
# max      74732.000000
# Name: bidID, dtype: float64

# %% [markdown]
# - 데이터 포맷 변경

# %%
df['개찰일시'] = pd.to_datetime(df['개찰일시'])

# %%
col = '낙찰금액'
# 숫자/마이너스만 허용
s = df[col].str.strip().str.replace(r'[^\d\-]', '', regex=True)

# 숫자(float64 또는 int64)로 변환
df['낙찰금액'] = pd.to_numeric(s, errors='coerce')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74732 entries, 0 to 74731
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   bidID          74732 non-null  int64
#  1   참가수            74732 non-null  int64
#  2   공고번호           74732 non-null  object
#  3   공고차수           74732 non-null  int64
#  4   판단번호           74732 non-null  object
#  5   항목번호           74732 non-null  object
#  6   입찰명            74732 non-null  object
#  7   업무구분           74732 non-null  object
#  8   발주기관코드         74732 non-null  object
#  9   발주기관           74732 non-null  object
#  10  개찰일시           74732 non-null  datetime64[ns]
#  11  낙찰업체코드         74732 non-null  object
#  12  낙찰업체상호         74732 non-null  object
#  13  영문상호           53075 non-null  object
#  14  대표자            74732 non-null  object
#  15  연락처            74732 non-null  object
#  16  연락처2           74732 non-null  object
# ...

# %%
df.head()
# Out:
#    bidID  참가수     공고번호  공고차수   판단번호 항목번호                           입찰명 업무구분  \
# 0      1   81  SFL0160     1  47669  ***                 임시명찰 등 2품목 구매   물품
# 1      2    1  LFC0043     1  45002    1            장거리 이동 신병 도시락 제조납품   물품
# 2      3   22  LGT0034     1  48136  ***     0부대 중대시설 분전반 제조설치(16-312)   물품
# 3      4   22  UMM0839     1  48049  ***  13-본-국대-01 00학교 가구 및 비품 제조설치   물품
# 4      5    9  LGT0035     1  48138  ***   00부대 중대시설 조명기구 제조납품(16-314)   물품
#
#   발주기관코드     발주기관  ...               영문상호  대표자        연락처          연락처2  \
# 0    SFL  제3283부대  ...  Jung woo military  이정구  222730487  02-2273-0487
# 1    LFC    육군훈련소  ...                LNF  이용환  437318109  043-731-8109
# 2    LGT  제2307부대  ...        seorak tech  김화성  334610399  033-461-0399
# 3    UMM  국군재정관리단  ...   DS NAIKI CO.,LTD  김준홍   27342125   02-734-2125
# 4    LGT  제2307부대  ...     HANSEO Co.,LTD  이명옥  337462110  033-746-2110
#
# ...

# %%
df2.to_csv('BID.csv',encoding='cp949', index=False)

# %%
df2 = pd.read_csv('BID.csv', encoding='cp949')
df2.head(2)
# Out:
#    bidID  참가수     공고번호  공고차수   판단번호 항목번호                 입찰명 업무구분 발주기관코드  \
# 0      1   81  SFL0160     1  47669  ***       임시명찰 등 2품목 구매   물품    SFL
# 1      2    1  LFC0043     1  45002    1  장거리 이동 신병 도시락 제조납품   물품    LFC
#
#       발주기관  ...               영문상호  대표자        연락처          연락처2  \
# 0  제3283부대  ...  Jung woo military  이정구  222730487  02-2273-0487
# 1    육군훈련소  ...                LNF  이용환  437318109  043-731-8109
#
#                                                 업체주소      낙찰률        낙찰금액  \
# 0  경기도 고양시 덕양구 통일로140, 1층 에이143호, 2층 에이261호,지하1층 ...  88.0062  23689950.0
# 1                              충청북도 옥천군 옥천읍 삼청리877-1  96.8333      5810.0
#
#   카테고리  pick_keywords  군 분류
# 0   2종             명찰    육군
# 1   1종            도시락   미분류
#
# [2 rows x 23 columns]

# %%
df[df.낙찰금액.isna()][['bidID', '입찰명','개찰일시', '낙찰률', '낙찰금액']]
# Out:
#        bidID                   입찰명                개찰일시  낙찰률  낙찰금액
# 53311  53312  검독수리-B B-II 1~4번함 건조 2022-10-24 14:00:00  NaN   NaN
# 60032  60033   AI기반 전술차량용 지능형 RCWS 2023-12-12 10:00:00  0.0   NaN

# %%
df = df[~df['bidID'].isin([53312, 60033])]

# %%
df[df.bidID == 53312]['입찰명']
# Out:
# 53311    검독수리-B B-II 1~4번함 건조
# Name: 입찰명, dtype: object

# %%
df3 = df2.drop(columns = ['영문상호', '연락처', '연락처2', '업무구분'])
df3.columns
# Out:
# Index(['bidID', '참가수', '공고번호', '공고차수', '판단번호', '항목번호', '입찰명', '발주기관코드', '발주기관',
#        '개찰일시', '낙찰업체코드', '낙찰업체상호', '대표자', '업체주소', '낙찰률', '낙찰금액', '카테고리',
#        'pick_keywords', '군 분류'],
#       dtype='object')

# %%
df3.to_csv('BID_fianl.csv',encoding='cp949', index=False)

# %%
# 조건별로 갱신
df3.loc[df["발주기관"].str.contains("육군", na=False), "군 분류"] = "육군"
df3.loc[df["발주기관"].str.contains("해군", na=False), "군 분류"] = "해군"
df3.loc[df["발주기관"].str.contains("공군", na=False), "군 분류"] = "공군"

# %%
df3[df3['군 분류'] == '미분류'][['군 분류']]
# Out:
# Empty DataFrame
# Columns: [군 분류]
# Index: []

# %%
df3.head(15)
# Out:
#     bidID  참가수     공고번호  공고차수   판단번호 항목번호                           입찰명  \
# 0       1   81  SFL0160     1  47669  ***                 임시명찰 등 2품목 구매
# 1       2    1  LFC0043     1  45002    1            장거리 이동 신병 도시락 제조납품
# 2       3   22  LGT0034     1  48136  ***     0부대 중대시설 분전반 제조설치(16-312)
# 3       4   22  UMM0839     1  48049  ***  13-본-국대-01 00학교 가구 및 비품 제조설치
# 4       5    9  LGT0035     1  48138  ***   00부대 중대시설 조명기구 제조납품(16-314)
# 5       6    4  HCL0100     1  48057  ***                    2017년 난방연료
# 6       7    8  LNF0041     1  49073  ***    00부대 체육시설 비품구매(고소작업대 등 9종)
# 7       8    2  HCM0002     1     19    1            17년 액화석유가스(LPG) 구매
# 8       9    3  HCL0097     2  46235  ***                      군수처 취사연료
# 9      10    2  SFC0229     1  47835  ***            우갈비 등 15품목 (덕산스포텔)
# 10     11    2  SFC0228     1  47822  ***           감자전분 등 211품목(덕산스포텔)
# 11     12    2  SFC0227     1  47817  ***                        다목적작업차
# ...

# %%
df3[df3['군 분류'] == '육군'][['군 분류', '발주기관']]
# Out:
#       군 분류      발주기관
# 0       육군   제3283부대
# 1       육군     육군훈련소
# 2       육군   제2307부대
# 4       육군   제2307부대
# 6       육군    제1보병사단
# ...    ...       ...
# 74718   육군     육군훈련소
# 74719   육군     육군훈련소
# 74726   육군  제 2167부대
# 74730   육군   제3707부대
# 74731   육군   제7001부대
#
# [25300 rows x 2 columns]

# %% [markdown]
# ---
