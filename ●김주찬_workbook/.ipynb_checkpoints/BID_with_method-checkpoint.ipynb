# %%
import pandas as pd
import numpy as np
import csv
import os

# %%
dfOrigin = pd.read_csv('BID_final.csv', encoding='cp949')
dfMethod = pd.read_csv('workbookdata/공고결과_낙찰방법/Total_공고결과_낙찰방법.csv', encoding='cp949')

# %%
dfOrigin.head(1)
# Out:
#    bidID  참가수     공고번호  공고차수   판단번호 항목번호            입찰명 발주기관코드     발주기관  \
# 0      1   81  SFL0160     1  47669  ***  임시명찰 등 2품목 구매    SFL  제3283부대
#
#                   개찰일시 낙찰업체코드       낙찰업체상호  대표자  \
# 0  2016-12-30 12:30:00  H84F8  주식회사 전우밀리터리  이정구
#
#                                                 업체주소      낙찰률        낙찰금액  \
# 0  경기도 고양시 덕양구 통일로140, 1층 에이143호, 2층 에이261호,지하1층 ...  88.0062  23689950.0
#
#   카테고리 pick_keywords 군 분류
# 0   2종            명찰   육군

# %%
dfMethod.head(1)
# Out:
#    공고구분     공고번호  공고차수  판단번호 항목번호             입찰명  요구년도 발주기관코드  \
# 0  정상공고  PIP0001     1  9100  ***  중요시설경계시스템 1차사업  2016    EGH
#
#                    발주기관         계약방법 입찰방법 낙찰자결정방법                 개찰일시  \
# 0  지휘정찰계약팀 (구:19.09.16)  협상에의한계약(서류)  총액제   최저가격제  2016-12-30 12:00:00
#
#          개찰일자 입찰결과
# 0  2016-12-30   낙찰

# %%
# 병합 수행 (left join)
dfMethod_unique = dfMethod.drop_duplicates(subset=['공고번호', '판단번호'], keep='first')
merged_df = pd.merge(dfOrigin, dfMethod_unique[['공고번호', '판단번호', '항목번호', '계약방법']], 
                     on=['공고번호', '항목번호', '판단번호'], how='left')

# NaN 값을 '확인안됨'으로 채움
merged_df['계약방법'] = merged_df['계약방법'].fillna('확인안됨')

# 결과 확인 (merged_df가 업데이트된 dfOrigin 역할을 함)
merged_df
# Out:
#        bidID  참가수     공고번호  공고차수   판단번호 항목번호                           입찰명  \
# 0          1   81  SFL0160     1  47669  ***                 임시명찰 등 2품목 구매
# 1          2    1  LFC0043     1  45002    1            장거리 이동 신병 도시락 제조납품
# 2          3   22  LGT0034     1  48136  ***     0부대 중대시설 분전반 제조설치(16-312)
# 3          4   22  UMM0839     1  48049  ***  13-본-국대-01 00학교 가구 및 비품 제조설치
# 4          5    9  LGT0035     1  48138  ***   00부대 중대시설 조명기구 제조납품(16-314)
# ...      ...  ...      ...   ...    ...  ...                           ...
# 74725  74728  164  SCQ0154     2  54928  ***             수영장자동청소기 등 16종 구매
# 74726  74729   33  HCL0005     1     51  ***               24년 간부식당 식자재 구매
# 74727  74730    3  SCR0090     2  61362  ***       24년 배추김치(포기절단) 등 10종 구매
# 74728  74731   31  MDS0030     1  66867  ***          교육단 증개축 GHP 실외기 설치납품
# 74729  74732    2  SCN0193     1  65508  ***         24-체단장 액화석유가스(LPG) 구매
#
# ...

# %%
merged_df.계약방법.value_counts()
# Out:
# 계약방법
# 확인안됨           46603
# 제한경쟁           19994
# 일반경쟁            7256
# 2단계경쟁(동시)        486
# 지명경쟁             236
# 협상에의한계약(전자)      122
# 협상에의한계약(서류)       21
# 2단계경쟁(분리)          7
# 수의계약               5
# Name: count, dtype: int64

# %%
len(dfOrigin)
# Out:
# 74730

# %%
len(merged_df)
# Out:
# 90468

# %%
merged_df.to_csv('BID_Method_Raw.csv', index=False, encoding='cp949')

# %%
df = pd.read_csv('BID_Method_Raw.csv', encoding='cp949')
result_df = df[~df['계약방법'].str.contains('확인안됨', na=False, regex=True)]

# %%
result_df.계약방법.value_counts()
# Out:
# 계약방법
# 제한경쟁           33050
# 일반경쟁            8240
# 2단계경쟁(동시)        619
# 지명경쟁             232
# 수의계약             147
# 협상에의한계약(전자)      109
# 협상에의한계약(서류)       14
# 2단계경쟁(분리)          7
# Name: count, dtype: int64

# %%
result_df.to_csv('BID_Method_unknownRemoved.csv', index=False, encoding='cp949')
