# %% [markdown]
# ### MySQL 연동

# %%
import numpy as np
import pandas as pd
import pymysql
from sqlalchemy import create_engine

# %% [markdown]
# #### cp949 형식의 csv 파일을 읽어 utf-8형식의 csv파일로 저장

# %%
df = pd.read_csv('물품_카테고리_분류완료_인간승리1.csv',encoding='cp949', low_memory=False)
df.head(2)
# Out:
#    Unnamed: 0  참가수     공고번호  공고차수   판단번호 항목번호                 입찰명 업무구분 발주기관코드  \
# 0           0   81  SFL0160     1  47669  ***       임시명찰 등 2품목 구매   물품    SFL
# 1           1    1  LFC0043     1  45002    1  장거리 이동 신병 도시락 제조납품   물품    LFC
#
#       발주기관  ...           낙찰자(상호)          낙찰자(영문상호) 낙찰자(대표자)   낙찰자(연락처)  \
# 0  제3283부대  ...       주식회사 전우밀리터리  Jung woo military      이정구  222730487
# 1    육군훈련소  ...  주식회사 엘엔에프 농업회사법인                LNF      이용환  437318109
#
#           ss    낙찰자(연락처).1                                            낙찰자(주소)  \
# 0  222730487  02-2273-0487  경기도 고양시 덕양구 통일로140, 1층 에이143호, 2층 에이261호,지하1층 ...
# 1  437318109  043-731-8109                              충청북도 옥천군 옥천읍 삼청리877-1
#
#        낙찰률      낙찰금액   카테고리
# 0  88.0062  23689950     2종
# 1  96.8333      5810     1종
#
# [2 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74732 entries, 0 to 74731
# Data columns (total 22 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  74732 non-null  int64
#  1   참가수         74732 non-null  int64
#  2   공고번호        74732 non-null  object
#  3   공고차수        74732 non-null  int64
#  4   판단번호        74732 non-null  object
#  5   항목번호        74732 non-null  object
#  6   입찰명         74732 non-null  object
#  7   업무구분        74732 non-null  object
#  8   발주기관코드      74732 non-null  object
#  9   발주기관        74732 non-null  object
#  10  개찰일시        74732 non-null  object
#  11  낙찰자(업체코드)   74732 non-null  object
#  12  낙찰자(상호)     74732 non-null  object
#  13  낙찰자(영문상호)   53075 non-null  object
#  14  낙찰자(대표자)    74732 non-null  object
#  15  낙찰자(연락처)    74732 non-null  object
#  16  ss          74732 non-null  object
#  17  낙찰자(연락처).1  74732 non-null  object
#  18  낙찰자(주소)     74732 non-null  object
# ...

# %% [markdown]
# - 결측치 확인

# %%
df.isna().sum()
# Out:
# Unnamed: 0        0
# 참가수               0
# 공고번호              0
# 공고차수              0
# 판단번호              0
# 항목번호              0
# 입찰명               0
# 업무구분              0
# 발주기관코드            0
# 발주기관              0
# 개찰일시              0
# 낙찰자(업체코드)         0
# 낙찰자(상호)           0
# 낙찰자(영문상호)     21657
# 낙찰자(대표자)          0
# 낙찰자(연락처)          0
# ss                0
# 낙찰자(연락처).1        0
# 낙찰자(주소)           0
# 낙찰률             133
#  낙찰금액             0
# 카테고리              0
# dtype: int64

# %% [markdown]
# #### 데이터 전처리

# %%
cols = df.columns
print(cols)
# Out:
# Index(['Unnamed: 0', '참가수', '공고번호', '공고차수', '판단번호', '항목번호', '입찰명', '업무구분',
#        '발주기관코드', '발주기관', '개찰일시', '낙찰자(업체코드)', '낙찰자(상호)', '낙찰자(영문상호)',
#        '낙찰자(대표자)', '낙찰자(연락처)', 'ss', '낙찰자(연락처).1', '낙찰자(주소)', '낙찰률', ' 낙찰금액 ',
#        '카테고리'],
#       dtype='object')

# %% [markdown]
# - 컬럼명 변경

# %%
columns=['ID', '참가수', '공고번호', '공고차수', '판단번호', '항목번호', '입찰명', '업무구분',
       '발주기관코드', '발주기관', '개찰일시', '낙찰업체코드', '상호', '영문상호',
       '대표자', '연락처', 'ss', '연락처2', '주소', '낙찰률', '낙찰금액','카테고리']

# %%
df.columns = columns

# %% [markdown]
# - 각 행 구분을 위한 ID 컬럼의 값을 1부터 시작하도록

# %%
df['ID'] =df['ID'] + 1

# %%
df['ID'].describe()
# Out:
# count    74732.000000
# mean     37366.500000
# std      21573.414496
# min          1.000000
# 25%      18683.750000
# 50%      37366.500000
# 75%      56049.250000
# max      74732.000000
# Name: ID, dtype: float64

# %% [markdown]
# - 데이터 포맷 변경

# %%
df['개찰일시'] = pd.to_datetime(df['개찰일시'])

# %%
col = '낙찰금액'
# 숫자/마이너스만 허용
s = df[col].str.strip().str.replace(r'[^\d\-]', '', regex=True)

# 숫자(float64 또는 int64)로 변환
df['낙찰금액'] = pd.to_numeric(s, errors='coerce')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74732 entries, 0 to 74731
# Data columns (total 22 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      74732 non-null  int64
#  1   참가수     74732 non-null  int64
#  2   공고번호    74732 non-null  object
#  3   공고차수    74732 non-null  int64
#  4   판단번호    74732 non-null  object
#  5   항목번호    74732 non-null  object
#  6   입찰명     74732 non-null  object
#  7   업무구분    74732 non-null  object
#  8   발주기관코드  74732 non-null  object
#  9   발주기관    74732 non-null  object
#  10  개찰일시    74732 non-null  datetime64[ns]
#  11  낙찰업체코드  74732 non-null  object
#  12  상호      74732 non-null  object
#  13  영문상호    53075 non-null  object
#  14  대표자     74732 non-null  object
#  15  연락처     74732 non-null  object
#  16  ss      74732 non-null  object
#  17  연락처2    74732 non-null  object
#  18  주소      74732 non-null  object
#  19  낙찰률     74599 non-null  float64
#  20  낙찰금액    74730 non-null  float64
# ...

# %%
df.head()
# Out:
#    ID  참가수     공고번호  공고차수   판단번호 항목번호                           입찰명 업무구분  \
# 0   1   81  SFL0160     1  47669  ***                 임시명찰 등 2품목 구매   물품
# 1   2    1  LFC0043     1  45002    1            장거리 이동 신병 도시락 제조납품   물품
# 2   3   22  LGT0034     1  48136  ***     0부대 중대시설 분전반 제조설치(16-312)   물품
# 3   4   22  UMM0839     1  48049  ***  13-본-국대-01 00학교 가구 및 비품 제조설치   물품
# 4   5    9  LGT0035     1  48138  ***   00부대 중대시설 조명기구 제조납품(16-314)   물품
#
#   발주기관코드     발주기관  ...                상호               영문상호  대표자        연락처  \
# 0    SFL  제3283부대  ...       주식회사 전우밀리터리  Jung woo military  이정구  222730487
# 1    LFC    육군훈련소  ...  주식회사 엘엔에프 농업회사법인                LNF  이용환  437318109
# 2    LGT  제2307부대  ...              설악테크        seorak tech  김화성  334610399
# 3    UMM  국군재정관리단  ...       주식회사 디에스나이키   DS NAIKI CO.,LTD  김준홍   27342125
# 4    LGT  제2307부대  ...           주식회사 한서     HANSEO Co.,LTD  이명옥  337462110
#
# ...

# %%
df.to_csv('BID.csv',encoding='cp949', index=False)

# %%
bid = pd.read_csv('BID.csv', encoding='cp949')
bid.head(2)
# Out:
#    ID  참가수     공고번호  공고차수   판단번호 항목번호                 입찰명 업무구분 발주기관코드  \
# 0   1   81  SFL0160     1  47669  ***       임시명찰 등 2품목 구매   물품    SFL
# 1   2    1  LFC0043     1  45002    1  장거리 이동 신병 도시락 제조납품   물품    LFC
#
#       발주기관  ...                상호               영문상호  대표자        연락처  \
# 0  제3283부대  ...       주식회사 전우밀리터리  Jung woo military  이정구  222730487
# 1    육군훈련소  ...  주식회사 엘엔에프 농업회사법인                LNF  이용환  437318109
#
#           ss          연락처2                                                 주소  \
# 0  222730487  02-2273-0487  경기도 고양시 덕양구 통일로140, 1층 에이143호, 2층 에이261호,지하1층 ...
# 1  437318109  043-731-8109                              충청북도 옥천군 옥천읍 삼청리877-1
#
#        낙찰률        낙찰금액  카테고리
# 0  88.0062  23689950.0    2종
# 1  96.8333      5810.0    1종
#
# [2 rows x 22 columns]

# %%
bid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74732 entries, 0 to 74731
# Data columns (total 22 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      74732 non-null  int64
#  1   참가수     74732 non-null  int64
#  2   공고번호    74732 non-null  object
#  3   공고차수    74732 non-null  int64
#  4   판단번호    74732 non-null  object
#  5   항목번호    74732 non-null  object
#  6   입찰명     74732 non-null  object
#  7   업무구분    74732 non-null  object
#  8   발주기관코드  74732 non-null  object
#  9   발주기관    74732 non-null  object
#  10  개찰일시    74732 non-null  object
#  11  낙찰업체코드  74732 non-null  object
#  12  상호      74732 non-null  object
#  13  영문상호    53075 non-null  object
#  14  대표자     74732 non-null  object
#  15  연락처     74732 non-null  object
#  16  ss      74732 non-null  object
#  17  연락처2    74732 non-null  object
#  18  주소      74732 non-null  object
#  19  낙찰률     74599 non-null  float64
#  20  낙찰금액    74730 non-null  float64
# ...

# %% [markdown]
# ---

# %% [markdown]
# #### MySQL 접속

# %% [markdown]
# - pymysql로 DB 접속

# %%
conn = pymysql.connect(user='root',
                        password='acorn1234',
                        host='127.0.0.1',
                        database='testDb',
                        port=3306,
                        charset='utf8mb4',
                        local_infile=True,   # ★LOCAL INFILE 허용
                        autocommit=False)
cur = conn.cursor()

# %%
# BID 테이블 생성 SQL
sql = r'''
    CREATE TABLE 낙찰정보 
        (id INT PRIMARY KEY,
        참가수 INT, 공고번호 VARCHAR(50), 
        공고차수 INT, 판단번호 VARCHAR(50),
        항목번호 VARCHAR(50), 입찰명 VARCHAR(255), 
        업무구분 VARCHAR(100), 
        발주기관코드 VARCHAR(50),  발주기관 VARCHAR(255), 개찰일시 DATETIME,
        낙찰업체코드 VARCHAR(50), 상호 VARCHAR(255),
        영문상호 VARCHAR(255), 대표자 VARCHAR(100),
        연락처 VARCHAR(100), ss VARCHAR(100), 연락처2 VARCHAR(100),
        주소 VARCHAR(255), 낙찰률 DECIMAL(5,3),
        낙찰금액 BIGINT, 카테고리 VARCHAR(100));
'''
cur.execute(sql)
cur.fetchall()
# Out:
# ()

# %%
cur.execute('show tables;')
cur.fetchall()
# Out:
# (('낙찰정보',),)

# %%
# cur.execute('drop table bid;')
# cur.fetchall()
# Out:
# ()

# %%
cur.execute('describe 낙찰정보;')
cur.fetchall()
# Out:
# (('id', 'int', 'NO', 'PRI', None, ''),
#  ('참가수', 'int', 'YES', '', None, ''),
#  ('공고번호', 'varchar(50)', 'YES', '', None, ''),
#  ('공고차수', 'int', 'YES', '', None, ''),
#  ('판단번호', 'varchar(50)', 'YES', '', None, ''),
#  ('항목번호', 'varchar(50)', 'YES', '', None, ''),
#  ('입찰명', 'varchar(255)', 'YES', '', None, ''),
#  ('업무구분', 'varchar(100)', 'YES', '', None, ''),
#  ('발주기관코드', 'varchar(50)', 'YES', '', None, ''),
#  ('발주기관', 'varchar(255)', 'YES', '', None, ''),
#  ('개찰일시', 'datetime', 'YES', '', None, ''),
#  ('낙찰업체코드', 'varchar(50)', 'YES', '', None, ''),
#  ('상호', 'varchar(255)', 'YES', '', None, ''),
#  ('영문상호', 'varchar(255)', 'YES', '', None, ''),
#  ('대표자', 'varchar(100)', 'YES', '', None, ''),
#  ('연락처', 'varchar(100)', 'YES', '', None, ''),
#  ('ss', 'varchar(100)', 'YES', '', None, ''),
#  ('연락처2', 'varchar(100)', 'YES', '', None, ''),
#  ('주소', 'varchar(255)', 'YES', '', None, ''),
#  ('낙찰률', 'decimal(5,3)', 'YES', '', None, ''),
# ...

# %%
conn.close()

# %% [markdown]
# - 대량 파일 임포트

# %%
bid.to_csv('bid_utf8.csv', encoding='utf-8', index=False)

# %%
csv_path = r'bid_utf8.csv'
# 테이블 생성 후 파일로 삽입
sql = r'''
    LOAD DATA LOCAL INFILE %s
    INTO TABLE `낙찰정보`
    CHARACTER SET utf8mb4
    FIELDS TERMINATED BY ','
    ENCLOSED BY '"'
    LINES TERMINATED BY '\n'
    IGNORE 1 ROWS
    (`ID`,`참가수`,`공고번호`,`공고차수`,`판단번호`,`항목번호`,`입찰명`,`업무구분`,
     `발주기관코드`,`발주기관`,`개찰일시`,`낙찰업체코드`,`상호`,`영문상호`,
     `대표자`,`연락처`,`ss`,`연락처2`,`주소`,`낙찰률`,`낙찰금액`,`카테고리`);
'''
conn = pymysql.connect(user='root',
                        password='acorn1234',
                        host='127.0.0.1',
                        database='testDb',
                        port=3306,
                        charset='utf8mb4',
                        local_infile=True,   # ★LOCAL INFILE 허용
                        autocommit=False)
try:
    with conn.cursor() as cur:
        # 연결 직후 문자셋을 확실히 고정
        # cur.execute("SET NAMES utf8mb4")
        cur.execute(sql, (csv_path,))
    conn.commit()
    print("LOAD DATA LOCAL INFILE 완료")
except Exception as e:
    print(f'삽입 오류: {e}')
    conn.rollback()
    raise
finally:
    conn.close()
# Out:
# LOAD DATA LOCAL INFILE 완료

# %% [markdown]
# - sqlalchemy로 DB접속

# %%
bid_utf = pd.read_csv('bid_utf8.csv', encoding='utf-8')

# %%
engine = create_engine(
    "mysql+pymysql://root:acorn1234@localhost:3306/testDb?charset=utf8mb4"
)
conn = engine.connect()

# %%
bid_utf.to_sql(
    name="입찰정보",
    con=engine,
    if_exists="replace",   # 'replace'=덮어쓰기, 'append'=추가
    index=False
)
conn.commit()

# %%
conn.close()

# %%
bid_utf.shape
# Out:
# (74732, 22)

# %% [markdown]
# ----
