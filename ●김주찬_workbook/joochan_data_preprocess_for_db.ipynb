# %%
import pandas as pd
import csv
import numpy as np

# %%
df = pd.read_csv('bidResCategorizedCP949.csv', encoding='cp949')
df.head(1)
# Out:
#    Unnamed: 0  bidID  참가수     공고번호  공고차수   판단번호 항목번호            입찰명 업무구분  \
# 0           0      1   81  SFL0160     1  47669  ***  임시명찰 등 2품목 구매   물품
#
#   발주기관코드  ...      낙찰자(상호)          낙찰자(영문상호) 낙찰자(대표자)   낙찰자(연락처)  \
# 0    SFL  ...  주식회사 전우밀리터리  Jung woo military      이정구  222730487
#
#      낙찰자(연락처).1                                            낙찰자(주소)      낙찰률  \
# 0  02-2273-0487  경기도 고양시 덕양구 통일로140, 1층 에이143호, 2층 에이261호,지하1층 ...  88.0062
#
#         낙찰금액  카테고리  pick_keywords
# 0  23,689,950   2종             명찰
#
# [1 rows x 23 columns]

# %%
df = df.loc[:, ~df.columns.str.contains(r'^Unnamed')]
df
# Out:
#        bidID  참가수     공고번호  공고차수   판단번호 항목번호                           입찰명  \
# 0          1   81  SFL0160     1  47669  ***                 임시명찰 등 2품목 구매
# 1          2    1  LFC0043     1  45002    1            장거리 이동 신병 도시락 제조납품
# 2          3   22  LGT0034     1  48136  ***     0부대 중대시설 분전반 제조설치(16-312)
# 3          4   22  UMM0839     1  48049  ***  13-본-국대-01 00학교 가구 및 비품 제조설치
# 4          5    9  LGT0035     1  48138  ***   00부대 중대시설 조명기구 제조납품(16-314)
# ...      ...  ...      ...   ...    ...  ...                           ...
# 74727  74728  164  SCQ0154     2  54928  ***             수영장자동청소기 등 16종 구매
# 74728  74729   33  HCL0005     1     51  ***               24년 간부식당 식자재 구매
# 74729  74730    3  SCR0090     2  61362  ***       24년 배추김치(포기절단) 등 10종 구매
# 74730  74731   31  MDS0030     1  66867  ***          교육단 증개축 GHP 실외기 설치납품
# 74731  74732    2  SCN0193     1  65508  ***         24-체단장 액화석유가스(LPG) 구매
#
#       업무구분 발주기관코드       발주기관  ...           낙찰자(상호)  \
# ...

# %%
df.index = pd.RangeIndex(1,df.shape[0]+1, name='bidID')

# %%
df = df.reset_index()
df
# Out:
#        bidID  참가수     공고번호  공고차수   판단번호 항목번호                           입찰명  \
# 0          1   81  SFL0160     1  47669  ***                 임시명찰 등 2품목 구매
# 1          2    1  LFC0043     1  45002    1            장거리 이동 신병 도시락 제조납품
# 2          3   22  LGT0034     1  48136  ***     0부대 중대시설 분전반 제조설치(16-312)
# 3          4   22  UMM0839     1  48049  ***  13-본-국대-01 00학교 가구 및 비품 제조설치
# 4          5    9  LGT0035     1  48138  ***   00부대 중대시설 조명기구 제조납품(16-314)
# ...      ...  ...      ...   ...    ...  ...                           ...
# 74727  74728  164  SCQ0154     2  54928  ***             수영장자동청소기 등 16종 구매
# 74728  74729   33  HCL0005     1     51  ***               24년 간부식당 식자재 구매
# 74729  74730    3  SCR0090     2  61362  ***       24년 배추김치(포기절단) 등 10종 구매
# 74730  74731   31  MDS0030     1  66867  ***          교육단 증개축 GHP 실외기 설치납품
# 74731  74732    2  SCN0193     1  65508  ***         24-체단장 액화석유가스(LPG) 구매
#
#       업무구분 발주기관코드       발주기관  ...           낙찰자(상호)  \
# ...

# %%
df.to_csv('bidResCategorizedCP949.csv', index=False, encoding='cp949')

# %%
df = pd.read_csv('bidResCategorizedCP949.csv', encoding='cp949')
df
# Out:
#        bidID  참가수     공고번호  공고차수   판단번호 항목번호                           입찰명  \
# 0          1   81  SFL0160     1  47669  ***                 임시명찰 등 2품목 구매
# 1          2    1  LFC0043     1  45002    1            장거리 이동 신병 도시락 제조납품
# 2          3   22  LGT0034     1  48136  ***     0부대 중대시설 분전반 제조설치(16-312)
# 3          4   22  UMM0839     1  48049  ***  13-본-국대-01 00학교 가구 및 비품 제조설치
# 4          5    9  LGT0035     1  48138  ***   00부대 중대시설 조명기구 제조납품(16-314)
# ...      ...  ...      ...   ...    ...  ...                           ...
# 74727  74728  164  SCQ0154     2  54928  ***             수영장자동청소기 등 16종 구매
# 74728  74729   33  HCL0005     1     51  ***               24년 간부식당 식자재 구매
# 74729  74730    3  SCR0090     2  61362  ***       24년 배추김치(포기절단) 등 10종 구매
# 74730  74731   31  MDS0030     1  66867  ***          교육단 증개축 GHP 실외기 설치납품
# 74731  74732    2  SCN0193     1  65508  ***         24-체단장 액화석유가스(LPG) 구매
#
#       업무구분 발주기관코드       발주기관  ...           낙찰자(상호)  \
# ...
