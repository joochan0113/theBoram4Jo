# %% [markdown]
# # 2024.10.31 입찰참여정보

# %%
from bs4 import BeautifulSoup
import requests
import numpy as np
import pandas as pd
import json
from urllib.request import urlopen

# %%
base_url     = 'https://api.odcloud.kr/api/'
service_name = '15050921/v1/uddi:3b739b71-cda8-4eba-9730-ba897be8c248'
perPage      = '100'
returnType   = 'xml'
serviceKey   = '416a0c4c87da58598c1fde059d56608bca0746c6d66fffb18def03dee40491a6'

# 총 데이터 건 / 50,000 = X+1
for page_num in range(1, 5):
    url = f'{base_url}{service_name}?serviceKey={serviceKey}&page={page_num}&perPage={perPage}&returnType={returnType}'
    
    print(f"page{page_num}: {url}")
# Out:
# page1: https://api.odcloud.kr/api/15050921/v1/uddi:3b739b71-cda8-4eba-9730-ba897be8c248?serviceKey=416a0c4c87da58598c1fde059d56608bca0746c6d66fffb18def03dee40491a6&page=1&perPage=100&returnType=xml
# page2: https://api.odcloud.kr/api/15050921/v1/uddi:3b739b71-cda8-4eba-9730-ba897be8c248?serviceKey=416a0c4c87da58598c1fde059d56608bca0746c6d66fffb18def03dee40491a6&page=2&perPage=100&returnType=xml
# page3: https://api.odcloud.kr/api/15050921/v1/uddi:3b739b71-cda8-4eba-9730-ba897be8c248?serviceKey=416a0c4c87da58598c1fde059d56608bca0746c6d66fffb18def03dee40491a6&page=3&perPage=100&returnType=xml
# page4: https://api.odcloud.kr/api/15050921/v1/uddi:3b739b71-cda8-4eba-9730-ba897be8c248?serviceKey=416a0c4c87da58598c1fde059d56608bca0746c6d66fffb18def03dee40491a6&page=4&perPage=100&returnType=xml

# %%
#Total: 176021

page1 = 'https://api.odcloud.kr/api/15050921/v1/uddi:3b739b71-cda8-4eba-9730-ba897be8c248?serviceKey=416a0c4c87da58598c1fde059d56608bca0746c6d66fffb18def03dee40491a6&page=1&perPage=50000&returnType=json'
page2 = 'https://api.odcloud.kr/api/15050921/v1/uddi:3b739b71-cda8-4eba-9730-ba897be8c248?serviceKey=416a0c4c87da58598c1fde059d56608bca0746c6d66fffb18def03dee40491a6&page=2&perPage=50000&returnType=json'
page3 = 'https://api.odcloud.kr/api/15050921/v1/uddi:3b739b71-cda8-4eba-9730-ba897be8c248?serviceKey=416a0c4c87da58598c1fde059d56608bca0746c6d66fffb18def03dee40491a6&page=3&perPage=50000&returnType=json'
page4 = 'https://api.odcloud.kr/api/15050921/v1/uddi:3b739b71-cda8-4eba-9730-ba897be8c248?serviceKey=416a0c4c87da58598c1fde059d56608bca0746c6d66fffb18def03dee40491a6&page=4&perPage=50000&returnType=json'

# %%
xml = requests.get(page1).text
data = response.json()   
company_list1 = data['data']

for company in company_list:
    representative = company['대표자']
    company_name = company['업체명']

    print(f"업체명: {company_name}")
    print(f"대표자: {representative}\n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 xml = requests.get(page1).text
# ----> 2 data = response.json()
#       3 company_list1 = data['data']
#       5 for company in company_list:
#
# NameError: name 'response' is not defined

# %%
base_url = 'https://api.odcloud.kr/api/'
service_name = '15050921/v1/uddi:3b739b71-cda8-4eba-9730-ba897be8c248'
serviceKey = '416a0c4c87da58598c1fde059d56608bca0746c6d66fffb18def03dee40491a6'


company_list = []

for page_num in range(1, 5):
    # 각 페이지에 맞는 요청 파라미터를 설정합니다 (returnType='json').
    params = {
        'serviceKey': serviceKey,
        'page': page_num,
        'perPage': 50000, 
        'returnType': 'json'
    }
    
    try:
        response = requests.get(f'{base_url}{service_name}', params=params, verify=False)
        data = response.json()
        
        if 'data' in data and data['data']:
            company_list.extend(data['data'])

    except requests.exceptions.RequestException as e:
        print(f"{page_num} 페이지 요청 중 오류가 발생했습니다: {e}")
        break

print(f"\n✅ 데이터 수집 완료! 총 {len(company_list)}개의 업체 정보가 저장되었습니다.")

print("\n--- 전체 업체 정보 처리 ---")
for company in company_list:
    representative = company.get('대표자', '정보 없음')
    company_name = company.get('업체명', '정보 없음')
# Out:
# C:\Users\jooch\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.odcloud.kr'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\jooch\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.odcloud.kr'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\jooch\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.odcloud.kr'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\jooch\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.odcloud.kr'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# ✅ 데이터 수집 완료! 총 176021개의 업체 정보가 저장되었습니다.
#
# --- 전체 업체 정보 처리 ---
# 🏢 업체명: 다온
#    - 대표자: AHNHYOUNGJIN
#
# 🏢 업체명: 구례마켓
#    - 대표자: ANDO KUMIKO
#
# 🏢 업체명: 탠탠
#    - 대표자: ANHONGZHE
#
# 🏢 업체명: 삼화에스앤디(주)
#    - 대표자: BAE SOON JA
#
# 🏢 업체명: 스카이글로벌네트웍스(주)
#    - 대표자: BAEK MICHAEL NAM JUNG
#
# 🏢 업체명: 레디스주식회사
#    - 대표자: BAEKMICHAELNAMJUNG
#
# 🏢 업체명: 주식회사 비비앤코
#    - 대표자: BAIKBRIANSEUNGWON
#
# 🏢 업체명: 주식회사 한솔소방이앤지
#    - 대표자: BAYARSAIKHAN BADAMTSETSEG
#
# 🏢 업체명: 주식회사케이스틸
#    - 대표자: CAI SHITING
#
# 🏢 업체명: 씨엠엘아시아 주식회사
#    - 대표자: CAPORUSSO ALESSANDRO
#
# 🏢 업체명: 삼원페트라 주식회사
#    - 대표자: CHA WONMIN
#
# 🏢 업체명: 일곱풍년
#    - 대표자: CHANG DAN YEUL
#
# 🏢 업체명: 정일사
#    - 대표자: chang seungho
#
# 🏢 업체명: 정일사
#    - 대표자: chang seungho(장승호)
#
# 🏢 업체명: 와이엠에이치
#    - 대표자: CHEE JIN JIK
#
# 🏢 업체명: 주식회사 엔크로트레이딩
#    - 대표자: CHIENCHINWEN
#
# 🏢 업체명: 한다루
#    - 대표자: CHO ANJELLA
#
# 🏢 업체명: 주식회사 신한
#    - 대표자: CHO KYUNG SUN(조경선)
#
# 🏢 업체명: 알에스케이에듀테크 유한회사
#    - 대표자: CHO STEVEN H
#
# 🏢 업체명: 위즈덤
#    - 대표자: CHOI HOUN JIN
#
# 🏢 업체명: 주식회사 경훈테크
#    - 대표자: CHOI HUI BONG
#
# 🏢 업체명: 구주기술(주)
#    - 대표자: CHOI JAE RIM
#
# 🏢 업체명: (주)유파인메드
#    - 대표자: choijungtaek
#
# 🏢 업체명: 영스산업
#    - 대표자: CHON YONG HAE
#
# 🏢 업체명: 헹복한샵
#    - 대표자: CUI FENGSHU
#
# 🏢 업체명: 리아몰
#    - 대표자: CUIXUELING
#
# 🏢 업체명: 제이에이치컴퍼니
#    - 대표자: CUIYING
#
# 🏢 업체명: 새성글로벌 주식회사
#    - 대표자: DU GUANGCHENG
#
# 🏢 업체명: (주)메들린
#    - 대표자: GIMENEZ JEAH MAY
#
# 🏢 업체명: 메이글로벌
#    - 대표자: GIMENEZ JEAH MAY
#
# 🏢 업체명: 벽원건설 주식회사
#    - 대표자: GUILLERM EMMA ANAIS AIMEE
#
# 🏢 업체명: 한국에이브이엘(주)
#    - 대표자: HAN KYUNG MAN
#
# 🏢 업체명: 도현마켓
#    - 대표자: HAYASHI NATSUMI
#
# 🏢 업체명: 서원개발주식회사
#    - 대표자: Hong Jeong A
#
# 🏢 업체명: 미친마켓
#    - 대표자: HOU CHU HSIEN
#
# 🏢 업체명: (주)쿨앤조이코리아
#    - 대표자: Huchun wonja pyong in
#
# 🏢 업체명: 옴니벅스
#    - 대표자: Huh Christine
#
# 🏢 업체명: (주)제이콘종합건설
#    - 대표자: HWANG SEAN SOJIN
#
# 🏢 업체명: 주식회사 그랜드제이알전기
#    - 대표자: ISLAM MD RAFIQUL
#
# 🏢 업체명: 주식회사 태백사람들
#    - 대표자: JIANG DONGHAO
#
# 🏢 업체명: 주식회사 엠에스에스코리아
#    - 대표자: JIANG XIANGYU
#
# 🏢 업체명: 글로벌 이스트 코리아
#    - 대표자: JIN AISHUN
#
# 🏢 업체명: 옥션JB
#    - 대표자: JIN BO
#
# 🏢 업체명: 이현기업
#    - 대표자: JIN CHUNHUA
#
# 🏢 업체명: 트레저헤븐
#    - 대표자: JIN CHUNHUA
#
# 🏢 업체명: 두두몽
#    - 대표자: JIN SHIFENG
#
# 🏢 업체명: 주식회사 디엠티랩스
#    - 대표자: JIN YUN
#
# 🏢 업체명: 형제지하수
#    - 대표자: jinjishun
#
# 🏢 업체명: 주식회사 이앤씨보광
#    - 대표자: JINLIANHUA
#
# 🏢 업체명: 애니아이앤지(anyING)
#    - 대표자: JUNG JENNY YOUNGNIM
#
# 🏢 업체명: 제이에스와이케이
#    - 대표자: JUNG SERGIO YUN KI
#
# 🏢 업체명: 주식회사 엑셀항공산업
#    - 대표자: JUNG YUN WOOK
#
# 🏢 업체명: (주)인터피아
#    - 대표자: KANG MAL AE
#
# 🏢 업체명: 수현K마트
#    - 대표자: KANG SOOHYUN
#
# 🏢 업체명: 해피조달
#    - 대표자: KAWAGUCHI SUMIKO
#
# 🏢 업체명: 주식회사 쇼엑서스
#    - 대표자: Khie Bruce
#
# 🏢 업체명: 아바노아
#    - 대표자: KIM ANDREW ILLANG
#
# 🏢 업체명: 빛과나무
#    - 대표자: KIM BINNAR
#
# 🏢 업체명: 쉐퍼드멀린릭터&햄튼 외국법자문법률사무소
#    - 대표자: KIM BYOUNG SOO
#
# 🏢 업체명: 보성과학(주)
#    - 대표자: KIM GYE RIM
#
# 🏢 업체명: (주)코디아
#    - 대표자: KIM HAN NIM
#
# 🏢 업체명: 주식회사 코프코코퍼레이션
#    - 대표자: KIM HENRY MYUNGHWAN
#
# 🏢 업체명: 어프로티움 주식회사(APPROTIUM)
#    - 대표자: KIM JAMES JOO HOON
#
# 🏢 업체명: 주식회사 제이피씨
#    - 대표자: KIM JANG JOONG
#
# 🏢 업체명: 주식회사 라벡스
#    - 대표자: KIM KANGSAN DANNY
#
# 🏢 업체명: 필연꼬
#    - 대표자: KIM KWANG TAEG
#
# 🏢 업체명: 위두 (WE DO)
#    - 대표자: KIM MIN JEONG
#
# 🏢 업체명: 주식회사 오맥스워터젯엠아이케이
#    - 대표자: KIM WOODROW WOO K
#
# 🏢 업체명: 한국쉘석유(주)
#    - 대표자: LAMERS JEROEN PIETER
#
# 🏢 업체명: 안톤파코리아주식회사
#    - 대표자: LAMPERSTORFER INGRID
#
# 🏢 업체명: 하이앤-테크
#    - 대표자: LEE DAIMYUNG
#
# 🏢 업체명: 청솔기업
#    - 대표자: LEE EUN SIL
#
# 🏢 업체명: 이스톤팜
#    - 대표자: LEE HYUNG KYU
#
# 🏢 업체명: 주식회사 스토프코리아
#    - 대표자: Lee John Hokwon
#
# 🏢 업체명: 순수
#    - 대표자: LEESOOJUNG
#
# 🏢 업체명: 케이앤월드
#    - 대표자: LI CHUNHU
#
# 🏢 업체명: 광명설비
#    - 대표자: LI DEZHU
#
# 🏢 업체명: 주식회사 미래스톤
#    - 대표자: LI LONGRI
#
# 🏢 업체명: 액셔니샵
#    - 대표자: LI XIAN
#
# 🏢 업체명: 주식회사 현대이엔씨
#    - 대표자: LI ZHE
#
# 🏢 업체명: 천일 인터내셔널
#    - 대표자: LI ZHUSHUN
#
# 🏢 업체명: 연성
#    - 대표자: LIJINJI
#
# 🏢 업체명: 한국랜트로비젼(주)
#    - 대표자: LIM HUEY LING
#
# 🏢 업체명: 이가게뭐야
#    - 대표자: LIN CHANGSONG
#
# 🏢 업체명: 나린컴퍼니
#    - 대표자: LIN ZHE
#
# 🏢 업체명: 퓨아람(PUARAM)
#    - 대표자: LINYUNXIU
#
# 🏢 업체명: 델타번역
#    - 대표자: LIU CHUNG KUO
#
# 🏢 업체명: 케이 엔씨 트레이딩
#    - 대표자: LIU FEI
#
# 🏢 업체명: (주)케스피온
#    - 대표자: Lloyd Yeonsu Lee
#
# 🏢 업체명: 주식회사 아틀라스랩스
#    - 대표자: LYU ROBIN SUKJOON
#
# 🏢 업체명: 충남북유통
#    - 대표자: MA LINGYU
#
# 🏢 업체명: 천일상회
#    - 대표자: MANABAT JAHYEON
#
# 🏢 업체명: 주식회사 새봄산업
#    - 대표자: MIN JINHWAN
#
# 🏢 업체명: 미리안
#    - 대표자: MIN JINJI
#
# 🏢 업체명: 피엔에이 컴퍼니
#    - 대표자: MIN YONG GYU
#
# 🏢 업체명: 한켈 트래이딩 (Hancal Trade)
#    - 대표자: MOON BENNY
#
# 🏢 업체명: (주)지올코리아
#    - 대표자: NAKAZAWA TAKASHI
#
# 🏢 업체명: 준컴퍼니
#    - 대표자: NAN JUN
#
# 🏢 업체명: 보미마켓
#    - 대표자: NARITOMI ETSUKO
#
# 🏢 업체명: 제로솔루션(파주점)
#    - 대표자: NGUYEN THI CAM
#
# 🏢 업체명: 라라스타
#    - 대표자: NISHIMURA MIKI
#
# 🏢 업체명: 행운마켓
#    - 대표자: NITTO TOMOKO
#
# 🏢 업체명: 다한마켓
#    - 대표자: OHSHIMA AYANO
#
# 🏢 업체명: 유한회사 미래금속창호
#    - 대표자: PARK HONGMI TIA
#
# 🏢 업체명: 로건
#    - 대표자: Park Jungyun
#
# 🏢 업체명: 대호전기 주식회사
#    - 대표자: PARK KIOUNG
#
# 🏢 업체명: 주식회사  송호건축
#    - 대표자: PARK SUE YEON
#
# 🏢 업체명: 커빙턴 앤드 벌링 외국법자문법률사무소
#    - 대표자: PARK WILLIAM HA YONG
#
# 🏢 업체명: 브이플러스
#    - 대표자: PHAM THI NHAN
#
# 🏢 업체명: 주식회사 아이디에스코리아
#    - 대표자: Piantoni Stefano
#
# 🏢 업체명: 한중무역
#    - 대표자: PIAO CAIHUA
#
# 🏢 업체명: 씨에이치
#    - 대표자: PIAO CAIHUA
#
# 🏢 업체명: 정화몰
#    - 대표자: PIAO ZHENHUA
#
# 🏢 업체명: GRAND VISION(그랜드 비전)
#    - 대표자: REN HAO
#
# 🏢 업체명: 주식회사 파인텔레콤
#    - 대표자: ronykohen
#
# 🏢 업체명: 마산마켓
#    - 대표자: SASAKI MEGUMI
#
# 🏢 업체명: 주식회사 샵디
#    - 대표자: Shin Alfred James Soo
#
# 🏢 업체명: 제이엔엘 주식회사
#    - 대표자: SHIN JAMES JOON YOUNG
#
# 🏢 업체명: 코넥트월드 주식회사
#    - 대표자: SHIN SU KYUNG
#
# 🏢 업체명: 세린식품 주식회사
#    - 대표자: SONG HYUN SUK(송현석)
#
# 🏢 업체명: 이지몰
#    - 대표자: SONG MINGSHU
#
# 🏢 업체명: 레프몰
#    - 대표자: SONG MINGZI
#
# 🏢 업체명: 설악마켓
#    - 대표자: TAKAYAMA TOMOKO
#
# 🏢 업체명: 주식회사 바덱스인더스트리스
#    - 대표자: THOMAS MILLER
#
# 🏢 업체명: 포키
#    - 대표자: TOKIEDA HITOMI
#
# 🏢 업체명: 만에너지솔루션즈코리아 주식회사
#    - 대표자: TOMMY RENE RASMUSSEN
#
# 🏢 업체명: 카리나마켓
#    - 대표자: WADA MAYUMI
#
# 🏢 업체명: 에잇스터너
#    - 대표자: WANG JUNL ING
#
# 🏢 업체명: WMZ (더블유엠제트)
#    - 대표자: WANGMINCHIH
#
# 🏢 업체명: 루디아
#    - 대표자: Wen yingzhu
#
# 🏢 업체명: 은재마켓
#    - 대표자: WU JINGYU
#
# 🏢 업체명: 씨엔케이엠 주식회사
#    - 대표자: XIA JINZHU
#
# 🏢 업체명: 금성전기조명
#    - 대표자: YAN JINHUA
#
# 🏢 업체명: 비디케이 인터내셔널
#    - 대표자: YAN RI
#
# 🏢 업체명: 한송
#    - 대표자: YI ANDREW KYONGIN
#
# 🏢 업체명: 주식회사 빛나리
#    - 대표자: YUAN CHUNYU
#
# 🏢 업체명: 제이앤에이치건설 주식회사
#    - 대표자: YUAN MINGJI
#
# 🏢 업체명: 비케이한국성형
#    - 대표자: zhang nan
#
# 🏢 업체명: 여우클로스
#    - 대표자: ZHENG XIANGDAN
#
# 🏢 업체명: 쓰리제이몰
#    - 대표자: ZHENGHEFU
#
# 🏢 업체명: 세계진주
#    - 대표자: ZHU CHENGGANG
#
# 🏢 업체명: 마루이엔씨
#    - 대표자: 가경복
#
# 🏢 업체명: 부일종합건설주식회사
#    - 대표자: 가귀현
#
# 🏢 업체명: 부영종합건설 주식회사
#    - 대표자: 가귀현
#
# 🏢 업체명: 주식회사지음종합건설
#    - 대표자: 가길현
#
# 🏢 업체명: (주)서령기공
#    - 대표자: 가당현
#
# 🏢 업체명: (합)동양전기공사
#    - 대표자: 가도현
#
# 🏢 업체명: 소망유통
#    - 대표자: 가무웅
#
# 🏢 업체명: 유한회사 문진건설
#    - 대표자: 가문진
#
# 🏢 업체명: 주식회사 미래기전
#    - 대표자: 가미진
#
# 🏢 업체명: 엠제이(주)
#    - 대표자: 가민진
#
# 🏢 업체명: (주)가화건설
#    - 대표자: 가백현
#
# 🏢 업체명: 한불에너지관리(주)
#    - 대표자: 가보렐 마르셀 루시앙 프랑소와
#
# 🏢 업체명: 반석건설(주)
#    - 대표자: 가봄
#
# 🏢 업체명: 예지산업 주식회사
#    - 대표자: 가봉섭
#
# 🏢 업체명: 에이치디한국조선해양(주)
#    - 대표자: 가삼현
#
# 🏢 업체명: 서창중공업건설(주)
#    - 대표자: 가상열
#
# 🏢 업체명: 주식회사 다담엔지니어링
#    - 대표자: 가상현
#
# 🏢 업체명: 유한회사 선민건설
#    - 대표자: 가석자
#
# 🏢 업체명: 가나종합건설주식회사
#    - 대표자: 가성현
#
# 🏢 업체명: 주식회사 금강전자
#    - 대표자: 가성현
#
# 🏢 업체명: 주식회사 양우이엔씨
#    - 대표자: 가성훈
#
# 🏢 업체명: 가영건축사사무소
#    - 대표자: 가수현
#
# 🏢 업체명: 대룡건설(주)
#    - 대표자: 가순열
#
# 🏢 업체명: 반석건설(주)
#    - 대표자: 가승현
#
# 🏢 업체명: 하은종합건설 (주)
#    - 대표자: 가승현
#
# 🏢 업체명: 볼로스튜디오
#    - 대표자: 가승훈
#
# 🏢 업체명: 월드그린
#    - 대표자: 가양진
#
# 🏢 업체명: 주식회사 우리이엔지
#    - 대표자: 가양현
#
# 🏢 업체명: 주식회사지유건설
#    - 대표자: 가웅현
#
# 🏢 업체명: 원일이엔씨 주식회사
#    - 대표자: 가은주
#
# 🏢 업체명: 노아종합건설 주식회사
#    - 대표자: 가장성
#
# 🏢 업체명: 주식회사 태안전기
#    - 대표자: 가재돈
#
# 🏢 업체명: 주식회사 재현인텍스
#    - 대표자: 가재민
#
# 🏢 업체명: 주식회사 서해엔지니어링
#    - 대표자: 가재삼
#
# 🏢 업체명: (주)위즈
#    - 대표자: 가재영
#
# 🏢 업체명: 주식회사 스카이환경개발
#    - 대표자: 가재옥
#
# 🏢 업체명: 다원종합건설(주)
#    - 대표자: 가재창
#
# 🏢 업체명: 중부웰빙산업
#    - 대표자: 가지선
#
# 🏢 업체명: 새람산림엔지니어링
#    - 대표자: 가지연
#
# 🏢 업체명: (주)미래건축전략연구소
#    - 대표자: 가참희
#
# 🏢 업체명: 서창중공업 주식회사
#    - 대표자: 가창윤
#
# 🏢 업체명: (주)현대렌탈서비스
#    - 대표자: 가철
#
# 🏢 업체명: 주식회사 대연건설산업
#    - 대표자: 가택순
#
# 🏢 업체명: 에이스건설산업주식회사
#    - 대표자: 가택순
#
# 🏢 업체명: 덕수산업
#    - 대표자: 가혁순
#
# 🏢 업체명: 삼원조경건설(주)
#    - 대표자: 가현
#
# 🏢 업체명: 지산종합건설주식회사
#    - 대표자: 가현
#
# 🏢 업체명: 주식회사 아주전기
#    - 대표자: 가혜림
#
# 🏢 업체명: 주식회사 청인
#    - 대표자: 가혜영
#
# 🏢 업체명: 주식회사 신나는세상
#    - 대표자: 가회광
#
# 🏢 업체명: 세종광고
#    - 대표자: 간명식
#
# 🏢 업체명: (주)원강바이오
#    - 대표자: 간봉철
#
# 🏢 업체명: 부흥환경
#    - 대표자: 간영길
#
# 🏢 업체명: (주) 국일전기
#    - 대표자: 간영순
#
# 🏢 업체명: 주식회사 다비치건설
#    - 대표자: 간은경
#
# 🏢 업체명: 에스디지컴(주)
#    - 대표자: 간태경
#
# 🏢 업체명: 비엠시스텍
#    - 대표자: 간현미
#
# 🏢 업체명: 주식회사 세일이씨씨
#    - 대표자: 간현선
#
# 🏢 업체명: 주식회사 유창토건
#    - 대표자: 갈동규
#
# 🏢 업체명: 진주국기사
#    - 대표자: 갈명옥
#
# 🏢 업체명: 동성조경주식회사
#    - 대표자: 갈미정
#
# 🏢 업체명: 주식회사 터원산업개발
#    - 대표자: 갈미화
#
# 🏢 업체명: 제이테크
#    - 대표자: 갈백하
#
# 🏢 업체명: 천수개발(주)
#    - 대표자: 갈영수
#
# 🏢 업체명: 진성통신
#    - 대표자: 갈용호
#
# 🏢 업체명: 우성아이엔디 주식회사
#    - 대표자: 갈창덕
#
# 🏢 업체명: 우성산업개발 주식회사
#    - 대표자: 갈창덕
#
# 🏢 업체명: 더비기닝
#    - 대표자: 갈혜진
#
# 🏢 업체명: 그아래건축사사무소
#    - 대표자: 감경락
#
# 🏢 업체명: 주식회사 대현전력
#    - 대표자: 감경민
#
# 🏢 업체명: 대원에코필드주식회사
#    - 대표자: 감문선
#
# 🏢 업체명: 민형
#    - 대표자: 감민형
#
# 🏢 업체명: 대경전력
#    - 대표자: 감병욱
#
# 🏢 업체명: 주식회사세명개발
#    - 대표자: 감병원
#
# 🏢 업체명: 주식회사 에스존
#    - 대표자: 감석분
#
# 🏢 업체명: (주)태성전력
#    - 대표자: 감승한
#
# 🏢 업체명: 동현테크 주식회사
#    - 대표자: 감승한
#
# 🏢 업체명: 한국보훈복지의료공단
#    - 대표자: 감신
#
# 🏢 업체명: 한국보훈복지의료공단 보훈교육연구원
#    - 대표자: 감신
#
# 🏢 업체명: 동현전력주식회사
#    - 대표자: 감영창
#
# 🏢 업체명: 현대실업주식회사
#    - 대표자: 감은근
#
# 🏢 업체명: 주식회사 단감
#    - 대표자: 감은희
#
# 🏢 업체명: 지오건설개발 주식회사
#    - 대표자: 감을석
#
# 🏢 업체명: 주식회사신영
#    - 대표자: 감정만
#
# 🏢 업체명: 주식회사 비츠로
#    - 대표자: 감정선
#
# 🏢 업체명: 강산토건 주식회사
#    - 대표자: 감종석
#
# 🏢 업체명: 현송건설 주식회사
#    - 대표자: 감진욱
#
# 🏢 업체명: 제이에스건설 주식회사
#    - 대표자: 감진욱
#
# 🏢 업체명: 주식회사 에스다
#    - 대표자: 감형길
#
# 🏢 업체명: 새한텔레콤
#    - 대표자: 감홍구
#
# 🏢 업체명: 대현건설 주식회사
#    - 대표자: 강 문 석
#
# 🏢 업체명: 우창전기(주)
#    - 대표자: 강 보
#
# 🏢 업체명: 이엠코리아주식회사창원지점
#    - 대표자: 강 삼 수
#
# 🏢 업체명: (주)코리아트리즈
#    - 대표자: 강 윤 철
#
# 🏢 업체명: 주식회사 유림이앤지
#    - 대표자: 강가림
#
# 🏢 업체명: (유)주성이엔씨
#    - 대표자: 강가염
#
# 🏢 업체명: 태원종합건설 주식회사
#    - 대표자: 강가영
#
# 🏢 업체명: (주)아일종합건설
#    - 대표자: 강가현
#
# 🏢 업체명: 주식회사 윈스타비투비
#    - 대표자: 강가현
#
# 🏢 업체명: 서동건설 주식회사
#    - 대표자: 강감찬
#
# 🏢 업체명: 새싹나라영농조합법인
#    - 대표자: 강갑동
#
# 🏢 업체명: 팔방미인 주식회사
#    - 대표자: 강갑례
#
# 🏢 업체명: 주식회사 다원토건
#    - 대표자: 강갑수
#
# 🏢 업체명: 휴먼케어솔루션
#    - 대표자: 강갑수
#
# 🏢 업체명: 대성포장건설 주식회사
#    - 대표자: 강갑중
#
# 🏢 업체명: 주식회사 대양종합물류
#    - 대표자: 강갑진
#
# 🏢 업체명: 주식회사 대원소방이엔지
#    - 대표자: 강강순
#
# 🏢 업체명: 주식회사 명건
#    - 대표자: 강건
#
# 🏢 업체명: (주)더블유피
#    - 대표자: 강건민
#
# 🏢 업체명: 주식회사 이오종합건설
#    - 대표자: 강건수
#
# 🏢 업체명: 쌍용전력(주)
#    - 대표자: 강건우
#
# 🏢 업체명: 기명전력(주)
#    - 대표자: 강건우
#
# 🏢 업체명: 글로벌세븐
#    - 대표자: 강건우
#
# 🏢 업체명: 주식회사 혜륜종합건설
#    - 대표자: 강건욱
#
# 🏢 업체명: (주)지플러스
#    - 대표자: 강건희
#
# 🏢 업체명: 주식회사 유민이앤씨
#    - 대표자: 강견래
#
# 🏢 업체명: 주식회사 누비텔레콤
#    - 대표자: 강경구
#
# 🏢 업체명: 신양아이엔지건설(주)
#    - 대표자: 강경구
#
# 🏢 업체명: 주식회사 가온푸르
#    - 대표자: 강경구
#
# 🏢 업체명: 주식회사 청호엔지니어링
#    - 대표자: 강경구
#
# 🏢 업체명: 주식회사 청광건설
#    - 대표자: 강경구
#
# 🏢 업체명: 바른사무가구
#    - 대표자: 강경구
#
# 🏢 업체명: 주식회사 해오름씨푸드
#    - 대표자: 강경구
#
# 🏢 업체명: (주)장원푸드
#    - 대표자: 강경구
#
# 🏢 업체명: 주식회사 오토시스템
#    - 대표자: 강경남
#
# 🏢 업체명: 태흥주식회사
#    - 대표자: 강경남
#
# 🏢 업체명: 건축물에너지평가사 협동조합
#    - 대표자: 강경남
#
# 🏢 업체명: 재다 건축사사무소
#    - 대표자: 강경남
#
# 🏢 업체명: 강건테크
#    - 대표자: 강경님
#
# 🏢 업체명: 주식회사 태인건설
#    - 대표자: 강경도
#
# 🏢 업체명: 주식회사 오리온아이
#    - 대표자: 강경돈
#
# 🏢 업체명: 주식회사 세이브앤 태원
#    - 대표자: 강경동
#
# 🏢 업체명: 케이앤와이 주식회사
#    - 대표자: 강경란
#
# 🏢 업체명: 무한개발(주)
#    - 대표자: 강경랑
#
# 🏢 업체명: 에스원종합건설 주식회사
#    - 대표자: 강경래
#
# 🏢 업체명: 위드환경산업
#    - 대표자: 강경면
#
# 🏢 업체명: 대한전기
#    - 대표자: 강경모
#
# 🏢 업체명: 씨엔씨해양개발(주)
#    - 대표자: 강경모
#
# 🏢 업체명: 케이앤케이건축사사무소
#    - 대표자: 강경모
#
# 🏢 업체명: 주식회사 유앤케이건축사사무소
#    - 대표자: 강경모
#
# 🏢 업체명: (주)대림전기
#    - 대표자: 강경문
#
# 🏢 업체명: 株式會社 鎭元建設
#    - 대표자: 강경미
#
# 🏢 업체명: (주)연미건설
#    - 대표자: 강경미
#
# 🏢 업체명: 시대건설주식회사
#    - 대표자: 강경미
#
# 🏢 업체명: 주식회사 세본테크
#    - 대표자: 강경미
#
# 🏢 업체명: 마루종합건설주식회사
#    - 대표자: 강경미
#
# 🏢 업체명: (주)거금이엔씨
#    - 대표자: 강경미
#
# 🏢 업체명: 주식회사 가호개발
#    - 대표자: 강경민
#
# 🏢 업체명: 나영컴퍼니
#    - 대표자: 강경민
#
# 🏢 업체명: 창천동13-3
#    - 대표자: 강경민
#
# 🏢 업체명: 다둥이네
#    - 대표자: 강경민
#
# 🏢 업체명: 그랜드스포츠
#    - 대표자: 강경민
#
# 🏢 업체명: 주식회사 건축사 사무소 우림
#    - 대표자: 강경범
#
# 🏢 업체명: 동성전력 주식회사
#    - 대표자: 강경보
#
# 🏢 업체명: 동호건설 주식회사
#    - 대표자: 강경석
#
# 🏢 업체명: 주식회사 팀아이원
#    - 대표자: 강경석
#
# 🏢 업체명: 주식회사 에스제이이엔씨
#    - 대표자: 강경석
#
# 🏢 업체명: 에이테크
#    - 대표자: 강경석
#
# 🏢 업체명: 선진전력(주)
#    - 대표자: 강경석
#
# 🏢 업체명: 주식회사효명
#    - 대표자: 강경선
#
# 🏢 업체명: 주식회사 경산전설
#    - 대표자: 강경선
#
# 🏢 업체명: 쌍디쓰
#    - 대표자: 강경선
#
# 🏢 업체명: 오션플랜트 주식회사
#    - 대표자: 강경수
#
# 🏢 업체명: 주식회사 상원건설개발
#    - 대표자: 강경수
#
# 🏢 업체명: 주식회사 태광이앤씨
#    - 대표자: 강경수
#
# 🏢 업체명: 태경개발 주식회사
#    - 대표자: 강경숙
#
# 🏢 업체명: 주식회사 영성조경
#    - 대표자: 강경숙
#
# 🏢 업체명: (주)창성티앤씨
#    - 대표자: 강경숙
#
# 🏢 업체명: 주식회사 금성랜드
#    - 대표자: 강경숙
#
# 🏢 업체명: (주)창명전력
#    - 대표자: 강경숙
#
# 🏢 업체명: 디노플러스 주식회사
#    - 대표자: 강경숙
#
# 🏢 업체명: 삼익(대구점)
#    - 대표자: 강경숙
#
# 🏢 업체명: 주식회사 제이제이건설
#    - 대표자: 강경숙
#
# 🏢 업체명: 주식회사 유진에코텍
#    - 대표자: 강경순
#
# 🏢 업체명: 더착한주식회사
#    - 대표자: 강경순
#
# 🏢 업체명: 와이케이 주식회사
#    - 대표자: 강경순
#
# 🏢 업체명: 유경건설 주식회사
#    - 대표자: 강경순
#
# 🏢 업체명: 승승이네 마켓
#    - 대표자: 강경식
#
# 🏢 업체명: 주식회사 클루라이프
#    - 대표자: 강경신
#
# 🏢 업체명: (주)윤디자인연구소
#    - 대표자: 강경아
#
# 🏢 업체명: 주식회사 태원조경
#    - 대표자: 강경아
#
# 🏢 업체명: 주식회사 새길건설
#    - 대표자: 강경아
#
# 🏢 업체명: 주식회사 은아건설
#    - 대표자: 강경아
#
# 🏢 업체명: (주)태윤종합건설
#    - 대표자: 강경아
#
# 🏢 업체명: 주식회사 솔향원
#    - 대표자: 강경애
#
# 🏢 업체명: 사단법인 한국장애인 한걸음더동행
#    - 대표자: 강경애
#
# 🏢 업체명: 주식회사 티에스
#    - 대표자: 강경오
#
# 🏢 업체명: (주)일렉워크
#    - 대표자: 강경옥
#
# 🏢 업체명: 난방산업 주식회사
#    - 대표자: 강경옥
#
# 🏢 업체명: 주식회사 다울이엔지
#    - 대표자: 강경옥
#
# 🏢 업체명: 이강솔루션
#    - 대표자: 강경옥
#
# 🏢 업체명: 이카리나
#    - 대표자: 강경옥
#
# 🏢 업체명: 마리정보통신
#    - 대표자: 강경옥
#
# 🏢 업체명: 주식회사 템솔
#    - 대표자: 강경완
#
# 🏢 업체명: 청호이엔지
#    - 대표자: 강경완
#
# 🏢 업체명: 주식회사 대원구조안전진단
#    - 대표자: 강경완
#
# 🏢 업체명: 광명이엔씨
#    - 대표자: 강경운
#
# 🏢 업체명: 주식회사 화당산업
#    - 대표자: 강경원
#
# 🏢 업체명: 주식회사 아름건설
#    - 대표자: 강경원
#
# 🏢 업체명: (주)세명구조엔지니어링
#    - 대표자: 강경원
#
# 🏢 업체명: 다움솔루션
#    - 대표자: 강경원
#
# 🏢 업체명: (주) 강운건설
#    - 대표자: 강경원
#
# 🏢 업체명: 보근이엔지 주식회사
#    - 대표자: 강경원
#
# 🏢 업체명: 웅천건설 주식회사
#    - 대표자: 강경유
#
# 🏢 업체명: 매직렌탈
#    - 대표자: 강경은
#
# 🏢 업체명: 주식회사기단기술
#    - 대표자: 강경의
#
# 🏢 업체명: 씨엘산업 주식회사
#    - 대표자: 강경일
#
# 🏢 업체명: 대림방역
#    - 대표자: 강경일
#
# 🏢 업체명: 정남진장흥농협 농산물산지유통센터
#    - 대표자: 강경일
#
# 🏢 업체명: 누마루종합건설(주)
#    - 대표자: 강경일
#
# 🏢 업체명: 주식회사 가람아키테리어
#    - 대표자: 강경임
#
# 🏢 업체명: (주)다원종합건설
#    - 대표자: 강경재
#
# 🏢 업체명: 잘나가는쇼핑
#    - 대표자: 강경재
#
# 🏢 업체명: 태호건설산업
#    - 대표자: 강경주
#
# 🏢 업체명: 주식회사 오승건설
#    - 대표자: 강경주
#
# 🏢 업체명: 주원정보통신
#    - 대표자: 강경주
#
# 🏢 업체명: M＆J 스포츠
#    - 대표자: 강경진
#
# 🏢 업체명: 주식회사 영보전기
#    - 대표자: 강경진
#
# 🏢 업체명: 편리한생활마트
#    - 대표자: 강경진
#
# 🏢 업체명: NC부산(주)
#    - 대표자: 강경진
#
# 🏢 업체명: 주식회사 거전이엔지
#    - 대표자: 강경철
#
# 🏢 업체명: 어메이징서비스
#    - 대표자: 강경탁
#
# 🏢 업체명: (주)정화건설
#    - 대표자: 강경탁
#
# 🏢 업체명: 주식회사 부경전기
#    - 대표자: 강경태
#
# 🏢 업체명: (주)글로벌넷
#    - 대표자: 강경택
#
# 🏢 업체명: 오토테크
#    - 대표자: 강경필
#
# 🏢 업체명: 동원산업주식회사
#    - 대표자: 강경필
#
# 🏢 업체명: 서진조경(주)
#    - 대표자: 강경호
#
# 🏢 업체명: 주식회사 태승건설
#    - 대표자: 강경호
#
# 🏢 업체명: 신화문화사
#    - 대표자: 강경호
#
# 🏢 업체명: 주식회사 명일전기
#    - 대표자: 강경호
#
# 🏢 업체명: 주식회사  삼일기계설비
#    - 대표자: 강경호
#
# 🏢 업체명: 강디자인
#    - 대표자: 강경호
#
# 🏢 업체명: 주식회사 대성산업개발
#    - 대표자: 강경호
#
# 🏢 업체명: 범한건설 주식회사
#    - 대표자: 강경호
#
# 🏢 업체명: 스크랩(SCLAB)
#    - 대표자: 강경호
#
# 🏢 업체명: 케이엘 에너지 솔루션
#    - 대표자: 강경호
#
# 🏢 업체명: 고봉
#    - 대표자: 강경호
#
# 🏢 업체명: 주식회사 통포장건설
#    - 대표자: 강경화
#
# 🏢 업체명: 주식회사 통건설
#    - 대표자: 강경화
#
# 🏢 업체명: 주식회사 이데
#    - 대표자: 강경환
#
# 🏢 업체명: 도도맨즈
#    - 대표자: 강경환
#
# 🏢 업체명: 동부전기
#    - 대표자: 강경훈
#
# 🏢 업체명: 현경산업개발 주식회사
#    - 대표자: 강경훈
#
# 🏢 업체명: (주)백경이엔씨
#    - 대표자: 강경훈
#
# 🏢 업체명: 푸른기획
#    - 대표자: 강경훈
#
# 🏢 업체명: 주식회사 애림
#    - 대표자: 강경희
#
# 🏢 업체명: 주식회사 삼양전자통신
#    - 대표자: 강경희
#
# 🏢 업체명: 주식회사 영진이엘에스
#    - 대표자: 강경희
#
# 🏢 업체명: 세운건설주식회사
#    - 대표자: 강경희
#
# 🏢 업체명: 주식회사 신흥전기
#    - 대표자: 강경희
#
# 🏢 업체명: 미래나라
#    - 대표자: 강경희
#
# 🏢 업체명: 청수건설 주식회사
#    - 대표자: 강경희
#
# 🏢 업체명: 주식회사 대로건축
#    - 대표자: 강경희
#
# 🏢 업체명: 제우스파라모터
#    - 대표자: 강경희
#
# 🏢 업체명: 경인
#    - 대표자: 강경희
#
# 🏢 업체명: (주)대성종합관리
#    - 대표자: 강계순
#
# 🏢 업체명: 청록환경산업(주)
#    - 대표자: 강계실
#
# 🏢 업체명: 다옴건축사사무소
#    - 대표자: 강계웅
#
# 🏢 업체명: 건축사사무소 세종
#    - 대표자: 강계원
#
# 🏢 업체명: 겸송
#    - 대표자: 강계홍
#
# 🏢 업체명: 주식회사 강산
#    - 대표자: 강계화
#
# 🏢 업체명: 에이미스토어
#    - 대표자: 강계희
#
# 🏢 업체명: 정성종합건설 주식회사
#    - 대표자: 강공만
#
# 🏢 업체명: 주식회사 피플아이디
#    - 대표자: 강관
#
# 🏢 업체명: 수성전척(주)
#    - 대표자: 강관수
#
# 🏢 업체명: 건축사사무소 늘그린
#    - 대표자: 강관욱
#
# 🏢 업체명: 주식회사 효광
#    - 대표자: 강광구
#
# 🏢 업체명: 조은환경
#    - 대표자: 강광남
#
# 🏢 업체명: 주식회사 부안안전시스템
#    - 대표자: 강광모
#
# 🏢 업체명: 땡큐
#    - 대표자: 강광민
#
# 🏢 업체명: 최강종합건설 주식회사
#    - 대표자: 강광석
#
# 🏢 업체명: 아세아테크
#    - 대표자: 강광수
#
# 🏢 업체명: 주식회사 대명전기
#    - 대표자: 강광용
#
# 🏢 업체명: 주식회사 큐센텍
#    - 대표자: 강광운
#
# 🏢 업체명: (주)신명과학
#    - 대표자: 강광표
#
# 🏢 업체명: 주식회사마루테크
#    - 대표자: 강광희
#
# 🏢 업체명: 주식회사한빛레이저텍
#    - 대표자: 강광희
#
# 🏢 업체명: 보강산업
#    - 대표자: 강교은
#
# 🏢 업체명: 마랑유통
#    - 대표자: 강교은
#
# 🏢 업체명: 주식회사 강인환경건설
#    - 대표자: 강구
#
# 🏢 업체명: 세종건설 주식회사
#    - 대표자: 강구남
#
# 🏢 업체명: 태범전설
#    - 대표자: 강구명
#
# 🏢 업체명: 주식회사 엑솔루스
#    - 대표자: 강구민
#
# 🏢 업체명: 소이전기조명
#    - 대표자: 강구식
#
# 🏢 업체명: 한국항공우주산업 주식회사
#    - 대표자: 강구영
#
# 🏢 업체명: 대은건설(주)
#    - 대표자: 강구원
#
# 🏢 업체명: 주식회사 동토종합건설
#    - 대표자: 강구원
#
# 🏢 업체명: 크린테크
#    - 대표자: 강구익
#
# 🏢 업체명: (주)크린테크
#    - 대표자: 강구익
#
# 🏢 업체명: 주식회사부경
#    - 대표자: 강구일
#
# 🏢 업체명: 중원기계
#    - 대표자: 강구태
#
# 🏢 업체명: 보성인재
#    - 대표자: 강구태
#
# 🏢 업체명: 넥스테크 주식회사
#    - 대표자: 강구태
#
# 🏢 업체명: 율시스템(주)
#    - 대표자: 강구학
#
# 🏢 업체명: 주식회사 대흥이엔지
#    - 대표자: 강구호
#
# 🏢 업체명: 씨케이건설 주식회사
#    - 대표자: 강구환
#
# 🏢 업체명: 평리ENG
#    - 대표자: 강국보
#
# 🏢 업체명: 거산조경건설주식회사
#    - 대표자: 강국진
#
# 🏢 업체명: 그린산림주식회사
#    - 대표자: 강국진
#
# 🏢 업체명: 주식회사 동양씨앤씨
#    - 대표자: 강국진
#
# 🏢 업체명: 비너스 상회
#    - 대표자: 강군석
#
# 🏢 업체명: (주)이에스텍
#    - 대표자: 강군혁
#
# 🏢 업체명: 코너스톤
#    - 대표자: 강궁원
#
# 🏢 업체명: 주식회사 협성
#    - 대표자: 강권목
#
# 🏢 업체명: 잉크뱅크
#    - 대표자: 강권호
#
# 🏢 업체명: 주식회사 에이스건설
#    - 대표자: 강귀봉
#
# 🏢 업체명: 주식회사 영원에스엠
#    - 대표자: 강귀성
#
# 🏢 업체명: 한반도공인중개사사무소
#    - 대표자: 강귀영
#
# 🏢 업체명: 에이스
#    - 대표자: 강귀이
#
# 🏢 업체명: 주식회사 가림
#    - 대표자: 강귀주
#
# 🏢 업체명: 주식회사 세강전력
#    - 대표자: 강규
#
# 🏢 업체명: 주식회사 엘케이플러스
#    - 대표자: 강규리
#
# 🏢 업체명: 라온제나
#    - 대표자: 강규리
#
# 🏢 업체명: 중우하나린 주식회사
#    - 대표자: 강규백
#
# 🏢 업체명: 영도건설 주식회사
#    - 대표자: 강규백
#
# 🏢 업체명: 신라건설 주식회사
#    - 대표자: 강규백
#
# 🏢 업체명: 우석종합관리
#    - 대표자: 강규석
#
# 🏢 업체명: 주식회사 휴서방
#    - 대표자: 강규성
#
# 🏢 업체명: 솔향서점
#    - 대표자: 강규영
#
# 🏢 업체명: (주)한미기술
#    - 대표자: 강규익
#
# 🏢 업체명: 금강정원주식회사
#    - 대표자: 강규일
#
# 🏢 업체명: 기린환경(주)
#    - 대표자: 강규임
#
# 🏢 업체명: 일진종합건설 주식회사
#    - 대표자: 강규철
#
# 🏢 업체명: 들목건축사사무소
#    - 대표자: 강규철
#
# 🏢 업체명: 주식회사 리또시뮬레이션솔루션스
#    - 대표자: 강규철
#
# 🏢 업체명: 하나랩
#    - 대표자: 강규호
#
# 🏢 업체명: 건우건축사사무소
#    - 대표자: 강규호
#
# 🏢 업체명: 두정건설 주식회사
#    - 대표자: 강규희
#
# 🏢 업체명: 수양버들주식회사
#    - 대표자: 강근기
#
# 🏢 업체명: 에이치에스닷컴
#    - 대표자: 강근선
#
# 🏢 업체명: 경동건설주식회사
#    - 대표자: 강근수
#
# 🏢 업체명: 주식회사 동신티앤지
#    - 대표자: 강근수
#
# 🏢 업체명: 주식회사 반석건설
#    - 대표자: 강근순
#
# 🏢 업체명: (주)라인원이앤씨
#    - 대표자: 강근순
#
# 🏢 업체명: 세아테크 주식회사
#    - 대표자: 강근실
#
# 🏢 업체명: 강성개발 주식회사
#    - 대표자: 강근영
#
# 🏢 업체명: 영도건설 주식회사
#    - 대표자: 강근영
#
# 🏢 업체명: 신정
#    - 대표자: 강근영
#
# 🏢 업체명: 주식회사 라이온교통
#    - 대표자: 강근우
#
# 🏢 업체명: 주식회사 루이스건설
#    - 대표자: 강근원
#
# 🏢 업체명: (주)가람정보통신
#    - 대표자: 강근호
#
# 🏢 업체명: 다온
#    - 대표자: 강근호
#
# 🏢 업체명: 주식회사삼우이엔지
#    - 대표자: 강근호
#
# 🏢 업체명: 더툴즈(The Tools)
#    - 대표자: 강근호
#
# 🏢 업체명: 건축사사무소 원
#    - 대표자: 강근호
#
# 🏢 업체명: 삼원산업개발 주식회사
#    - 대표자: 강근환
#
# 🏢 업체명: 썬그린
#    - 대표자: 강금과
#
# 🏢 업체명: 포스메이드 주식회사
#    - 대표자: 강금단
#
# 🏢 업체명: 주식회사 태성정보통신기술
#    - 대표자: 강금례
#
# 🏢 업체명: 미래도시환경
#    - 대표자: 강금미
#
# 🏢 업체명: (주)친환경
#    - 대표자: 강금미
#
# 🏢 업체명: 주식회사 미르 어패럴
#    - 대표자: 강금분
#
# 🏢 업체명: 대명건설 주식회사
#    - 대표자: 강금선
#
# 🏢 업체명: 신양건설 주식회사
#    - 대표자: 강금선
#
# 🏢 업체명: 청남종합건설(주)
#    - 대표자: 강금선
#
# 🏢 업체명: 행운쇼핑
#    - 대표자: 강금선
#
# 🏢 업체명: 반야토건 주식회사
#    - 대표자: 강금숙
#
# 🏢 업체명: 반야건설 주식회사
#    - 대표자: 강금숙
#
# 🏢 업체명: ks전자
#    - 대표자: 강금순
#
# 🏢 업체명: 금정종합건설(주)
#    - 대표자: 강금순
#
# 🏢 업체명: (주)안전소방
#    - 대표자: 강금실
#
# 🏢 업체명: 모아히어
#    - 대표자: 강금영
#
# 🏢 업체명: (주)대룡
#    - 대표자: 강금용
#
# 🏢 업체명: 대성개발(주)
#    - 대표자: 강금자
#
# 🏢 업체명: 주식회사 금문이앤지
#    - 대표자: 강금자
#
# 🏢 업체명: 더꿈
#    - 대표자: 강금주
#
# 🏢 업체명: (주) 서호디자인건설
#    - 대표자: 강금주
#
# 🏢 업체명: 유한회사 종합전설
#    - 대표자: 강금희
#
# 🏢 업체명: 케이쓰리
#    - 대표자: 강기공
#
# 🏢 업체명: 유엔케이(UnK)유통회사
#    - 대표자: 강기남
#
# 🏢 업체명: (주)아이메탈
#    - 대표자: 강기도
#
# 🏢 업체명: (주)청풍이엔에스
#    - 대표자: 강기동
#
# 🏢 업체명: 보령건설산업 주식회사
#    - 대표자: 강기동
#
# 🏢 업체명: 가온누리
#    - 대표자: 강기리
#
# 🏢 업체명: (주)세미
#    - 대표자: 강기만
#
# 🏢 업체명: (주)제일
#    - 대표자: 강기만
#
# 🏢 업체명: 정주종합건설(주)
#    - 대표자: 강기만
#
# 🏢 업체명: 호영전기소방주식회사
#    - 대표자: 강기문
#
# 🏢 업체명: (주)그린에이알테크
#    - 대표자: 강기백
#
# 🏢 업체명: 주식회사 케이엔유통
#    - 대표자: 강기범
#
# 🏢 업체명: (주)태광건설
#    - 대표자: 강기봉
#
# 🏢 업체명: 주식회사 한솔전기
#    - 대표자: 강기봉
#
# 🏢 업체명: 수광종합건설 주식회사
#    - 대표자: 강기생
#
# 🏢 업체명: 한국플랜트서비스 주식회사
#    - 대표자: 강기석
#
# 🏢 업체명: 주식회사 우재종합건설
#    - 대표자: 강기성
#
# 🏢 업체명: 휴안건축사사무소
#    - 대표자: 강기수
#
# 🏢 업체명: 주식회사 에스디페이브
#    - 대표자: 강기수
#
# 🏢 업체명: (주)쌍암건설
#    - 대표자: 강기순
#
# 🏢 업체명: 뉴월드인텍(주)
#    - 대표자: 강기엽
#
# 🏢 업체명: 도로안전건설 주식회사
#    - 대표자: 강기영
#
# 🏢 업체명: 마이피스
#    - 대표자: 강기옥
#
# 🏢 업체명: 미소산업(주)
#    - 대표자: 강기완
#
# 🏢 업체명: 기원상사
#    - 대표자: 강기용
#
# 🏢 업체명: (주)금강이앤지
#    - 대표자: 강기용
#
# 🏢 업체명: 주식회사 대명종합상사
#    - 대표자: 강기용
#
# 🏢 업체명: 주식회사토마토렌트카
#    - 대표자: 강기용
#
# 🏢 업체명: 주식회사 송암
#    - 대표자: 강기욱
#
# 🏢 업체명: 주식회사대경오앤티
#    - 대표자: 강기웅
#
# 🏢 업체명: 유니종합물산
#    - 대표자: 강기웅
#
# 🏢 업체명: 주식회사 와이즈투모로우
#    - 대표자: 강기웅
#
# 🏢 업체명: (주)강산씨앤씨
#    - 대표자: 강기원
#
# 🏢 업체명: 유한회사 키움조경
#    - 대표자: 강기원
#
# 🏢 업체명: 나이스방재 주식회사
#    - 대표자: 강기원
#
# 🏢 업체명: 강림종합건설 주식회사
#    - 대표자: 강기종
#
# 🏢 업체명: 주식회사 케이엔
#    - 대표자: 강기주
#
# 🏢 업체명: 주식회사 삼주토건
#    - 대표자: 강기진
#
# 🏢 업체명: 대일전기 주식회사
#    - 대표자: 강기철
#
# 🏢 업체명: 경보테크
#    - 대표자: 강기철
#
# 🏢 업체명: 주식회사 세모
#    - 대표자: 강기철
#
# 🏢 업체명: (주)메트로이엔지
#    - 대표자: 강기태
#
# 🏢 업체명: 케이테크
#    - 대표자: 강기택
#
# 🏢 업체명: 대구드림텍
#    - 대표자: 강기표
#
# 🏢 업체명: 주식회사 종로소방
#    - 대표자: 강기현
#
# 🏢 업체명: 이안엔지니어링
#    - 대표자: 강기현
#
# 🏢 업체명: 주식회사 이현테크윈
#    - 대표자: 강기현
#
# 🏢 업체명: 아림건설(주)
#    - 대표자: 강기형
#
# 🏢 업체명: 한국설비연구(주)
#    - 대표자: 강기호
#
# 🏢 업체명: 주식회사 라온건영
#    - 대표자: 강기호
#
# 🏢 업체명: 주식회사 한빛테크
#    - 대표자: 강기홍
#
# 🏢 업체명: 세승산업개발 주식회사
#    - 대표자: 강기훈
#
# 🏢 업체명: 주식회사 청풍기업
#    - 대표자: 강기훈
#
# 🏢 업체명: 우왕건설(주)
#    - 대표자: 강길리
#
# 🏢 업체명: 모닝
#    - 대표자: 강길모
#
# 🏢 업체명: (주)천양사의료과학
#    - 대표자: 강길모
#
# 🏢 업체명: 모닝커머스
#    - 대표자: 강길모
#
# 🏢 업체명: 태완개발(주)
#    - 대표자: 강길석
#
# 🏢 업체명: 우광건축사사무소
#    - 대표자: 강길선
#
# 🏢 업체명: 해암상사
#    - 대표자: 강길성
#
# 🏢 업체명: 주식회사 반도전기통신
#    - 대표자: 강길수
#
# 🏢 업체명: 에솜 주식회사
#    - 대표자: 강길영
#
# 🏢 업체명: 우임
#    - 대표자: 강길우
#
# 🏢 업체명: 주식회사 리메이드
#    - 대표자: 강길원
#
# 🏢 업체명: 청광전기
#    - 대표자: 강길자
#
# 🏢 업체명: 대양전설주식회사
#    - 대표자: 강길진
#
# 🏢 업체명: 주식회사 대승
#    - 대표자: 강길진
#
# 🏢 업체명: 교보종합건설주식회사
#    - 대표자: 강길현
#
# 🏢 업체명: 주식회사 일성계전
#    - 대표자: 강길화
#
# 🏢 업체명: 그린구스
#    - 대표자: 강김구
#
# 🏢 업체명: 디와이플로우테크 주식회사
#    - 대표자: 강나루
#
# 🏢 업체명: 케이엘컴퍼니
#    - 대표자: 강나미
#
# 🏢 업체명: 디엠아이디산업(구)디엠인테리어
#    - 대표자: 강나연
#
# 🏢 업체명: 바오산업
#    - 대표자: 강나연
#
# 🏢 업체명: 안녕
#    - 대표자: 강나연
#
# 🏢 업체명: 인코니
#    - 대표자: 강나연
#
# 🏢 업체명: 주식회사 선정퍼니처
#    - 대표자: 강나연
#
# 🏢 업체명: 엔에이치산업
#    - 대표자: 강나영
#
# 🏢 업체명: 일루미
#    - 대표자: 강나영
#
# 🏢 업체명: 주식회사 금오산맥
#    - 대표자: 강나원
#
# 🏢 업체명: 주식회사 나은
#    - 대표자: 강나은
#
# 🏢 업체명: 삼흥티앤에스 주식회사
#    - 대표자: 강나은
#
# 🏢 업체명: 신진기술(주)
#    - 대표자: 강나은
#
# 🏢 업체명: 고려통상
#    - 대표자: 강나정
#
# 🏢 업체명: 주식회사 해림건설
#    - 대표자: 강나현
#
# 🏢 업체명: 주식회사 참조은이엔지
#    - 대표자: 강낙관
#
# 🏢 업체명: (유)미래조경
#    - 대표자: 강난경
#
# 🏢 업체명: 주식회사 나래건설환경
#    - 대표자: 강난수
#
# 🏢 업체명: 주식회사 한울종합건설
#    - 대표자: 강남구
#
# 🏢 업체명: 엔케이 커머스
#    - 대표자: 강남구
#
# 🏢 업체명: (주)태림개발
#    - 대표자: 강남규
#
# 🏢 업체명: 유한회사 신광종합방재
#    - 대표자: 강남규
#
# 🏢 업체명: (주)지엔씨
#    - 대표자: 강남규
#
# 🏢 업체명: 한국에너시스
#    - 대표자: 강남규
#
# 🏢 업체명: 대봉건설 주식회사
#    - 대표자: 강남규
#
# 🏢 업체명: 건축사사무소필 강남규
#    - 대표자: 강남규
#
# 🏢 업체명: SH도어텍(주)
#    - 대표자: 강남기
#
# 🏢 업체명: 주식회사 입법정책연구원
#    - 대표자: 강남기
#
# 🏢 업체명: 최강기업
#    - 대표자: 강남기
#
# 🏢 업체명: 주식회사 태남건설
#    - 대표자: 강남도
#
# 🏢 업체명: 주식회사 에코와트전기
#    - 대표자: 강남림
#
# 🏢 업체명: 덕우컴퍼니
#    - 대표자: 강남미
#
# 🏢 업체명: 알카메디
#    - 대표자: 강남수
#
# 🏢 업체명: 주식회사 환영종합건설
#    - 대표자: 강남수
#
# 🏢 업체명: 주식회사 동건소방
#    - 대표자: 강남식
#
# 🏢 업체명: (주)  삼성토건
#    - 대표자: 강남실
#
# 🏢 업체명: 주식회사 삼성토건
#    - 대표자: 강남실
#
# 🏢 업체명: (주)태흥기업
#    - 대표자: 강남열
#
# 🏢 업체명: (유)반석건설
#    - 대표자: 강남우
#
# 🏢 업체명: 주식회사 파인트리
#    - 대표자: 강남욱
#
# 🏢 업체명: 아이오니아에너지(주)
#    - 대표자: 강남욱
#
# 🏢 업체명: 이천조경주식회사
#    - 대표자: 강남원
#
# 🏢 업체명: 대성전기
#    - 대표자: 강남이
#
# 🏢 업체명: 엔씨정보통신 주식회사
#    - 대표자: 강남일
#
# 🏢 업체명: (주)해온건설
#    - 대표자: 강남임
#
# 🏢 업체명: 유한회사 연화이엔지
#    - 대표자: 강남주
#
# 🏢 업체명: 유한회사 연화건설
#    - 대표자: 강남주
#
# 🏢 업체명: 주식회사 세경
#    - 대표자: 강남철
#
# 🏢 업체명: (주)현인
#    - 대표자: 강남춘
#
# 🏢 업체명: (주)우영종합건설
#    - 대표자: 강남헌
#
# 🏢 업체명: 유한회사 순창올크린
#    - 대표자: 강남훈
#
# 🏢 업체명: 디알티전력 주식회사
#    - 대표자: 강남희
#
# 🏢 업체명: 광목건설 주식회사
#    - 대표자: 강노경
#
# 🏢 업체명: 케이엠(KM)건축사사무소
#    - 대표자: 강노경
#
# 🏢 업체명: 한창개발 주식회사
#    - 대표자: 강노산
#
# 🏢 업체명: 주식회사 우리전력
#    - 대표자: 강늘란
#
# 🏢 업체명: 주식회사 엘리온
#    - 대표자: 강능숙
#
# 🏢 업체명: 주식회사 다감디자인
#    - 대표자: 강다감
#
# 🏢 업체명: 디앤에스
#    - 대표자: 강다겸
#
# 🏢 업체명: 쇼핑스토리T
#    - 대표자: 강다미
#
# 🏢 업체명: 동서개발 주식회사
#    - 대표자: 강다성
#
# 🏢 업체명: 스틸
#    - 대표자: 강다솔
#
# 🏢 업체명: 만경건설 주식회사
#    - 대표자: 강다솜
#
# 🏢 업체명: 미루건설합자회사
#    - 대표자: 강다영
#
# 🏢 업체명: 다온유통
#    - 대표자: 강다영
#
# 🏢 업체명: 다미
#    - 대표자: 강다영
#
# 🏢 업체명: 세무회계 단
#    - 대표자: 강다은
#
# 🏢 업체명: (주)하나엔지니어링
#    - 대표자: 강달관
#
# 🏢 업체명: 주식회사 우진개발
#    - 대표자: 강달중
#
# 🏢 업체명: 중앙건설산업주식회사
#    - 대표자: 강대건
#
# 🏢 업체명: 중앙전기 주식회사
#    - 대표자: 강대건
#
# 🏢 업체명: 중앙정보통신(주)
#    - 대표자: 강대건
#
# 🏢 업체명: 더(The) 덕빛
#    - 대표자: 강대겸
#
# 🏢 업체명: (주)마니건설
#    - 대표자: 강대경
#
# 🏢 업체명: 대호전기공사
#    - 대표자: 강대관
#
# 🏢 업체명: 주식회사 은성건설
#    - 대표자: 강대관
#
# 🏢 업체명: (주)정진팜
#    - 대표자: 강대관
#
# 🏢 업체명: 주식회사대호전기
#    - 대표자: 강대관
#
# 🏢 업체명: 주식회사 일해전기
#    - 대표자: 강대구
#
# 🏢 업체명: 지디시선산업
#    - 대표자: 강대군
#
# 🏢 업체명: 만복상사
#    - 대표자: 강대권
#
# 🏢 업체명: 더블유아이건설 주식회사
#    - 대표자: 강대귀
#
# 🏢 업체명: 승현산업
#    - 대표자: 강대규
#
# 🏢 업체명: 다원건설
#    - 대표자: 강대근
#
# 🏢 업체명: 대동건설
#    - 대표자: 강대근
#
# 🏢 업체명: 한송건설 주식회사
#    - 대표자: 강대근
#
# 🏢 업체명: (주)엔이아이기술
#    - 대표자: 강대남
#
# 🏢 업체명: 예진기업사
#    - 대표자: 강대만
#
# 🏢 업체명: 아이스박스(ICEBOX)
#    - 대표자: 강대모
#
# 🏢 업체명: 나눔산업개발 주식회사
#    - 대표자: 강대민
#
# 🏢 업체명: 사단법인 경기산업연구원
#    - 대표자: 강대붕
#
# 🏢 업체명: 한림기업(주)
#    - 대표자: 강대석
#
# 🏢 업체명: (주)진우티에스
#    - 대표자: 강대석
#
# 🏢 업체명: 미래전력개발(주)
#    - 대표자: 강대선
#
# 🏢 업체명: (주)대동산업
#    - 대표자: 강대성
#
# 🏢 업체명: 해주엔지니어링 주식회사
#    - 대표자: 강대성
#
# 🏢 업체명: (주)엠디이엔지
#    - 대표자: 강대성
#
# 🏢 업체명: 주식회사 에이치에스건설
#    - 대표자: 강대성
#
# 🏢 업체명: 주식회사 젠알에프티
#    - 대표자: 강대성
#
# 🏢 업체명: 주식회사 골든솔라
#    - 대표자: 강대성
#
# 🏢 업체명: 나라군장 주식회사
#    - 대표자: 강대성
#
# 🏢 업체명: 다히만
#    - 대표자: 강대성
#
# 🏢 업체명: 주식회사 아라종합건설
#    - 대표자: 강대성
#
# 🏢 업체명: 주식회사 가온씨앤디
#    - 대표자: 강대성
#
# 🏢 업체명: 하이퍼미디어
#    - 대표자: 강대수
#
# 🏢 업체명: 성신건설(주)
#    - 대표자: 강대순
#
# 🏢 업체명: 주식회사 하이메디칼
#    - 대표자: 강대순
#
# 🏢 업체명: 거화전설(주)
#    - 대표자: 강대식
#
# 🏢 업체명: 주식회사 대한공조기특판
#    - 대표자: 강대식
#
# 🏢 업체명: 케이랩
#    - 대표자: 강대식
#
# 🏢 업체명: 주경바스
#    - 대표자: 강대식
#
# 🏢 업체명: 주식회사 삼부조경
#    - 대표자: 강대식
#
# 🏢 업체명: (주)서우티이씨
#    - 대표자: 강대신
#
# 🏢 업체명: (주)드레곤에너지
#    - 대표자: 강대심
#
# 🏢 업체명: 디에스이엔씨 주식회사
#    - 대표자: 강대심
#
# 🏢 업체명: 주식회사 대양환경건설산업
#    - 대표자: 강대양
#
# 🏢 업체명: 디앤이구조엔지니어링 주식회사
#    - 대표자: 강대언
#
# 🏢 업체명: 대명조경주식회사
#    - 대표자: 강대업
#
# 🏢 업체명: 가담종합유통
#    - 대표자: 강대영
#
# 🏢 업체명: 삼안산업주식회사
#    - 대표자: 강대영
#
# 🏢 업체명: (주)디지베이스
#    - 대표자: 강대영
#
# 🏢 업체명: 주식회사 라인전기
#    - 대표자: 강대영
#
# 🏢 업체명: 주식회사 강대영장갑
#    - 대표자: 강대영
#
# 🏢 업체명: 삼도기술주식회사
#    - 대표자: 강대영
#
# 🏢 업체명: 드림건설주식회사
#    - 대표자: 강대용
#
# 🏢 업체명: 주식회사 서진산업
#    - 대표자: 강대용
#
# 🏢 업체명: 주식회사 건희이앤씨
#    - 대표자: 강대우
#
# 🏢 업체명: (주)레이테크
#    - 대표자: 강대욱
#
# 🏢 업체명: 주식회사 디에이
#    - 대표자: 강대욱
#
# 🏢 업체명: 씨에스씨인터내셔날 주식회사
#    - 대표자: 강대운
#
# 🏢 업체명: 주식회사 위더스
#    - 대표자: 강대웅
#
# 🏢 업체명: 주식회사 티월드
#    - 대표자: 강대웅
#
# 🏢 업체명: 주식회사 소윤건설
#    - 대표자: 강대웅
#
# 🏢 업체명: 금호전설(주)
#    - 대표자: 강대원
#
# 🏢 업체명: 두산건설주식회사
#    - 대표자: 강대원
#
# 🏢 업체명: 서안전력공사
#    - 대표자: 강대윤
#
# 🏢 업체명: 주식회사 삼원코어
#    - 대표자: 강대윤
#
# 🏢 업체명: 탐라씨앤씨
#    - 대표자: 강대은
#
# 🏢 업체명: 경기조경건설
#    - 대표자: 강대일
#
# 🏢 업체명: 북앤북
#    - 대표자: 강대준
#
# 🏢 업체명: 신흥이엔지
#    - 대표자: 강대준
#
# 🏢 업체명: 한  솔
#    - 대표자: 강대중
#
# 🏢 업체명: 대승상사
#    - 대표자: 강대중
#
# 🏢 업체명: 동서산업
#    - 대표자: 강대중
#
# 🏢 업체명: 대진산업개발(주)
#    - 대표자: 강대진
#
# 🏢 업체명: (주)해동전기공사
#    - 대표자: 강대진
#
# 🏢 업체명: 주식회사 비에스이앤씨
#    - 대표자: 강대찬
#
# 🏢 업체명: 주식회사 비에스에너지
#    - 대표자: 강대찬
#
# 🏢 업체명: (유)대진전기소방
#    - 대표자: 강대철
#
# 🏢 업체명: 로이스틸코리아 주식회사
#    - 대표자: 강대철
#
# 🏢 업체명: 송산건설(주)
#    - 대표자: 강대판
#
# 🏢 업체명: 삼영전설 주식회사
#    - 대표자: 강대한
#
# 🏢 업체명: 대운에스엔티
#    - 대표자: 강대한
#
# 🏢 업체명: (주)칠칠공사
#    - 대표자: 강대헌
#
# 🏢 업체명: 주식회사 우경이앤지
#    - 대표자: 강대헌
#
# 🏢 업체명: 와이제이건설산업 주식회사
#    - 대표자: 강대혁
#
# 🏢 업체명: 주식회사의흥건설
#    - 대표자: 강대현
#
# 🏢 업체명: 주식회사 유림종합건설
#    - 대표자: 강대현
#
# 🏢 업체명: 주식회사 토원티엔씨
#    - 대표자: 강대현
#
# 🏢 업체명: 대한산업
#    - 대표자: 강대현
#
# 🏢 업체명: 주식회사 디엠이앤씨
#    - 대표자: 강대현
#
# 🏢 업체명: 혁문당
#    - 대표자: 강대현
#
# 🏢 업체명: 주식회사 씨아이엘
#    - 대표자: 강대현
#
# 🏢 업체명: 주식회사 경호건설
#    - 대표자: 강대형
#
# 🏢 업체명: 주식회사  디에이치이엔지
#    - 대표자: 강대형
#
# 🏢 업체명: 주식회사 에스코
#    - 대표자: 강대호
#
# 🏢 업체명: 아토 건축사사무소
#    - 대표자: 강대호
#
# 🏢 업체명: 강건축사 사무소
#    - 대표자: 강대홍
#
# 🏢 업체명: 노블마인
#    - 대표자: 강대홍
#
# 🏢 업체명: 주식회사 위드종합건설
#    - 대표자: 강대환
#
# 🏢 업체명: 용흥건설 주식회사
#    - 대표자: 강대환
#
# 🏢 업체명: 주식회사 대성기술
#    - 대표자: 강대후
#
# 🏢 업체명: (주)세정코리아
#    - 대표자: 강대훈
#
# 🏢 업체명: (주)서경씨앤씨
#    - 대표자: 강대훈
#
# 🏢 업체명: 대성종합건설주식회사
#    - 대표자: 강대훈
#
# 🏢 업체명: 대원
#    - 대표자: 강대훈
#
# 🏢 업체명: 케이디 공구
#    - 대표자: 강대훈
#
# 🏢 업체명: 홍광건설(주)
#    - 대표자: 강대휘
#
# 🏢 업체명: 유한회사 성덕건설
#    - 대표자: 강대희
#
# 🏢 업체명: 주식회사대은건설
#    - 대표자: 강대희
#
# 🏢 업체명: (주)성은건설
#    - 대표자: 강대희
#
# 🏢 업체명: 일진건설 주식회사
#    - 대표자: 강덕광
#
# 🏢 업체명: 주식회사 덕성기업사
#    - 대표자: 강덕구
#
# 🏢 업체명: 충무환경＆세진엔지니어링
#    - 대표자: 강덕규
#
# 🏢 업체명: 주식회사목석원
#    - 대표자: 강덕근
#
# 🏢 업체명: 크리에이티브그래버스
#    - 대표자: 강덕기
#
# 🏢 업체명: 동아이엔지 주식회사
#    - 대표자: 강덕만
#
# 🏢 업체명: 미르건설주식회사
#    - 대표자: 강덕수
#
# 🏢 업체명: 유한회사 힘찬건설
#    - 대표자: 강덕숙
#
# 🏢 업체명: 경덕 주식회사
#    - 대표자: 강덕용
#
# 🏢 업체명: 목림종합건설 주식회사
#    - 대표자: 강덕원
#
# 🏢 업체명: 주식회사 쓰리원
#    - 대표자: 강덕원
#
# 🏢 업체명: 엘시아
#    - 대표자: 강덕원
#
# 🏢 업체명: 에이치에이건설 주식회사
#    - 대표자: 강덕자
#
# 🏢 업체명: 주식회사 한국유닉스경남
#    - 대표자: 강덕현
#
# 🏢 업체명: 주식회사 뉴퍼플
#    - 대표자: 강덕현
#
# 🏢 업체명: 국민하이테크
#    - 대표자: 강덕환
#
# 🏢 업체명: 휴스토리
#    - 대표자: 강덕훈
#
# 🏢 업체명: 대승전기(주)
#    - 대표자: 강덕희
#
# 🏢 업체명: 시안건축사사무소
#    - 대표자: 강덕희
#
# 🏢 업체명: (주)끌림이앤씨
#    - 대표자: 강도경
#
# 🏢 업체명: 주식회사 기산엔지니어링
#    - 대표자: 강도묵
#
# 🏢 업체명: 대신산업
#    - 대표자: 강도숙
#
# 🏢 업체명: (주)삼손단열
#    - 대표자: 강도영
#
# 🏢 업체명: 주식회사 훼미리하우스산업개발
#    - 대표자: 강도영
#
# 🏢 업체명: 매일북부유통
#    - 대표자: 강도영
#
# 🏢 업체명: 아이지오메디（I．G．O MEDI）
#    - 대표자: 강도영
#
# 🏢 업체명: 티에이치테크
#    - 대표자: 강도완
#
# 🏢 업체명: 동경건설 주식회사
#    - 대표자: 강도원
#
# 🏢 업체명: 주식회사케이에스테크
#    - 대표자: 강도춘
#
# 🏢 업체명: 케이토건(주)
#    - 대표자: 강도혁
#
# 🏢 업체명: 주식회사 푸른산림
#    - 대표자: 강도현
#
# 🏢 업체명: 한국해양과학기술원
#    - 대표자: 강도형
#
# 🏢 업체명: 제이엔케이주식회사
#    - 대표자: 강도형
#
# 🏢 업체명: 주식회사 아이알
#    - 대표자: 강도홍
#
# 🏢 업체명: 주식회사 월천
#    - 대표자: 강도희
#
# 🏢 업체명: 주식회사 대흥엔지니어링
#    - 대표자: 강돈구
#
# 🏢 업체명: 에코피아(주)
#    - 대표자: 강돈원
#
# 🏢 업체명: 아세아광고사
#    - 대표자: 강동구
#
# 🏢 업체명: 동성엔지니어링주식회사
#    - 대표자: 강동구
#
# 🏢 업체명: 주식회사 큐텍이씨에스
#    - 대표자: 강동구
#
# 🏢 업체명: 도깨비소독방역
#    - 대표자: 강동구
#
# 🏢 업체명: 주식회사펨스서비스
#    - 대표자: 강동구
#
# 🏢 업체명: 영주조경(주)
#    - 대표자: 강동국
#
# 🏢 업체명: 대지종합건설 주식회사
#    - 대표자: 강동국
#
# 🏢 업체명: 주식회사 용주이엔씨
#    - 대표자: 강동권
#
# 🏢 업체명: 주식회사넷솔테크
#    - 대표자: 강동규
#
# 🏢 업체명: 주식회사 강인
#    - 대표자: 강동규
#
# 🏢 업체명: 성미컴퍼니
#    - 대표자: 강동균
#
# 🏢 업체명: 청호토건 주식회사
#    - 대표자: 강동근
#
# 🏢 업체명: (주)동방사이메드
#    - 대표자: 강동근
#
# 🏢 업체명: 주식회사 서우종합건설
#    - 대표자: 강동기
#
# 🏢 업체명: 대동과학
#    - 대표자: 강동길
#
# 🏢 업체명: 강영 주식회사
#    - 대표자: 강동길
#
# 🏢 업체명: 주식회사 금강건설
#    - 대표자: 강동남
#
# 🏢 업체명: 디엠컴퍼니
#    - 대표자: 강동만
#
# 🏢 업체명: 주식회사 에스피씨지에프에스
#    - 대표자: 강동만
#
# 🏢 업체명: 주식회사 새롬건설
#    - 대표자: 강동명
#
# 🏢 업체명: 동남건축사사무소
#    - 대표자: 강동민
#
# 🏢 업체명: 주식회사 대원소방
#    - 대표자: 강동삼
#
# 🏢 업체명: 주식회사 동광건설
#    - 대표자: 강동석
#
# 🏢 업체명: 유한회사 삼우건설
#    - 대표자: 강동선
#
# 🏢 업체명: (주)동해종합건설
#    - 대표자: 강동성
#
# 🏢 업체명: 세탁전문점향기
#    - 대표자: 강동성
#
# 🏢 업체명: 주식회사 부성이엔씨
#    - 대표자: 강동수
#
# 🏢 업체명: 주식회사 호겸건설
#    - 대표자: 강동수
#
# 🏢 업체명: 양강종합건설 주식회사
#    - 대표자: 강동수
#
# 🏢 업체명: 주식회사 3엠프론티어
#    - 대표자: 강동순
#
# 🏢 업체명: 남경엘엔씨(주)
#    - 대표자: 강동식
#
# 🏢 업체명: (주)케이케이건설
#    - 대표자: 강동식
#
# 🏢 업체명: 주식회사 디에스전기
#    - 대표자: 강동식
#
# 🏢 업체명: 산림이엔지 울림
#    - 대표자: 강동아
#
# 🏢 업체명: 흥원전기공사
#    - 대표자: 강동암
#
# 🏢 업체명: 주식회사 케이프로시스템
#    - 대표자: 강동애
#
# 🏢 업체명: 현경산업
#    - 대표자: 강동열
#
# 🏢 업체명: 주식회사 최강건설
#    - 대표자: 강동열
#
# 🏢 업체명: (주)세진기술개발
#    - 대표자: 강동영
#
# 🏢 업체명: 주식회사 청어람알앤씨건축사사무소
#    - 대표자: 강동영
#
# 🏢 업체명: 천일라사
#    - 대표자: 강동옥
#
# 🏢 업체명: 새론유통
#    - 대표자: 강동옥
#
# 🏢 업체명: (주)부경
#    - 대표자: 강동완
#
# 🏢 업체명: 스포츠마켓
#    - 대표자: 강동완
#
# 🏢 업체명: 푸른제주방역
#    - 대표자: 강동완
#
# 🏢 업체명: (주)아인건축인테리어
#    - 대표자: 강동우
#
# 🏢 업체명: 주식회사 아리
#    - 대표자: 강동우
#
# 🏢 업체명: 주식회사 삼영전력
#    - 대표자: 강동우
#
# 🏢 업체명: 주식회사 삼진
#    - 대표자: 강동우
#
# 🏢 업체명: 디엔
#    - 대표자: 강동우
#
# 🏢 업체명: 주식회사 현이건설
#    - 대표자: 강동우
#
# 🏢 업체명: 삼성로드
#    - 대표자: 강동우
#
# 🏢 업체명: 애드케이원 주식회사
#    - 대표자: 강동욱
#
# 🏢 업체명: 클컴퍼니
#    - 대표자: 강동욱
#
# 🏢 업체명: 인테그리티
#    - 대표자: 강동욱
#
# 🏢 업체명: 주식회사 혜성이엔디
#    - 대표자: 강동운
#
# 🏢 업체명: 주식회사 재이플랜트
#    - 대표자: 강동원
#
# 🏢 업체명: 주식회사 선민전설
#    - 대표자: 강동원
#
# 🏢 업체명: (주)대원주방뱅크
#    - 대표자: 강동원
#
# 🏢 업체명: 요다정보기술(주)
#    - 대표자: 강동원
#
# 🏢 업체명: 유한회사 행복건설
#    - 대표자: 강동원
#
# 🏢 업체명: 효재산업
#    - 대표자: 강동원
#
# 🏢 업체명: 향진( 向進)
#    - 대표자: 강동원
#
# 🏢 업체명: 주식회사 서민갑부
#    - 대표자: 강동원
#
# 🏢 업체명: 유니유통
#    - 대표자: 강동윤
#
# 🏢 업체명: 에이치에스건설주식회사
#    - 대표자: 강동율
#
# 🏢 업체명: 키데아랩
#    - 대표자: 강동은
#
# 🏢 업체명: 올라운드주식회사
#    - 대표자: 강동은
#
# 🏢 업체명: 한국무선
#    - 대표자: 강동의
#
# 🏢 업체명: 토이월드
#    - 대표자: 강동의
#
# 🏢 업체명: 닛시
#    - 대표자: 강동인
#
# 🏢 업체명: 주식회사 대곡건설
#    - 대표자: 강동주
#
# 🏢 업체명: (주)조은 엔터프라이즈
#    - 대표자: 강동주
#
# 🏢 업체명: 주식회사 대곡조경
#    - 대표자: 강동주
#
# 🏢 업체명: 다인텍
#    - 대표자: 강동주
#
# 🏢 업체명: 사가랴
#    - 대표자: 강동주
#
# 🏢 업체명: 주식회사 케이디제이
#    - 대표자: 강동주
#
# 🏢 업체명: 신광산업
#    - 대표자: 강동주
#
# 🏢 업체명: 부자조경 주식회사
#    - 대표자: 강동준
#
# 🏢 업체명: 주식회사 엘케이월드
#    - 대표자: 강동중
#
# 🏢 업체명: 주식회사인정보기술
#    - 대표자: 강동진
#
# 🏢 업체명: 아델인
#    - 대표자: 강동진
#
# 🏢 업체명: (주)미가온푸드
#    - 대표자: 강동진
#
# 🏢 업체명: (주)에이치디건설
#    - 대표자: 강동진
#
# 🏢 업체명: 주식회사동진엘이디산업
#    - 대표자: 강동진
#
# 🏢 업체명: 주식회사 명신이앤씨
#    - 대표자: 강동철
#
# 🏢 업체명: 주식회사 동주
#    - 대표자: 강동철
#
# 🏢 업체명: 주식회사 아이씨티솔루션스
#    - 대표자: 강동철
#
# 🏢 업체명: 주식회사 미래에너지
#    - 대표자: 강동춘
#
# 🏢 업체명: 대곡상사
#    - 대표자: 강동출
#
# 🏢 업체명: 주식회사 한창테크
#    - 대표자: 강동필
#
# 🏢 업체명: 주식회사 한창하이텍
#    - 대표자: 강동필
#
# 🏢 업체명: 주식회사 씨앤에스
#    - 대표자: 강동한
#
# 🏢 업체명: 원포유(oneforyou)
#    - 대표자: 강동한
#
# 🏢 업체명: (주)해피고속관광
#    - 대표자: 강동헌
#
# 🏢 업체명: 제주정보통신
#    - 대표자: 강동현
#
# 🏢 업체명: 디에이치전력
#    - 대표자: 강동현
#
# 🏢 업체명: 주식회사 티케이랩
#    - 대표자: 강동현
#
# 🏢 업체명: 디에이치전력주식회사
#    - 대표자: 강동현
#
# 🏢 업체명: 씨티건설(주)
#    - 대표자: 강동호
#
# 🏢 업체명: (주) 에스이티
#    - 대표자: 강동호
#
# 🏢 업체명: 아이본건설 주식회사
#    - 대표자: 강동호
#
# 🏢 업체명: 주식회사 동호아이엔지
#    - 대표자: 강동호
#
# 🏢 업체명: 명신관광 주식회사
#    - 대표자: 강동호
#
# 🏢 업체명: 케이원 일렉트릭
#    - 대표자: 강동호
#
# 🏢 업체명: 주식회사 신태양전력
#    - 대표자: 강동호
#
# 🏢 업체명: (주)두꺼비인테리어디자인
#    - 대표자: 강동호
#
# 🏢 업체명: 건축사사무소 토마
#    - 대표자: 강동호
#
# 🏢 업체명: 주식회사 거평
#    - 대표자: 강동호
#
# 🏢 업체명: 주식회사 인덕소방
#    - 대표자: 강동화
#
# 🏢 업체명: 동화나라넷
#    - 대표자: 강동화
#
# 🏢 업체명: 주식회사 인덕전기소방
#    - 대표자: 강동화
#
# 🏢 업체명: (주)대화이엔지
#    - 대표자: 강동화
#
# 🏢 업체명: 누리조경 주식회사
#    - 대표자: 강동환
#
# 🏢 업체명: 주식회사 나라건설
#    - 대표자: 강동환
#
# 🏢 업체명: 주식회사 장인전문건설
#    - 대표자: 강동효
#
# 🏢 업체명: (주) 아라
#    - 대표자: 강동훈
#
# 🏢 업체명: 수목토건설(주)
#    - 대표자: 강동훈
#
# 🏢 업체명: 신양아이엔지건설(주)
#    - 대표자: 강동훈
#
# 🏢 업체명: 강동소방
#    - 대표자: 강동훈
#
# 🏢 업체명: 깔끔이청소나라 & 신화토탈케어
#    - 대표자: 강동훈
#
# 🏢 업체명: 스마트보리
#    - 대표자: 강동훈
#
# 🏢 업체명: 강동이엔지 주식회사
#    - 대표자: 강동훈
#
# 🏢 업체명: (주)대산전기공사
#    - 대표자: 강동희
#
# 🏢 업체명: DH팩토리
#    - 대표자: 강동희
#
# 🏢 업체명: 돌핀크린
#    - 대표자: 강동희
#
# 🏢 업체명: 지온글로벌
#    - 대표자: 강동희
#
# 🏢 업체명: 서원테크
#    - 대표자: 강두리
#
# 🏢 업체명: 주식회사 보보건설
#    - 대표자: 강두선
#
# 🏢 업체명: (주)에바다엘티
#    - 대표자: 강두승
#
# 🏢 업체명: 헤릭스코리아 주식회사
#    - 대표자: 강두식
#
# 🏢 업체명: 유한회사 보광이엔씨
#    - 대표자: 강두업
#
# 🏢 업체명: 주식회사 에테르스튜디오
#    - 대표자: 강두엽
#
# 🏢 업체명: 병산종합건설(주)
#    - 대표자: 강두영
#
# 🏢 업체명: 미창건설(주)
#    - 대표자: 강두영
#
# 🏢 업체명: (주)태우이엠씨
#    - 대표자: 강두용
#
# 🏢 업체명: (유)대영전력
#    - 대표자: 강두원
#
# 🏢 업체명: 도우종합건설(주)
#    - 대표자: 강두원
#
# 🏢 업체명: 주식회사 이십일스토어
#    - 대표자: 강두원
#
# 🏢 업체명: 주식회사 탑클리닝
#    - 대표자: 강두원
#
# 🏢 업체명: 금성개발주식회사
#    - 대표자: 강두이
#
# 🏢 업체명: (주)스팀지니
#    - 대표자: 강두한
#
# 🏢 업체명: 주식회사 그린고속투어
#    - 대표자: 강두한
#
# 🏢 업체명: 에스지인터네셔널
#    - 대표자: 강두한
#
# 🏢 업체명: 주식회사기린종합건설
#    - 대표자: 강두혁
#
# 🏢 업체명: 바나다하우스
#    - 대표자: 강두혁
#
# 🏢 업체명: 주식회사 우리정보통신
#    - 대표자: 강두현
#
# 🏢 업체명: 주식회사 태봉도장건설
#    - 대표자: 강둘영
#
# 🏢 업체명: 동인워터솔루션(주)
#    - 대표자: 강득남
#
# 🏢 업체명: (주)엔에이치엔다이퀘스트
#    - 대표자: 강락근
#
# 🏢 업체명: (주)세창건설
#    - 대표자: 강란구
#
# 🏢 업체명: 삼보이엔지(주)
#    - 대표자: 강란수
#
# 🏢 업체명: 태강컴퍼니
#    - 대표자: 강란희
#
# 🏢 업체명: 주식회사 시티종합건설
#    - 대표자: 강래길
#
# 🏢 업체명: 부산경남우유협동조합
#    - 대표자: 강래수
#
# 🏢 업체명: 지수건설
#    - 대표자: 강래신
#
# 🏢 업체명: 대주건설산업(주)
#    - 대표자: 강래억
#
# 🏢 업체명: 주식회사 보림종합건설
#    - 대표자: 강래웅
#
# 🏢 업체명: (주)이레에너지테크
#    - 대표자: 강래원
#
# 🏢 업체명: 그린황토랜드 주식회사
#    - 대표자: 강래원
#
# 🏢 업체명: 에이뎀（Aidem）
#    - 대표자: 강래윤
#
# 🏢 업체명: 주식회사 웨이드
#    - 대표자: 강려원
#
# 🏢 업체명: 일루아디자인
#    - 대표자: 강류리
#
# 🏢 업체명: 아이에스테크
#    - 대표자: 강리원
#
# 🏢 업체명: 마린산업
#    - 대표자: 강리화
#
# 🏢 업체명: 리도러블
#    - 대표자: 강리화
#
# 🏢 업체명: 주식회사 청라푸르미
#    - 대표자: 강리화
#
# 🏢 업체명: 주식회사 엠케이산업
#    - 대표자: 강마리
#
# 🏢 업체명: 주식회사 시영산업
#    - 대표자: 강만구
#
# 🏢 업체명: 주식회사 이강하우징
#    - 대표자: 강만구
#
# 🏢 업체명: 팔공환경운수(주)
#    - 대표자: 강만규
#
# 🏢 업체명: 주식회사 예담건설
#    - 대표자: 강만근
#
# 🏢 업체명: 주식회사 우림테크
#    - 대표자: 강만수
#
# 🏢 업체명: 동양텔레콤주식회사
#    - 대표자: 강만준
#
# 🏢 업체명: (주)인터메드
#    - 대표자: 강만희
#
# 🏢 업체명: (주)진우디앤씨건설
#    - 대표자: 강말숙
#
# 🏢 업체명: (주)한성
#    - 대표자: 강말순
#
# 🏢 업체명: 창한푸드
#    - 대표자: 강말순
#
# 🏢 업체명: 주식회사 해동디앤씨
#    - 대표자: 강말자
#
# 🏢 업체명: 자연조경(주)
#    - 대표자: 강매봉
#
# 🏢 업체명: (주)신광엔지니어링
#    - 대표자: 강매선
#
# 🏢 업체명: (주)KJ엔지니어링
#    - 대표자: 강맹환
#
# 🏢 업체명: 더원건설산업 주식회사
#    - 대표자: 강면구
#
# 🏢 업체명: 주식회사 더비건설
#    - 대표자: 강면구
#
# 🏢 업체명: 보성전기산업(주)
#    - 대표자: 강명구
#
# 🏢 업체명: 더라인이앤씨(주)
#    - 대표자: 강명구
#
# 🏢 업체명: 빛샘전자(주)
#    - 대표자: 강명구
#
# 🏢 업체명: 파워전력플랜트
#    - 대표자: 강명구
#
# 🏢 업체명: 주식회사 파워전력플랜트
#    - 대표자: 강명구
#
# 🏢 업체명: 가모사회적 협동조합
#    - 대표자: 강명구
#
# 🏢 업체명: (주)일진전자산업
#    - 대표자: 강명구
#
# 🏢 업체명: (주)에이.텍한독
#    - 대표자: 강명국
#
# 🏢 업체명: (주)서린이엔씨
#    - 대표자: 강명규
#
# 🏢 업체명: 주식회사 씨에이치이엔씨
#    - 대표자: 강명규
#
# 🏢 업체명: 밝은별
#    - 대표자: 강명규
#
# 🏢 업체명: (주)에코이앤씨
#    - 대표자: 강명근
#
# 🏢 업체명: 주식회사 진보
#    - 대표자: 강명기
#
# 🏢 업체명: 신아
#    - 대표자: 강명기
#
# 🏢 업체명: 주식회사 호남전기
#    - 대표자: 강명기
#
# 🏢 업체명: 두리유통
#    - 대표자: 강명난
#
# 🏢 업체명: 주식회사 우강건설
#    - 대표자: 강명남
#
# 🏢 업체명: 청림건설 주식회사
#    - 대표자: 강명남
#
# 🏢 업체명: (주)대성휀스개발
#    - 대표자: 강명덕
#
# 🏢 업체명: 명성
#    - 대표자: 강명란
#
# 🏢 업체명: 마루임업 주식회사
#    - 대표자: 강명렬
#
# 🏢 업체명: 나라기전
#    - 대표자: 강명묵
#
# 🏢 업체명: 클라젠
#    - 대표자: 강명산
#
# 🏢 업체명: 주식회사 신전사
#    - 대표자: 강명석
#
# 🏢 업체명: (주)승보이엔씨
#    - 대표자: 강명석
#
# 🏢 업체명: 주식회사 유성엠앤에스
#    - 대표자: 강명석
#
# 🏢 업체명: 도겸건설 주식회사
#    - 대표자: 강명석
#
# 🏢 업체명: 도움시스템
#    - 대표자: 강명석
#
# 🏢 업체명: (주)지앤비이앤씨
#    - 대표자: 강명선
#
# 🏢 업체명: 주식회사제주이레조경
#    - 대표자: 강명선
#
# 🏢 업체명: 한국표준협회
#    - 대표자: 강명수
#
# 🏢 업체명: 주식회사 코드에이
#    - 대표자: 강명수
#
# 🏢 업체명: 유덕토건(주)
#    - 대표자: 강명수
#
# 🏢 업체명: 대한이엔지
#    - 대표자: 강명수
#
# 🏢 업체명: 한국표준협회 KSA가산디지털센터
#    - 대표자: 강명수
#
# 🏢 업체명: 만호
#    - 대표자: 강명수
#
# 🏢 업체명: 세종솔루텍 주식회사
#    - 대표자: 강명수
#
# 🏢 업체명: 주식회사 명윤건설
#    - 대표자: 강명숙
#
# 🏢 업체명: 주식회사 은천
#    - 대표자: 강명숙
#
# 🏢 업체명: 주식회사 파로스
#    - 대표자: 강명숙
#
# 🏢 업체명: 정상문화재보존
#    - 대표자: 강명숙
#
# 🏢 업체명: (주)대경이엔에스플러스
#    - 대표자: 강명숙
#
# 🏢 업체명: 주식회사 대경이엔에스플러스
#    - 대표자: 강명숙
#
# 🏢 업체명: 주식회사 금산건설
#    - 대표자: 강명순
#
# 🏢 업체명: 수림건설 주식회사
#    - 대표자: 강명순
#
# 🏢 업체명: 연디자인，삼성사
#    - 대표자: 강명순
#
# 🏢 업체명: (유)대현기업
#    - 대표자: 강명식
#
# 🏢 업체명: 이하우징코리아(주)
#    - 대표자: 강명식
#
# 🏢 업체명: 공영씨엔이(주)
#    - 대표자: 강명식
#
# 🏢 업체명: 대명종합상사
#    - 대표자: 강명식
#
# 🏢 업체명: 주식회사 대현기업
#    - 대표자: 강명식
#
# 🏢 업체명: 핸드메이드 초대점
#    - 대표자: 강명신
#
# 🏢 업체명: 명신
#    - 대표자: 강명신
#
# 🏢 업체명: 유한회사 창비
#    - 대표자: 강명심
#
# 🏢 업체명: 주식회사 석보전력
#    - 대표자: 강명열
#
# 🏢 업체명: 보국이엔지
#    - 대표자: 강명영
#
# 🏢 업체명: (주)명성이엔지
#    - 대표자: 강명옥
#
# 🏢 업체명: 정명건설 주식회사
#    - 대표자: 강명우
#
# 🏢 업체명: (주)새론건설
#    - 대표자: 강명원
#
# 🏢 업체명: (주)견준씨에스
#    - 대표자: 강명원
#
# 🏢 업체명: 주식회사 아이원
#    - 대표자: 강명원
#
# 🏢 업체명: 주식회사 대성기업
#    - 대표자: 강명인
#
# 🏢 업체명: 주식회사 동북임업
#    - 대표자: 강명자
#
# 🏢 업체명: 대지종합개발 (주)
#    - 대표자: 강명자
#
# 🏢 업체명: (주)정명건설
#    - 대표자: 강명자
#
# 🏢 업체명: (주) 제이에스통신정보
#    - 대표자: 강명자
#
# 🏢 업체명: 주식회사 고원
#    - 대표자: 강명자
#
# 🏢 업체명: 유진전기
#    - 대표자: 강명조
#
# 🏢 업체명: 중앙조경
#    - 대표자: 강명주
#
# 🏢 업체명: 수부건설주식회사
#    - 대표자: 강명주
#
# 🏢 업체명: 명진상사
#    - 대표자: 강명주
#
# 🏢 업체명: 주식회사 배원조경
#    - 대표자: 강명주
#
# 🏢 업체명: 그린힐주식회사
#    - 대표자: 강명준
#
# 🏢 업체명: (주)네오네트윅스
#    - 대표자: 강명지
#
# 🏢 업체명: 앰라이프
#    - 대표자: 강명지
#
# 🏢 업체명: (주)아주디자인그룹
#    - 대표자: 강명진
#
# 🏢 업체명: 유한회사 명진종합소방
#    - 대표자: 강명진
#
# 🏢 업체명: 주식회사 아주건설
#    - 대표자: 강명진
#
# 🏢 업체명: 주식회사 제이케이산업
#    - 대표자: 강명진
#
# 🏢 업체명: 우원산업개발주식회사
#    - 대표자: 강명진
#
# 🏢 업체명: 엠팩토리
#    - 대표자: 강명진
#
# 🏢 업체명: 엠제이유통
#    - 대표자: 강명진
#
# 🏢 업체명: 주식회사이에스
#    - 대표자: 강명철
#
# 🏢 업체명: 우건산업개발 주식회사
#    - 대표자: 강명철
#
# 🏢 업체명: 명진전기건설주식회사
#    - 대표자: 강명호
#
# 🏢 업체명: 주식회사 창조인테리어
#    - 대표자: 강명호
#
# 🏢 업체명: (주)예찬도장기업
#    - 대표자: 강명호
#
# 🏢 업체명: 주식회사 다원
#    - 대표자: 강명호
#
# 🏢 업체명: 주식회사 동화일렉트릭
#    - 대표자: 강명호
#
# 🏢 업체명: 케이인시스트
#    - 대표자: 강명호
#
# 🏢 업체명: 소서민
#    - 대표자: 강명호
#
# 🏢 업체명: 주식회사보성건설
#    - 대표자: 강명화
#
# 🏢 업체명: 햇살크리닝
#    - 대표자: 강명화
#
# 🏢 업체명: 엠에이치컴퍼니
#    - 대표자: 강명화
#
# 🏢 업체명: 신나라
#    - 대표자: 강명화
#
# 🏢 업체명: 주식회사 윈미디텍
#    - 대표자: 강명환
#
# 🏢 업체명: 주식회사 유엔에이엔지니어링
#    - 대표자: 강명훈
#
# 🏢 업체명: 다원엠테크 주식회사
#    - 대표자: 강명훈
#
# 🏢 업체명: 유한회사 재연건설
#    - 대표자: 강명훈
#
# 🏢 업체명: 리즈텍
#    - 대표자: 강명훈
#
# 🏢 업체명: (유)황강종합건설
#    - 대표자: 강명희
#
# 🏢 업체명: 대승기전유한회사
#    - 대표자: 강명희
#
# 🏢 업체명: 에이치시스템 주식회사
#    - 대표자: 강명희
#
# 🏢 업체명: 주식회사 성영전설
#    - 대표자: 강명희
#
# 🏢 업체명: 주식회사 영신조경개발
#    - 대표자: 강명희
#
# 🏢 업체명: 주식회사 자람
#    - 대표자: 강명희
#
# 🏢 업체명: 미래환경
#    - 대표자: 강모준
#
# 🏢 업체명: 모현
#    - 대표자: 강모현
#
# 🏢 업체명: 유한회사 에스엠건설
#    - 대표자: 강몽주
#
# 🏢 업체명: 주식회사 제이와이이
#    - 대표자: 강묘순
#
# 🏢 업체명: 주식회사 가재원
#    - 대표자: 강무선
#
# 🏢 업체명: (주)알앤디테크
#    - 대표자: 강무성
#
# 🏢 업체명: 대신종합건설 주식회사
#    - 대표자: 강무용
#
# 🏢 업체명: 오엔 건축사사무소
#    - 대표자: 강무현
#
# 🏢 업체명: 동일건설 주식회사
#    - 대표자: 강묵태
#
# 🏢 업체명: 주식회사 더포림
#    - 대표자: 강문경
#
# 🏢 업체명: 주식회사 지역재생연구소
#    - 대표자: 강문구
#
# 🏢 업체명: 주식회사 태창임업개발
#    - 대표자: 강문권
#
# 🏢 업체명: 주식회사 한울조경
#    - 대표자: 강문권
#
# 🏢 업체명: 서연환경개발 주식회사
#    - 대표자: 강문규
#
# 🏢 업체명: 한주이엔씨 주식회사
#    - 대표자: 강문기
#
# 🏢 업체명: 조양토건주식회사
#    - 대표자: 강문기
#
# 🏢 업체명: 문경종합상사
#    - 대표자: 강문기
#
# 🏢 업체명: 문경상사
#    - 대표자: 강문기
#
# 🏢 업체명: 와이앤비사이언스 주식회사
#    - 대표자: 강문대
#
# 🏢 업체명: 하이지니컴퍼니
#    - 대표자: 강문보
#
# 🏢 업체명: (주)케이엠비건설
#    - 대표자: 강문빈
#
# 🏢 업체명: (주)보템
#    - 대표자: 강문석
#
# 🏢 업체명: 오피스넥스(의정부점)
#    - 대표자: 강문선
#
# 🏢 업체명: 소석건축사사무소
#    - 대표자: 강문선
#
# 🏢 업체명: 태영이앤씨 주식회사
#    - 대표자: 강문선
#
# 🏢 업체명: 주식회사 백년종합건설
#    - 대표자: 강문성
#
# 🏢 업체명: 주식회사 쿱에코하우징
#    - 대표자: 강문성
#
# 🏢 업체명: 주식회사 고림조경건설
#    - 대표자: 강문성
#
# 🏢 업체명: 유한회사 가람건설
#    - 대표자: 강문수
#
# 🏢 업체명: (주)에스에이치조경
#    - 대표자: 강문수
#
# 🏢 업체명: 주식회사연준종합건설
#    - 대표자: 강문수
#
# 🏢 업체명: 주식회사 에스제이건설
#    - 대표자: 강문수
#
# 🏢 업체명: 백마종합건설(주)
#    - 대표자: 강문수
#
# 🏢 업체명: 유한회사 가람산업
#    - 대표자: 강문수
#
# 🏢 업체명: 디아이케이 주식회사
#    - 대표자: 강문수
#
# 🏢 업체명: 주식회사 엠에스
#    - 대표자: 강문승
#
# 🏢 업체명: (주)한빛파워텍
#    - 대표자: 강문식
#
# 🏢 업체명: (주)파루
#    - 대표자: 강문식
#
# 🏢 업체명: 주식회사 디자인쉬엔비(Design Shenb Inc.)
#    - 대표자: 강문식
#
# 🏢 업체명: 다움건축사사무소
#    - 대표자: 강문식
#
# 🏢 업체명: 로드톡 주식회사
#    - 대표자: 강문식
#
# 🏢 업체명: 주식회사 백건
#    - 대표자: 강문신
#
# 🏢 업체명: 주식회사 금오기술
#    - 대표자: 강문자
#
# 🏢 업체명: 삼보건설 주식회사
#    - 대표자: 강문정
#
# 🏢 업체명: 문정건설
#    - 대표자: 강문정
#
# 🏢 업체명: 보성이엔씨 주식회사
#    - 대표자: 강문정
#
# 🏢 업체명: 주식회사 제이앤에스엔지니어링
#    - 대표자: 강문준
#
# 🏢 업체명: 주식회사 대수건설
#    - 대표자: 강문중
#
# 🏢 업체명: 주식회사 대영전설
#    - 대표자: 강문창
#
# 🏢 업체명: 광진건축사사무소
#    - 대표자: 강문철
#
# 🏢 업체명: 주식회사 지오건축사사무소
#    - 대표자: 강문철
#
# 🏢 업체명: (주)대성소방
#    - 대표자: 강문철
#
# 🏢 업체명: 삼진산업(주)
#    - 대표자: 강문혁
#
# 🏢 업체명: 케이팩토리
#    - 대표자: 강문형
#
# 🏢 업체명: 신안기업
#    - 대표자: 강문호
#
# 🏢 업체명: 주식회사 대운전력
#    - 대표자: 강문호
#
# 🏢 업체명: 주식회사 나라건재
#    - 대표자: 강문호
#
# 🏢 업체명: 제이에스무역
#    - 대표자: 강문호
#
# 🏢 업체명: 티엔정보기술(주)
#    - 대표자: 강문화
#
# 🏢 업체명: 디자인은송 유한회사
#    - 대표자: 강문희
#
# 🏢 업체명: 주식회사신승
#    - 대표자: 강문희
#
# 🏢 업체명: 주식회사 거성종합건설
#    - 대표자: 강문희
#
# 🏢 업체명: 주식회사 미지숲
#    - 대표자: 강문희
#
# 🏢 업체명: 알이즈웰
#    - 대표자: 강문희
#
# 🏢 업체명: 주식회사 화우리종합건설
#    - 대표자: 강미
#
# 🏢 업체명: 주식회사 휘강건설
#    - 대표자: 강미
#
# 🏢 업체명: 주식회사 이레전기
#    - 대표자: 강미경
#
# 🏢 업체명: 서산메디칼
#    - 대표자: 강미경
#
# 🏢 업체명: 천지건설  주식회사
#    - 대표자: 강미경
#
# 🏢 업체명: 주식회사 더존디자인조명
#    - 대표자: 강미경
#
# 🏢 업체명: 대근전력
#    - 대표자: 강미경
#
# 🏢 업체명: 미산조경 주식회사
#    - 대표자: 강미경
#
# 🏢 업체명: 영환유통
#    - 대표자: 강미경
#
# 🏢 업체명: 주식회사제로텍
#    - 대표자: 강미경
#
# 🏢 업체명: 주식회사 이송
#    - 대표자: 강미경
#
# 🏢 업체명: 지수금속
#    - 대표자: 강미경
#
# 🏢 업체명: 가온건설산업
#    - 대표자: 강미라
#
# 🏢 업체명: 주식회사 예담하우징건설
#    - 대표자: 강미라
#
# 🏢 업체명: 신성클린
#    - 대표자: 강미란
#
# 🏢 업체명: 달빛사무소
#    - 대표자: 강미란
#
# 🏢 업체명: 란커넥션
#    - 대표자: 강미란
#
# 🏢 업체명: (주)신울진건설
#    - 대표자: 강미령
#
# 🏢 업체명: 주식회사 태성정보통신
#    - 대표자: 강미령
#
# 🏢 업체명: 주식회사울진산업
#    - 대표자: 강미령
#
# 🏢 업체명: 가온메디
#    - 대표자: 강미리
#
# 🏢 업체명: 레이나블랑
#    - 대표자: 강미리
#
# 🏢 업체명: 주식회사 화성테크윈
#    - 대표자: 강미복
#
# 🏢 업체명: 우리공영주식회사
#    - 대표자: 강미석
#
# 🏢 업체명: 유한회사 정원건설
#    - 대표자: 강미선
#
# 🏢 업체명: 현진테크
#    - 대표자: 강미선
#
# 🏢 업체명: 주식회사 동양방수건설
#    - 대표자: 강미선
#
# 🏢 업체명: 따봉스대디
#    - 대표자: 강미선
#
# 🏢 업체명: 세원건설주식회사
#    - 대표자: 강미선
#
# 🏢 업체명: 주식회사 완승이앤씨
#    - 대표자: 강미선
#
# 🏢 업체명: 세아전기 주식회사
#    - 대표자: 강미성
#
# 🏢 업체명: 거구산업개발(주)
#    - 대표자: 강미숙
#
# 🏢 업체명: 삼환포장건설
#    - 대표자: 강미숙
#
# 🏢 업체명: (주)진산기업
#    - 대표자: 강미숙
#
# 🏢 업체명: 주식회사 후광종합건설
#    - 대표자: 강미숙
#
# 🏢 업체명: (주)영신엔지니어링
#    - 대표자: 강미숙
#
# 🏢 업체명: 우민건설 주식회사
#    - 대표자: 강미숙
#
# 🏢 업체명: 주식회사 중앙건축사사무소
#    - 대표자: 강미숙
#
# 🏢 업체명: 찬솔그린텍
#    - 대표자: 강미숙
#
# 🏢 업체명: 플러스
#    - 대표자: 강미숙
#
# 🏢 업체명: 건우상사
#    - 대표자: 강미숙
#
# 🏢 업체명: 유나상사
#    - 대표자: 강미숙
#
# 🏢 업체명: 보산환경 주식회사
#    - 대표자: 강미숙
#
# 🏢 업체명: 가르다디자인 주식회사
#    - 대표자: 강미숙
#
# 🏢 업체명: (주)우림조경
#    - 대표자: 강미순
#
# 🏢 업체명: 주식회사 신한네오텍
#    - 대표자: 강미순
#
# 🏢 업체명: 디종인테리어
#    - 대표자: 강미순
#
# 🏢 업체명: 주식회사 다은전기
#    - 대표자: 강미순
#
# 🏢 업체명: 주식회사 다은에너지
#    - 대표자: 강미순
#
# 🏢 업체명: 페이스메디칼
#    - 대표자: 강미애
#
# 🏢 업체명: (주) 미성테크
#    - 대표자: 강미애
#
# 🏢 업체명: 주식회사 윤승건설
#    - 대표자: 강미애
#
# 🏢 업체명: 슈크림미학
#    - 대표자: 강미애
#
# 🏢 업체명: 수지나라
#    - 대표자: 강미애
#
# 🏢 업체명: 주식회사아더건축사사무소
#    - 대표자: 강미애
#
# 🏢 업체명: 대주정보산업(주)
#    - 대표자: 강미연
#
# 🏢 업체명: 아라
#    - 대표자: 강미연
#
# 🏢 업체명: 신세계
#    - 대표자: 강미열
#
# 🏢 업체명: 미영사
#    - 대표자: 강미영
#
# 🏢 업체명: 인성전기 주식회사
#    - 대표자: 강미영
#
# 🏢 업체명: 유한회사 일오고속관광
#    - 대표자: 강미영
#
# 🏢 업체명: 풀숲조경
#    - 대표자: 강미영
#
# 🏢 업체명: 주식회사 백두건설
#    - 대표자: 강미영
#
# 🏢 업체명: 서연환경개발 주식회사
#    - 대표자: 강미영
#
# 🏢 업체명: 유경이엔씨주식회사
#    - 대표자: 강미영
#
# 🏢 업체명: 앤123
#    - 대표자: 강미영
#
# 🏢 업체명: 주식회사 한통
#    - 대표자: 강미영
#
# 🏢 업체명: 금빛
#    - 대표자: 강미영
#
# 🏢 업체명: 골드비엠씨 주식회사
#    - 대표자: 강미옥
#
# 🏢 업체명: 유한회사 미소건설
#    - 대표자: 강미옥
#
# 🏢 업체명: 주식회사이지이엔지
#    - 대표자: 강미옥
#
# 🏢 업체명: 주식회사 펄하우징
#    - 대표자: 강미옥
#
# 🏢 업체명: 풍기건설주식회사
#    - 대표자: 강미월
#
# 🏢 업체명: 미인물류
#    - 대표자: 강미인
#
# 🏢 업체명: 나이스메디텍
#    - 대표자: 강미자
#
# 🏢 업체명: 주식회사 경창엔지니어링
#    - 대표자: 강미자
#
# 🏢 업체명: 주식회사 태경엔지니어링
#    - 대표자: 강미정
#
# 🏢 업체명: (주)윤지건설
#    - 대표자: 강미정
#
# 🏢 업체명: (주)유진정보기술
#    - 대표자: 강미정
#
# 🏢 업체명: 다인건설 주식회사
#    - 대표자: 강미정
#
# 🏢 업체명: 주식회사 울트라전기
#    - 대표자: 강미정
#
# 🏢 업체명: 해인컴퍼니
#    - 대표자: 강미정
#
# 🏢 업체명: 강미정연합내과의원
#    - 대표자: 강미정
#
# 🏢 업체명: 가디록 주식회사
#    - 대표자: 강미정
#
# 🏢 업체명: 호산씨앤씨 주식회사
#    - 대표자: 강미정
#
# 🏢 업체명: 천무건설주식회사
#    - 대표자: 강미정
#
# 🏢 업체명: 주식회사대담하우징
#    - 대표자: 강미정
#
# 🏢 업체명: 주식회사 진투어
#    - 대표자: 강미정
#
# 🏢 업체명: 주식회사 헤라넷
#    - 대표자: 강미정
#
# 🏢 업체명: (유)엔젤시스템
#    - 대표자: 강미진
#
# 🏢 업체명: (주)상상
#    - 대표자: 강미진
#
# 🏢 업체명: 주식회사 대신하우징
#    - 대표자: 강미진
#
# 🏢 업체명: 한솔건설(주)
#    - 대표자: 강미향
#
# 🏢 업체명: 주식회사 대선이엔씨
#    - 대표자: 강미향
#
# 🏢 업체명: 건축사사무소 예감
#    - 대표자: 강미현
#
# 🏢 업체명: 주식회사 태영텔레콤
#    - 대표자: 강미현
#
# 🏢 업체명: 세림산업개발 주식회사
#    - 대표자: 강미현
#
# 🏢 업체명: 서하건설 주식회사
#    - 대표자: 강미현
#
# 🏢 업체명: 리브뉴
#    - 대표자: 강미현
#
# 🏢 업체명: (주)에이포환경
#    - 대표자: 강미현
#
# 🏢 업체명: 주식회사 창용
#    - 대표자: 강미혜
#
# 🏢 업체명: 주식회사 포인트정보
#    - 대표자: 강미혜
#
# 🏢 업체명: 주식회사 건양전력
#    - 대표자: 강미화
#
# 🏢 업체명: 아산조경개발 주식회사
#    - 대표자: 강미화
#
# 🏢 업체명: 홍원종합건설주식회사
#    - 대표자: 강미화
#
# 🏢 업체명: 이아이테크
#    - 대표자: 강미화
#
# 🏢 업체명: 주식회사 범영테크
#    - 대표자: 강미희
#
# 🏢 업체명: (주)태현디자인
#    - 대표자: 강미희
#
# 🏢 업체명: 주식회사 원솔루션
#    - 대표자: 강민
#
# 🏢 업체명: 금명건설(주)
#    - 대표자: 강민
#
# 🏢 업체명: (주)하이테크주택
#    - 대표자: 강민경
#
# 🏢 업체명: 주식회사 더블유에스
#    - 대표자: 강민경
#
# 🏢 업체명: 건희개발 주식회사
#    - 대표자: 강민경
#
# 🏢 업체명: 사랑 주식회사
#    - 대표자: 강민경
#
# 🏢 업체명: 주식회사 회광전기
#    - 대표자: 강민경
#
# 🏢 업체명: 후하의보물창고
#    - 대표자: 강민경
#
# 🏢 업체명: 주식회사 금록조경
#    - 대표자: 강민경
#
# 🏢 업체명: (주)세화전력
#    - 대표자: 강민경
#
# 🏢 업체명: MGS미공사
#    - 대표자: 강민곤
#
# 🏢 업체명: 주식회사 현대이엔지
#    - 대표자: 강민교
#
# 🏢 업체명: (주)세종산업가스
#    - 대표자: 강민구
#
# 🏢 업체명: 씨엠피엠건설(주)
#    - 대표자: 강민구
#
# 🏢 업체명: 근남정보기술 주식회사
#    - 대표자: 강민구
#
# 🏢 업체명: 클린연구소
#    - 대표자: 강민구
#
# 🏢 업체명: 은별전자
#    - 대표자: 강민구
#
# 🏢 업체명: 유한회사 디딤돌건설
#    - 대표자: 강민구
#
# 🏢 업체명: 브랜디
#    - 대표자: 강민구
#
# 🏢 업체명: 한방기능식품연구소
#    - 대표자: 강민구
#
# 🏢 업체명: 지엠건설 주식회사
#    - 대표자: 강민권
#
# 🏢 업체명: 알앤비텍주식회사
#    - 대표자: 강민권
#
# 🏢 업체명: 엔담 주식회사
#    - 대표자: 강민규
#
# 🏢 업체명: (주)가온건설
#    - 대표자: 강민규
#
# 🏢 업체명: 주식회사 와이앤제이이앤씨
#    - 대표자: 강민규
#
# 🏢 업체명: 서아유통
#    - 대표자: 강민규
#
# 🏢 업체명: (주)신광이엔지
#    - 대표자: 강민규
#
# 🏢 업체명: 주식회사 엠케이건설산업
#    - 대표자: 강민규
#
# 🏢 업체명: 호재건설 주식회사
#    - 대표자: 강민균
#
# 🏢 업체명: 케이탑기술사사무소주식회사
#    - 대표자: 강민기
#
# 🏢 업체명: 주식회사 이룸라이프
#    - 대표자: 강민서
#
# 🏢 업체명: 주식회사 신화
#    - 대표자: 강민서
#
# 🏢 업체명: 매력뿜뿜샵
#    - 대표자: 강민서
#
# 🏢 업체명: 석신건설주식회사
#    - 대표자: 강민석
#
# 🏢 업체명: 주식회사 윤진전기
#    - 대표자: 강민석
#
# 🏢 업체명: 주식회사보림종합건설
#    - 대표자: 강민석
#
# 🏢 업체명: 주식회사 가온씨앤에이
#    - 대표자: 강민석
#
# 🏢 업체명: 알리바바 상점
#    - 대표자: 강민석
#
# 🏢 업체명: 민석그룹
#    - 대표자: 강민석
#
# 🏢 업체명: 강민석
#    - 대표자: 강민석
#
# 🏢 업체명: 주식회사 서호건설
#    - 대표자: 강민성
#
# 🏢 업체명: 우림
#    - 대표자: 강민성
#
# 🏢 업체명: 창진종합건설주식회사
#    - 대표자: 강민성
#
# 🏢 업체명: 중앙운수3543
#    - 대표자: 강민성
#
# 🏢 업체명: 미라쏠
#    - 대표자: 강민성
#
# 🏢 업체명: 가재울명품(303-1185)공인중개사사무소
#    - 대표자: 강민성
#
# 🏢 업체명: 신성건축사사무소
#    - 대표자: 강민성
#
# 🏢 업체명: 이일산업 주식회사
#    - 대표자: 강민성
#
# 🏢 업체명: 그린산업개발 주식회사
#    - 대표자: 강민수
#
# 🏢 업체명: 에듀바비 서울 영등포지점
#    - 대표자: 강민수
#
# 🏢 업체명: 메이커스미디어
#    - 대표자: 강민수
#
# 🏢 업체명: 주식회사유림도서정보
#    - 대표자: 강민숙
#
# 🏢 업체명: 에어로 앤 마린
#    - 대표자: 강민숙
#
# 🏢 업체명: 대진건설
#    - 대표자: 강민순
#
# 🏢 업체명: (주)대진건설
#    - 대표자: 강민순
#
# 🏢 업체명: 주식회사 국방건업
#    - 대표자: 강민식
#
# 🏢 업체명: 민스타니
#    - 대표자: 강민아
#
# 🏢 업체명: (주)경동홀딩스
#    - 대표자: 강민아
#
# 🏢 업체명: 주식회사 피앤케이건설
#    - 대표자: 강민아
#
# 🏢 업체명: 주식회사 오엔조경
#    - 대표자: 강민아
#
# 🏢 업체명: 주식회사 가람건설
#    - 대표자: 강민아
#
# 🏢 업체명: 주식회사 한려산업
#    - 대표자: 강민영
#
# 🏢 업체명: 주식회사동아넷
#    - 대표자: 강민영
#
# 🏢 업체명: 민영상사
#    - 대표자: 강민영
#
# 🏢 업체명: 현영종합건설 주식회사
#    - 대표자: 강민영
#
# 🏢 업체명: 주식회사 해월
#    - 대표자: 강민오
#
# 🏢 업체명: 흥양종합건설 주식회사
#    - 대표자: 강민우
#
# 🏢 업체명: 해인임업주식회사
#    - 대표자: 강민우
#
# 🏢 업체명: (주)성진조경
#    - 대표자: 강민우
#
# 🏢 업체명: 포더유니버스
#    - 대표자: 강민우
#
# 🏢 업체명: 민우테크
#    - 대표자: 강민우
#
# 🏢 업체명: 주식회사 대윤엔지니어링
#    - 대표자: 강민우
#
# 🏢 업체명: 인동조경 주식회사
#    - 대표자: 강민자
#
# 🏢 업체명: 용천조경 주식회사
#    - 대표자: 강민자
#
# 🏢 업체명: 교림건설(주)
#    - 대표자: 강민재
#
# 🏢 업체명: 이지앤웰니스 주식회사
#    - 대표자: 강민재
#
# 🏢 업체명: 공공조달 강민재
#    - 대표자: 강민재
#
# 🏢 업체명: (주)그린프로젝트
#    - 대표자: 강민재
#
# 🏢 업체명: 삼호건설(주)
#    - 대표자: 강민정
#
# 🏢 업체명: 성원건설(주)
#    - 대표자: 강민정
#
# 🏢 업체명: 주식회사 해성씨앤에이
#    - 대표자: 강민정
#
# 🏢 업체명: 엔에이치산업주식회사
#    - 대표자: 강민정
#
# 🏢 업체명: 은모토건 주식회사
#    - 대표자: 강민정
#
# 🏢 업체명: 주식회사 스카이뷰
#    - 대표자: 강민정
#
# 🏢 업체명: 주식회사 랩디자인
#    - 대표자: 강민정
#
# 🏢 업체명: 신대양건설 주식회사
#    - 대표자: 강민정
#
# 🏢 업체명: 서호통상
#    - 대표자: 강민정
#
# 🏢 업체명: 달라리
#    - 대표자: 강민정
#
# 🏢 업체명: 씨에스
#    - 대표자: 강민정
#
# 🏢 업체명: 주식회사 바른숲
#    - 대표자: 강민정
#
# 🏢 업체명: 삼호건설  주식회사
#    - 대표자: 강민정
#
# 🏢 업체명: 유한회사 제이건설
#    - 대표자: 강민정
#
# 🏢 업체명: 주식회사 진흥종합건설
#    - 대표자: 강민정
#
# 🏢 업체명: 주식회사 이강
#    - 대표자: 강민정
#
# 🏢 업체명: 경기유통
#    - 대표자: 강민정
#
# 🏢 업체명: 우신환경건설 주식회사
#    - 대표자: 강민제
#
# 🏢 업체명: 합자회사 한보기업
#    - 대표자: 강민주
#
# 🏢 업체명: (주)종환경디자인연구소
#    - 대표자: 강민주
#
# 🏢 업체명: (주)천광밝은세상
#    - 대표자: 강민주
#
# 🏢 업체명: (주)아티즌디자인
#    - 대표자: 강민주
#
# 🏢 업체명: 유담종합건설 주식회사
#    - 대표자: 강민주
#
# 🏢 업체명: 뉴유탑 유한회사
#    - 대표자: 강민주
#
# 🏢 업체명: 유한회사 유창
#    - 대표자: 강민주
#
# 🏢 업체명: 알파논산점
#    - 대표자: 강민주
#
# 🏢 업체명: 주식회사 동아건설
#    - 대표자: 강민주
#
# 🏢 업체명: 엠제이컴퍼니
#    - 대표자: 강민주
#
# 🏢 업체명: 디아전력주식회사
#    - 대표자: 강민주
#
# 🏢 업체명: 주식회사 도원조경
#    - 대표자: 강민주
#
# 🏢 업체명: 이지산업
#    - 대표자: 강민주
#
# 🏢 업체명: 대한산업
#    - 대표자: 강민주
#
# 🏢 업체명: 이즈리얼
#    - 대표자: 강민주
#
# 🏢 업체명: 주식회사대호전기
#    - 대표자: 강민주
#
# 🏢 업체명: 코델리아
#    - 대표자: 강민주
#
# 🏢 업체명: 구평건설(주)
#    - 대표자: 강민준
#
# 🏢 업체명: (주)미르정보기술
#    - 대표자: 강민준
#
# 🏢 업체명: 주식회사 한스푸드
#    - 대표자: 강민준
#
# 🏢 업체명: 주식회사 한스푸드 강원지점
#    - 대표자: 강민준
#
# 🏢 업체명: (주)아름다운강산
#    - 대표자: 강민지
#
# 🏢 업체명: 푸른환경산업 주식회사
#    - 대표자: 강민지
#
# 🏢 업체명: (주)금강송
#    - 대표자: 강민지
#
# 🏢 업체명: 대성
#    - 대표자: 강민지
#
# 🏢 업체명: 버틀러하우스
#    - 대표자: 강민지
#
# 🏢 업체명: 주식회사 인지원
#    - 대표자: 강민지
#
# 🏢 업체명: 마라톤
#    - 대표자: 강민지
#
# 🏢 업체명: 비지비지
#    - 대표자: 강민지
#
# 🏢 업체명: 영주건설 주식회사
#    - 대표자: 강민진
#
# 🏢 업체명: 아이원
#    - 대표자: 강민철
#
# 🏢 업체명: 주식회사 썬앤케이건설
#    - 대표자: 강민철
#
# 🏢 업체명: 주식회사 에프비정보통신
#    - 대표자: 강민철
#
# 🏢 업체명: 주식회사 토우
#    - 대표자: 강민철
#
# 🏢 업체명: 한국데이터기술 주식회사
#    - 대표자: 강민철
#
# 🏢 업체명: 주식회사 티앤씨종합건설
#    - 대표자: 강민철
#
# 🏢 업체명: 밀리언웰스
#    - 대표자: 강민철
#
# 🏢 업체명: 세인건설산업 주식회사
#    - 대표자: 강민철
#
# 🏢 업체명: 가인종합건설 주식회사
#    - 대표자: 강민표
#
# 🏢 업체명: 주식회사 태화종합건설
#    - 대표자: 강민헌
#
# 🏢 업체명: 인왕산 호랭이
#    - 대표자: 강민혁
#
# 🏢 업체명: 주식회사 랩이앤이
#    - 대표자: 강민협
#
# 🏢 업체명: 파워기획
#    - 대표자: 강민형
#
# 🏢 업체명: 주식회사 남악건설
#    - 대표자: 강민호
#
# 🏢 업체명: (유)대산건설
#    - 대표자: 강민호
#
# 🏢 업체명: 스페이스클라우드건축사사무소
#    - 대표자: 강민호
#
# 🏢 업체명: 미래상사
#    - 대표자: 강민희
#
# 🏢 업체명: 유강정보
#    - 대표자: 강민희
#
# 🏢 업체명: 명성건설 주식회사
#    - 대표자: 강민희
#
# 🏢 업체명: 주식회사 시그널아이씨티
#    - 대표자: 강민희
#
# 🏢 업체명: 위너스
#    - 대표자: 강민희
#
# 🏢 업체명: 컴레인올샤인
#    - 대표자: 강민희
#
# 🏢 업체명: 주식회사디오텍
#    - 대표자: 강방식
#
# 🏢 업체명: 메종드메라
#    - 대표자: 강배식
#
# 🏢 업체명: 주식회사 천우건설
#    - 대표자: 강백선
#
# 🏢 업체명: 주식회사 백강
#    - 대표자: 강백선
#
# 🏢 업체명: 주식회사 삼호종합물류
#    - 대표자: 강백종
#
# 🏢 업체명: (합)마이크로닉정보통신
#    - 대표자: 강범규
#
# 🏢 업체명: 주식회사  비티건설
#    - 대표자: 강범규
#
# 🏢 업체명: 주식회사 마이크로닉
#    - 대표자: 강범규
#
# 🏢 업체명: 하늘종합건설주식회사
#    - 대표자: 강범대
#
# 🏢 업체명: 서진종합건설 주식회사
#    - 대표자: 강범서
#
# 🏢 업체명: 다한컴퍼니
#    - 대표자: 강범수
#
# 🏢 업체명: 종합건축사사무소한섬
#    - 대표자: 강범수
#
# 🏢 업체명: 프라임건설 주식회사
#    - 대표자: 강범식
#
# 🏢 업체명: 범건축사사무소
#    - 대표자: 강범식
#
# 🏢 업체명: (주)신원건설
#    - 대표자: 강범준
#
# 🏢 업체명: (주)한솔그린
#    - 대표자: 강병갑
#
# 🏢 업체명: 주식회사 그린월드
#    - 대표자: 강병계
#
# 🏢 업체명: (주)경원개발
#    - 대표자: 강병관
#
# 🏢 업체명: 유한회사 연기수도
#    - 대표자: 강병구
#
# 🏢 업체명: 주식회사 표준산업
#    - 대표자: 강병구
#
# 🏢 업체명: 주식회사 지연이앤씨
#    - 대표자: 강병구
#
# 🏢 업체명: 삼오건설 주식회사
#    - 대표자: 강병구
#
# 🏢 업체명: 한길정보기술
#    - 대표자: 강병국
#
# 🏢 업체명: (주)태우종합건설
#    - 대표자: 강병국
#
# 🏢 업체명: 기동종합건설주식회사
#    - 대표자: 강병국
#
# 🏢 업체명: 주식회사 에스피환경
#    - 대표자: 강병군
#
# 🏢 업체명: (주)앤종합건설
#    - 대표자: 강병규
#
# 🏢 업체명: 주식회사위즈케이엘
#    - 대표자: 강병규
#
# 🏢 업체명: 주식회사 가나산업에이
#    - 대표자: 강병규
#
# 🏢 업체명: (주)서청
#    - 대표자: 강병기
#
# 🏢 업체명: 주식회사 오렌지이앤씨
#    - 대표자: 강병길
#
# 🏢 업체명: 흥한주택종합건설 주식회사
#    - 대표자: 강병길
#
# 🏢 업체명: (주)성인토건
#    - 대표자: 강병길
#
# 🏢 업체명: 화천미래기업 주식회사
#    - 대표자: 강병남
#
# 🏢 업체명: 스토리컴퍼니
#    - 대표자: 강병도
#
# 🏢 업체명: 주식회사 유성쉬핑
#    - 대표자: 강병도
#
# 🏢 업체명: 강형
#    - 대표자: 강병록
#
# 🏢 업체명: 프로유비스 주식회사
#    - 대표자: 강병모
#
# 🏢 업체명: 경일바이오
#    - 대표자: 강병모
#
# 🏢 업체명: 주식회사 서광그린
#    - 대표자: 강병민
#
# 🏢 업체명: 백송
#    - 대표자: 강병민
#
# 🏢 업체명: 대한시멘트(주)
#    - 대표자: 강병복
#
# 🏢 업체명: 주식회사 전일이앤씨
#    - 대표자: 강병삼
#
# 🏢 업체명: 미래오피스쇼핑
#    - 대표자: 강병석
#
# 🏢 업체명: 주식회사제이탑건설
#    - 대표자: 강병선
#
# 🏢 업체명: 조은전력
#    - 대표자: 강병선
#
# 🏢 업체명: 씨에이치종합건설주식회사
#    - 대표자: 강병설
#
# ...
#    - 대표자: 김병환
#
# 🏢 업체명: 주식회사 백암중공업
#    - 대표자: 김병환
#
# 🏢 업체명: 재동상사
#    - 대표자: 김병환
#
# 🏢 업체명: 김병환건축사사무소
#    - 대표자: 김병환
#
# 🏢 업체명: (주) 성우종합건설
#    - 대표자: 김병후
#
# 🏢 업체명: 주식회사 에이치에스씨엠티
#    - 대표자: 김병훈
#
# 🏢 업체명: (주)신동전설
#    - 대표자: 김병훈
#
# 🏢 업체명: 주식회사 인프라이엔씨
#    - 대표자: 김병훈
#
# 🏢 업체명: 국보종합건설 주식회사
#    - 대표자: 김병훈
#
# 🏢 업체명: (주)에코에너지
#    - 대표자: 김병훈
#
# 🏢 업체명: 주식회사 훈시스템
#    - 대표자: 김병훈
#
# 🏢 업체명: 주식회사 대림방재
#    - 대표자: 김병훈
#
# 🏢 업체명: (주)웨이브엔텍
#    - 대표자: 김병훈
#
# 🏢 업체명: 주원종합목재
#    - 대표자: 김병훈
#
# 🏢 업체명: 엔플
#    - 대표자: 김병훈
#
# 🏢 업체명: 씨앤케이조경
#    - 대표자: 김병훈
#
# 🏢 업체명: 루에리상사
#    - 대표자: 김병훈
#
# 🏢 업체명: 주식회사 선명정보통신
#    - 대표자: 김병훈
#
# 🏢 업체명: 비에이치솔루션
#    - 대표자: 김병훈
#
# 🏢 업체명: 제이비 엔지니어링
#    - 대표자: 김병훈
#
# 🏢 업체명: 주식회사 비앤에프
#    - 대표자: 김병훈
#
# 🏢 업체명: 주식회사광안건설
#    - 대표자: 김병휘
#
# 🏢 업체명: 명보방수씨앤알 합자회사
#    - 대표자: 김병희
#
# 🏢 업체명: 경동나비엔동마산대리점
#    - 대표자: 김병희
#
# 🏢 업체명: 주식회사 현대이앤엘
#    - 대표자: 김병희
#
# 🏢 업체명: 씨티이엔지 주식회사
#    - 대표자: 김병희
#
# 🏢 업체명: 주식회사 가온텍
#    - 대표자: 김병희
#
# 🏢 업체명: 재단법인 한성문화재연구원
#    - 대표자: 김병희
#
# 🏢 업체명: 주식회사 좋은엔지니어링
#    - 대표자: 김병희
#
# 🏢 업체명: 주식회사 디지비캐피탈
#    - 대표자: 김병희
#
# 🏢 업체명: 수인조경 주식회사
#    - 대표자: 김병희
#
# 🏢 업체명: 공감도예 더희
#    - 대표자: 김병희
#
# 🏢 업체명: 삼성클라크지게차총판
#    - 대표자: 김병희
#
# 🏢 업체명: 희
#    - 대표자: 김병희
#
# 🏢 업체명: 드림빅드래곤
#    - 대표자: 김보건
#
# 🏢 업체명: 주식회사 광영건설
#    - 대표자: 김보겸
#
# 🏢 업체명: 주식회사 문보건설
#    - 대표자: 김보겸
#
# 🏢 업체명: 성보건설 주식회사
#    - 대표자: 김보겸
#
# 🏢 업체명: 주식회사 진성
#    - 대표자: 김보경
#
# 🏢 업체명: (주)세일기술공영
#    - 대표자: 김보경
#
# 🏢 업체명: 주안기업 주식회사
#    - 대표자: 김보경
#
# 🏢 업체명: 휘데스인터내셔날
#    - 대표자: 김보경
#
# 🏢 업체명: 유한회사 청송
#    - 대표자: 김보경
#
# 🏢 업체명: 신도유성사무기
#    - 대표자: 김보경
#
# 🏢 업체명: (주) 리더라이텍
#    - 대표자: 김보경
#
# 🏢 업체명: 주식회사 수목테크
#    - 대표자: 김보경
#
# 🏢 업체명: 주식회사 대신기업
#    - 대표자: 김보경
#
# 🏢 업체명: (주)에스엔티디자인건축
#    - 대표자: 김보경
#
# 🏢 업체명: 한진타올
#    - 대표자: 김보경
#
# 🏢 업체명: 주식회사 신일이엔시
#    - 대표자: 김보경
#
# 🏢 업체명: 주식회사 파이너
#    - 대표자: 김보경
#
# 🏢 업체명: 주식회사 터앤터
#    - 대표자: 김보경
#
# 🏢 업체명: 유한회사 백수정건설
#    - 대표자: 김보경
#
# 🏢 업체명: 주식회사 우인컴퍼니
#    - 대표자: 김보경
#
# 🏢 업체명: 주식회사태정기술
#    - 대표자: 김보경
#
# 🏢 업체명: 서경컴퍼니
#    - 대표자: 김보경
#
# 🏢 업체명: 성도종합건설 주식회사
#    - 대표자: 김보경
#
# 🏢 업체명: 공간이음주식회사
#    - 대표자: 김보경
#
# 🏢 업체명: 주식회사 연조경
#    - 대표자: 김보경
#
# 🏢 업체명: (주)서건이엔씨
#    - 대표자: 김보경
#
# 🏢 업체명: 주)극동레이저
#    - 대표자: 김보경
#
# 🏢 업체명: 주식회사세은건설
#    - 대표자: 김보경
#
# 🏢 업체명: 다온
#    - 대표자: 김보경
#
# 🏢 업체명: 위드비
#    - 대표자: 김보경
#
# 🏢 업체명: 주식회사 태성전력
#    - 대표자: 김보경
#
# 🏢 업체명: 캣츠앤
#    - 대표자: 김보경
#
# 🏢 업체명: 까사꼬모다
#    - 대표자: 김보경
#
# 🏢 업체명: 현테크
#    - 대표자: 김보경
#
# 🏢 업체명: 블로썸코리아
#    - 대표자: 김보경
#
# 🏢 업체명: 틴지수
#    - 대표자: 김보경
#
# 🏢 업체명: 주식회사 다올건축
#    - 대표자: 김보경
#
# 🏢 업체명: 안다미로
#    - 대표자: 김보경
#
# 🏢 업체명: 라우종합건설(주)
#    - 대표자: 김보경
#
# 🏢 업체명: 파르파르
#    - 대표자: 김보경
#
# 🏢 업체명: 공제이
#    - 대표자: 김보경
#
# 🏢 업체명: 니즈
#    - 대표자: 김보경
#
# 🏢 업체명: 대유디자인 주식회사
#    - 대표자: 김보경
#
# 🏢 업체명: 솔채
#    - 대표자: 김보경
#
# 🏢 업체명: (주)환경안전연구원
#    - 대표자: 김보경
#
# 🏢 업체명: 디자인 보(design bo)
#    - 대표자: 김보경
#
# 🏢 업체명: 주식회사 하진
#    - 대표자: 김보경
#
# 🏢 업체명: 형제모아퍼스
#    - 대표자: 김보곤
#
# 🏢 업체명: 주식회사 동강전력
#    - 대표자: 김보곤
#
# 🏢 업체명: 동강전력
#    - 대표자: 김보곤
#
# 🏢 업체명: 주식회사 인플러에프앤씨
#    - 대표자: 김보곤
#
# 🏢 업체명: 성보이앤씨종합건설 주식회사
#    - 대표자: 김보구
#
# 🏢 업체명: 일신에너지(주)
#    - 대표자: 김보극
#
# 🏢 업체명: 주식회사 도건시스템
#    - 대표자: 김보근
#
# 🏢 업체명: 오얼앤드
#    - 대표자: 김보근
#
# 🏢 업체명: 양평클린
#    - 대표자: 김보나
#
# 🏢 업체명: 우주유통
#    - 대표자: 김보나
#
# 🏢 업체명: 주식회사 스마트항만
#    - 대표자: 김보나
#
# 🏢 업체명: 유한회사 광성건설
#    - 대표자: 김보덕
#
# 🏢 업체명: 주식회사 이레인하우스
#    - 대표자: 김보라
#
# 🏢 업체명: 주식회사 진흥건설
#    - 대표자: 김보라
#
# 🏢 업체명: 주식회사 큐앤비푸드
#    - 대표자: 김보라
#
# 🏢 업체명: 주식회사 라곤이엔씨
#    - 대표자: 김보라
#
# 🏢 업체명: 보라꾹
#    - 대표자: 김보라
#
# 🏢 업체명: 비알컴퍼니
#    - 대표자: 김보라
#
# 🏢 업체명: 퍼플하우스
#    - 대표자: 김보라
#
# 🏢 업체명: 보람
#    - 대표자: 김보람
#
# 🏢 업체명: 바른 한약국
#    - 대표자: 김보람
#
# 🏢 업체명: 풍요자유평온
#    - 대표자: 김보람
#
# 🏢 업체명: 다온라온
#    - 대표자: 김보람
#
# 🏢 업체명: 리얼라이즈
#    - 대표자: 김보람
#
# 🏢 업체명: (주)우수지엔에스
#    - 대표자: 김보람
#
# 🏢 업체명: 블링 너구리
#    - 대표자: 김보람
#
# 🏢 업체명: 보광산업
#    - 대표자: 김보령
#
# 🏢 업체명: 비율
#    - 대표자: 김보리
#
# 🏢 업체명: 디딤컴퍼니
#    - 대표자: 김보리
#
# 🏢 업체명: 라온유통
#    - 대표자: 김보명
#
# 🏢 업체명: 중원산업주식회사
#    - 대표자: 김보미
#
# 🏢 업체명: (주)대성텔레콤
#    - 대표자: 김보미
#
# 🏢 업체명: 주식회사 한백
#    - 대표자: 김보미
#
# 🏢 업체명: 한누리건설 주식회사
#    - 대표자: 김보미
#
# 🏢 업체명: 더블에이치
#    - 대표자: 김보미
#
# 🏢 업체명: 주식회사 일생
#    - 대표자: 김보미
#
# 🏢 업체명: 태건기업
#    - 대표자: 김보미
#
# 🏢 업체명: 새종로약국
#    - 대표자: 김보미
#
# 🏢 업체명: 유한회사 초록환경
#    - 대표자: 김보미
#
# 🏢 업체명: 지성이엔지
#    - 대표자: 김보미
#
# 🏢 업체명: 주식회사 제일하우징
#    - 대표자: 김보미
#
# 🏢 업체명: 건축사사무소 우진
#    - 대표자: 김보미
#
# 🏢 업체명: 주식회사 새건아이엔씨
#    - 대표자: 김보미
#
# 🏢 업체명: 성신진흥산업개발(주)
#    - 대표자: 김보민
#
# 🏢 업체명: (주)한국이건
#    - 대표자: 김보민
#
# 🏢 업체명: 경북상사
#    - 대표자: 김보민
#
# 🏢 업체명: (주)보민
#    - 대표자: 김보민
#
# 🏢 업체명: 주식회사 양치기소년들
#    - 대표자: 김보민
#
# 🏢 업체명: 주식회사 비엠에너텍
#    - 대표자: 김보민
#
# 🏢 업체명: 주식회사 칼라투
#    - 대표자: 김보민
#
# 🏢 업체명: 송산조경
#    - 대표자: 김보민
#
# 🏢 업체명: 새로이
#    - 대표자: 김보민
#
# 🏢 업체명: 비엠퍼시픽
#    - 대표자: 김보민
#
# 🏢 업체명: 해림
#    - 대표자: 김보민
#
# 🏢 업체명: 토리
#    - 대표자: 김보민
#
# 🏢 업체명: 주식회사 헤라
#    - 대표자: 김보민
#
# 🏢 업체명: 한울푸드
#    - 대표자: 김보배
#
# 🏢 업체명: 주식회사 한별엔지니어링
#    - 대표자: 김보상
#
# 🏢 업체명: 주식회사 보우건설
#    - 대표자: 김보석
#
# 🏢 업체명: 보석하우스
#    - 대표자: 김보석
#
# 🏢 업체명: 주식회사 반디에코라인
#    - 대표자: 김보석
#
# 🏢 업체명: 주식회사동천아이엔씨
#    - 대표자: 김보선
#
# 🏢 업체명: 대구산전
#    - 대표자: 김보선
#
# 🏢 업체명: 주식회사 아인기술
#    - 대표자: 김보선
#
# 🏢 업체명: 주식회사 디에코
#    - 대표자: 김보섭
#
# 🏢 업체명: 주식회사 프로프레
#    - 대표자: 김보섭
#
# 🏢 업체명: 진성건설개발 주식회사
#    - 대표자: 김보성
#
# 🏢 업체명: 신진아이앤씨주식회사
#    - 대표자: 김보성
#
# 🏢 업체명: 이지스
#    - 대표자: 김보성
#
# 🏢 업체명: 주식회사 지아이글로벌
#    - 대표자: 김보성
#
# 🏢 업체명: 민코리아
#    - 대표자: 김보성
#
# 🏢 업체명: 포디
#    - 대표자: 김보성
#
# 🏢 업체명: (주)보성전력
#    - 대표자: 김보성
#
# 🏢 업체명: 제네르(genereux)
#    - 대표자: 김보성
#
# 🏢 업체명: 랩뽀송이양
#    - 대표자: 김보성
#
# 🏢 업체명: 주식회사 컴버스테크
#    - 대표자: 김보성
#
# 🏢 업체명: 주식회사 성보건설
#    - 대표자: 김보성
#
# 🏢 업체명: 명성그리드
#    - 대표자: 김보송
#
# 🏢 업체명: 주식회사 마가
#    - 대표자: 김보송
#
# 🏢 업체명: 하이송
#    - 대표자: 김보송
#
# 🏢 업체명: 중우건설주식회사
#    - 대표자: 김보수
#
# 🏢 업체명: 주식회사중외종합건설
#    - 대표자: 김보수
#
# 🏢 업체명: 주식회사 남경에스텍
#    - 대표자: 김보수
#
# 🏢 업체명: 사람과넛지
#    - 대표자: 김보수
#
# 🏢 업체명: 대승건설 주식회사
#    - 대표자: 김보순
#
# 🏢 업체명: 홍문당서적
#    - 대표자: 김보순
#
# 🏢 업체명: (주)라인이엔지
#    - 대표자: 김보순
#
# 🏢 업체명: 주식회사 금화전기
#    - 대표자: 김보슬
#
# 🏢 업체명: 비원
#    - 대표자: 김보식
#
# 🏢 업체명: 주식회사 형제종합안전공사
#    - 대표자: 김보아
#
# 🏢 업체명: 제이비컴퍼니
#    - 대표자: 김보애
#
# 🏢 업체명: 고양시산림조합
#    - 대표자: 김보연
#
# 🏢 업체명: 나무사랑조경주식회사
#    - 대표자: 김보연
#
# 🏢 업체명: (주)한성파워텍
#    - 대표자: 김보연
#
# 🏢 업체명: 자경원
#    - 대표자: 김보연
#
# 🏢 업체명: 주식회사 윈스
#    - 대표자: 김보연
#
# 🏢 업체명: 비오인터내셔널
#    - 대표자: 김보연
#
# 🏢 업체명: (주)대성보안공사
#    - 대표자: 김보영
#
# 🏢 업체명: 경일엔바이로
#    - 대표자: 김보영
#
# 🏢 업체명: 주식회사 윌비시스
#    - 대표자: 김보영
#
# 🏢 업체명: 보은건설 주식회사
#    - 대표자: 김보영
#
# 🏢 업체명: 지앤와이일렉텍(주)
#    - 대표자: 김보영
#
# 🏢 업체명: 바이리테일
#    - 대표자: 김보영
#
# 🏢 업체명: 모나코
#    - 대표자: 김보영
#
# 🏢 업체명: 소원테크
#    - 대표자: 김보영
#
# 🏢 업체명: 늘솔길
#    - 대표자: 김보영
#
# 🏢 업체명: 유성전력
#    - 대표자: 김보영
#
# 🏢 업체명: 주식회사 투지웍스
#    - 대표자: 김보영
#
# 🏢 업체명: 주식회사 대방건업
#    - 대표자: 김보영
#
# 🏢 업체명: 주식회사 주원더베스트
#    - 대표자: 김보영
#
# 🏢 업체명: 주식회사 정우종합건설
#    - 대표자: 김보옥
#
# 🏢 업체명: 보배
#    - 대표자: 김보은
#
# 🏢 업체명: 리원
#    - 대표자: 김보은
#
# 🏢 업체명: 보르사르
#    - 대표자: 김보은
#
# 🏢 업체명: 고래마켓
#    - 대표자: 김보은
#
# 🏢 업체명: 신성조경개발
#    - 대표자: 김보읍
#
# 🏢 업체명: 주식회사 하늘조경
#    - 대표자: 김보읍
#
# 🏢 업체명: 버텍스액세스서비스 유한회사
#    - 대표자: 김보준
#
# 🏢 업체명: 주식회사 드림전력 (Dream Electric Power Co.,Ltd)
#    - 대표자: 김보중
#
# 🏢 업체명: (주)중앙석재조경
#    - 대표자: 김보한
#
# 🏢 업체명: 주식회사 가온종합건설
#    - 대표자: 김보해
#
# 🏢 업체명: 주식회사 에이디앤에이치
#    - 대표자: 김보현
#
# 🏢 업체명: 건축사사무소 명건축
#    - 대표자: 김보현
#
# 🏢 업체명: 주식회사 재승
#    - 대표자: 김보현
#
# 🏢 업체명: 주식회사대영산업
#    - 대표자: 김보현
#
# 🏢 업체명: 대한건설기술단(주)
#    - 대표자: 김보현
#
# 🏢 업체명: 주식회사 부성전기
#    - 대표자: 김보현
#
# 🏢 업체명: 주식회사 세진과전산
#    - 대표자: 김보현
#
# 🏢 업체명: 주식회사 호수조명
#    - 대표자: 김보현
#
# 🏢 업체명: 주식회사 오케이팜
#    - 대표자: 김보현
#
# 🏢 업체명: 주식회사 아이즈온솔루션
#    - 대표자: 김보현
#
# 🏢 업체명: 보강
#    - 대표자: 김보현
#
# 🏢 업체명: 건축사사무소루이
#    - 대표자: 김보현
#
# 🏢 업체명: 주식회사피엔피
#    - 대표자: 김보현
#
# 🏢 업체명: (주)하나엔텍
#    - 대표자: 김보형
#
# 🏢 업체명: 주식회사 세종이엔씨
#    - 대표자: 김보형
#
# 🏢 업체명: 주식회사 국보안전
#    - 대표자: 김보형
#
# 🏢 업체명: 엔젤테크
#    - 대표자: 김보형
#
# 🏢 업체명: 주식회사 주원이앤씨
#    - 대표자: 김보형
#
# 🏢 업체명: (주)흥일토건
#    - 대표자: 김보혜
#
# 🏢 업체명: 대흥컴퍼니
#    - 대표자: 김보혜
#
# 🏢 업체명: 나무씨엔아이 주식회사
#    - 대표자: 김보홍
#
# 🏢 업체명: 일진산업(주)
#    - 대표자: 김보화
#
# 🏢 업체명: (주)유인조경
#    - 대표자: 김보훈
#
# 🏢 업체명: (유)천하환경
#    - 대표자: 김보훈
#
# 🏢 업체명: 주식회사 디스
#    - 대표자: 김보훈
#
# 🏢 업체명: 엘로힘
#    - 대표자: 김보훈
#
# 🏢 업체명: 구룡오앤에스
#    - 대표자: 김보희
#
# 🏢 업체명: 주식회사 레인보우
#    - 대표자: 김보희
#
# 🏢 업체명: 디디팩토리
#    - 대표자: 김보희
#
# 🏢 업체명: 디에스 아이엔디
#    - 대표자: 김복겸
#
# 🏢 업체명: (주) 제니컴
#    - 대표자: 김복경
#
# 🏢 업체명: 동양국악기제작소
#    - 대표자: 김복곤
#
# 🏢 업체명: 주식회사 골드라인
#    - 대표자: 김복구
#
# 🏢 업체명: 주식회사 케이앤
#    - 대표자: 김복구
#
# 🏢 업체명: 중앙통신
#    - 대표자: 김복권
#
# 🏢 업체명: 사단법인 한국인사행정학회
#    - 대표자: 김복규
#
# 🏢 업체명: 이엔지에스텍(주)
#    - 대표자: 김복근
#
# 🏢 업체명: (주)해송
#    - 대표자: 김복기
#
# 🏢 업체명: 세흥주식회사
#    - 대표자: 김복기
#
# 🏢 업체명: 건우종합전기 주식회사
#    - 대표자: 김복기
#
# 🏢 업체명: (유)건용건설
#    - 대표자: 김복남
#
# 🏢 업체명: 주식회사 우형정보통신
#    - 대표자: 김복녀
#
# 🏢 업체명: 강원OA통신
#    - 대표자: 김복녀
#
# 🏢 업체명: 대상전력 주식회사
#    - 대표자: 김복년
#
# 🏢 업체명: 신화 주식회사
#    - 대표자: 김복란
#
# 🏢 업체명: 성진건설 주식회사
#    - 대표자: 김복래
#
# 🏢 업체명: 대복건설(주)
#    - 대표자: 김복렬
#
# 🏢 업체명: 디자인주식회사
#    - 대표자: 김복렬
#
# 🏢 업체명: (주)포이닉스
#    - 대표자: 김복례
#
# 🏢 업체명: 인디언
#    - 대표자: 김복례
#
# 🏢 업체명: 태성논슬립
#    - 대표자: 김복만
#
# 🏢 업체명: 주식회사부일에스티
#    - 대표자: 김복만
#
# 🏢 업체명: 복명광고
#    - 대표자: 김복명
#
# 🏢 업체명: (주)파란종합관리
#    - 대표자: 김복미
#
# 🏢 업체명: 주식회사제이엔에스
#    - 대표자: 김복미
#
# 🏢 업체명: 주식회사 엠제이이엔지
#    - 대표자: 김복배
#
# 🏢 업체명: 주식회사 태일조경건설
#    - 대표자: 김복선
#
# 🏢 업체명: 유진
#    - 대표자: 김복설
#
# 🏢 업체명: 주식회사 도우안전산업
#    - 대표자: 김복성
#
# 🏢 업체명: 주식회사 수창미디어
#    - 대표자: 김복수
#
# 🏢 업체명: 주식회사 태건씨앤씨
#    - 대표자: 김복수
#
# 🏢 업체명: 동인전력공사
#    - 대표자: 김복수
#
# 🏢 업체명: 주식회사 부손종합개발
#    - 대표자: 김복수
#
# 🏢 업체명: 봉림조경
#    - 대표자: 김복수
#
# 🏢 업체명: 주식회사 백령도연합상공인
#    - 대표자: 김복수
#
# 🏢 업체명: 주식회사 진덕
#    - 대표자: 김복수
#
# 🏢 업체명: 주식회사 알파
#    - 대표자: 김복숙
#
# 🏢 업체명: 한빛환경
#    - 대표자: 김복순
#
# 🏢 업체명: 삼합전설(주)
#    - 대표자: 김복순
#
# 🏢 업체명: (합)세일
#    - 대표자: 김복순
#
# 🏢 업체명: 신라건설(주)
#    - 대표자: 김복순
#
# 🏢 업체명: 주식회사 거성
#    - 대표자: 김복순
#
# 🏢 업체명: 주식회사 한명엔지니어링
#    - 대표자: 김복순
#
# 🏢 업체명: 주식회사 부경해양기술
#    - 대표자: 김복순
#
# 🏢 업체명: 케이떠블유에너지
#    - 대표자: 김복순
#
# 🏢 업체명: 주식회사 중부에너지
#    - 대표자: 김복순
#
# 🏢 업체명: 주식회사 네오정보통신
#    - 대표자: 김복순
#
# 🏢 업체명: 주식회사 중앙시스템
#    - 대표자: 김복순
#
# 🏢 업체명: 주식회사 풀잎소리
#    - 대표자: 김복순
#
# 🏢 업체명: 대동종합환경
#    - 대표자: 김복술
#
# 🏢 업체명: 자연건설 주식회사
#    - 대표자: 김복식
#
# 🏢 업체명: (주)신영엔지니어링
#    - 대표자: 김복식
#
# 🏢 업체명: 진영전기
#    - 대표자: 김복식
#
# 🏢 업체명: 미래이엔지 유한회사
#    - 대표자: 김복실
#
# 🏢 업체명: 주식회사 영상
#    - 대표자: 김복실
#
# 🏢 업체명: 주식회사 한남전력
#    - 대표자: 김복심
#
# 🏢 업체명: (주)태범산업
#    - 대표자: 김복연
#
# 🏢 업체명: 주식회사 천우건설
#    - 대표자: 김복연
#
# 🏢 업체명: 주식회사 케이시스템
#    - 대표자: 김복연
#
# 🏢 업체명: 금강환경(주)
#    - 대표자: 김복열
#
# 🏢 업체명: 동아건축사사무소
#    - 대표자: 김복열
#
# 🏢 업체명: 아키반 건축사사무소
#    - 대표자: 김복열
#
# 🏢 업체명: 영동건설(주)
#    - 대표자: 김복영
#
# 🏢 업체명: 대일관광(주)
#    - 대표자: 김복용
#
# 🏢 업체명: (합자)건화기업
#    - 대표자: 김복일
#
# 🏢 업체명: 주식회사 석영
#    - 대표자: 김복임
#
# 🏢 업체명: (주)명성실내디자인건축
#    - 대표자: 김복임
#
# 🏢 업체명: (주)청목건설
#    - 대표자: 김복자
#
# 🏢 업체명: (주)삼주건설
#    - 대표자: 김복자
#
# 🏢 업체명: 재용기업 주식회사
#    - 대표자: 김복자
#
# 🏢 업체명: 삼원파워주식회사
#    - 대표자: 김복자
#
# 🏢 업체명: (주)광성건설
#    - 대표자: 김복자
#
# 🏢 업체명: 농업회사법인 주식회사 동호식품
#    - 대표자: 김복자
#
# 🏢 업체명: 주식회사 샘물조경
#    - 대표자: 김복자
#
# 🏢 업체명: 주식회사 광천
#    - 대표자: 김복자
#
# 🏢 업체명: 주식회사 호은
#    - 대표자: 김복자
#
# 🏢 업체명: 주식회사 어울림조경
#    - 대표자: 김복자
#
# 🏢 업체명: 은광건설 주식회사
#    - 대표자: 김복자
#
# 🏢 업체명: 일복상사
#    - 대표자: 김복자
#
# 🏢 업체명: 주식회사 다솔건설
#    - 대표자: 김복자
#
# 🏢 업체명: 신흥설비(주)
#    - 대표자: 김복제
#
# 🏢 업체명: (주)탑이앤지
#    - 대표자: 김복종
#
# 🏢 업체명: 동창건설 주식회사
#    - 대표자: 김복주
#
# 🏢 업체명: 제이케이토건 주식회사
#    - 대표자: 김복주
#
# 🏢 업체명: 주식회사신명건설
#    - 대표자: 김복준
#
# 🏢 업체명: 주식회사 천운정보통신
#    - 대표자: 김복중
#
# 🏢 업체명: 이온건설(주)
#    - 대표자: 김복진
#
# 🏢 업체명: 주식회사 에스이에스
#    - 대표자: 김복헌
#
# 🏢 업체명: 주식회사 솔라윈드
#    - 대표자: 김복헌
#
# 🏢 업체명: 주식회사영동시스템에어컨
#    - 대표자: 김복화
#
# 🏢 업체명: 가온종합건설 주식회사
#    - 대표자: 김복화
#
# 🏢 업체명: 세종전기공업(주)
#    - 대표자: 김복환
#
# 🏢 업체명: 금풍문화사
#    - 대표자: 김복환
#
# 🏢 업체명: (유)청우조경
#    - 대표자: 김복환
#
# 🏢 업체명: 유한회사 신흥건설산업
#    - 대표자: 김복환
#
# 🏢 업체명: 디앤디산업
#    - 대표자: 김복환
#
# 🏢 업체명: 주식회사 그린이엔지
#    - 대표자: 김복희
#
# 🏢 업체명: 합자회사 낙안이엔씨
#    - 대표자: 김복희
#
# 🏢 업체명: 장수건설
#    - 대표자: 김복희
#
# 🏢 업체명: 국광종합건설주식회사
#    - 대표자: 김복희
#
# 🏢 업체명: 주식회사 태양에너지
#    - 대표자: 김복희
#
# 🏢 업체명: (주)서일알엔씨
#    - 대표자: 김복희
#
# 🏢 업체명: 주식회사 양지건설
#    - 대표자: 김복희
#
# 🏢 업체명: 주식회사 옐로우커머스
#    - 대표자: 김복희
#
# 🏢 업체명: 주식회사 풍진전력
#    - 대표자: 김복희
#
# 🏢 업체명: 주식회사 하린
#    - 대표자: 김복희
#
# 🏢 업체명: 주식회사 지연이앤씨
#    - 대표자: 김복희
#
# 🏢 업체명: 한도 세탁소 ( 란드리 마을 (Landry Villiage))
#    - 대표자: 김복희
#
# 🏢 업체명: (주)중앙기초
#    - 대표자: 김본철
#
# 🏢 업체명: 스노우뮤직
#    - 대표자: 김봄
#
# 🏢 업체명: 주식회사 거성전력
#    - 대표자: 김봄
#
# 🏢 업체명: 금륭투수개발 주식회사
#    - 대표자: 김봉갑
#
# 🏢 업체명: 용사의집
#    - 대표자: 김봉겸
#
# 🏢 업체명: (주)디에스에너지
#    - 대표자: 김봉관
#
# 🏢 업체명: (유)광석건설
#    - 대표자: 김봉구
#
# 🏢 업체명: 한진전기
#    - 대표자: 김봉구
#
# 🏢 업체명: 월드농원
#    - 대표자: 김봉구
#
# 🏢 업체명: 비엠텍시스템 주식회사
#    - 대표자: 김봉구
#
# 🏢 업체명: 류전력
#    - 대표자: 김봉국
#
# 🏢 업체명: 서울서점
#    - 대표자: 김봉권
#
# 🏢 업체명: 주식회사 웰파워
#    - 대표자: 김봉규
#
# 🏢 업체명: 현토건설(주)
#    - 대표자: 김봉규
#
# 🏢 업체명: 주식회사 디엔씨전력
#    - 대표자: 김봉규
#
# 🏢 업체명: 주식회사 에스피건설
#    - 대표자: 김봉규
#
# 🏢 업체명: 의성기업 주식회사
#    - 대표자: 김봉규
#
# 🏢 업체명: 정도전설(주)
#    - 대표자: 김봉균
#
# 🏢 업체명: 동일전기
#    - 대표자: 김봉균
#
# 🏢 업체명: (주)아이지커뮤니케이션즈
#    - 대표자: 김봉균
#
# 🏢 업체명: 주식회사 신성기업
#    - 대표자: 김봉균
#
# 🏢 업체명: 시작한유
#    - 대표자: 김봉균
#
# 🏢 업체명: 주식회사 디엔에이치산업
#    - 대표자: 김봉금
#
# 🏢 업체명: 성진
#    - 대표자: 김봉금
#
# 🏢 업체명: 월드계전
#    - 대표자: 김봉기
#
# 🏢 업체명: 갈렙이엔씨 주식회사
#    - 대표자: 김봉기
#
# 🏢 업체명: 은성문화사
#    - 대표자: 김봉기
#
# 🏢 업체명: 선명전자통신주식회사
#    - 대표자: 김봉기
#
# 🏢 업체명: (주)신창이엔지
#    - 대표자: 김봉기
#
# 🏢 업체명: 금강종합건설 주식회사
#    - 대표자: 김봉기
#
# 🏢 업체명: 금성종합상사
#    - 대표자: 김봉기
#
# 🏢 업체명: 주식회사 대보
#    - 대표자: 김봉기
#
# 🏢 업체명: 소망상사
#    - 대표자: 김봉기
#
# 🏢 업체명: 리플레이스디자인
#    - 대표자: 김봉기
#
# 🏢 업체명: 주식회사 유정이앤티
#    - 대표자: 김봉길
#
# 🏢 업체명: (주)태창마린
#    - 대표자: 김봉길
#
# 🏢 업체명: (주)메타소프트
#    - 대표자: 김봉길
#
# 🏢 업체명: 주식회사 전주전력
#    - 대표자: 김봉길
#
# 🏢 업체명: 주식회사 예원제이앤비
#    - 대표자: 김봉남
#
# 🏢 업체명: (주)상원인퍼스
#    - 대표자: 김봉남
#
# 🏢 업체명: 주식회사대명이엔지
#    - 대표자: 김봉남
#
# 🏢 업체명: 황금건설 주식회사
#    - 대표자: 김봉님
#
# 🏢 업체명: 지평종합건설 주식회사
#    - 대표자: 김봉님
#
# 🏢 업체명: 주식회사 나우  (NAWOO)
#    - 대표자: 김봉덕
#
# 🏢 업체명: 주식회사 디에이치씨앤에스
#    - 대표자: 김봉래
#
# 🏢 업체명: 하얀크린
#    - 대표자: 김봉래
#
# 🏢 업체명: 주식회사 이앤에프
#    - 대표자: 김봉례
#
# 🏢 업체명: 주식회사 가민
#    - 대표자: 김봉만
#
# 🏢 업체명: 주식회사코리아세찬종합건설
#    - 대표자: 김봉모
#
# 🏢 업체명: 봉화 상사
#    - 대표자: 김봉모
#
# 🏢 업체명: 주식회사 온누리이엔지
#    - 대표자: 김봉무
#
# 🏢 업체명: (주)보강건설
#    - 대표자: 김봉문
#
# 🏢 업체명: 공간인력개발
#    - 대표자: 김봉미
#
# 🏢 업체명: 주식회사 공간산업개발
#    - 대표자: 김봉미
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#    - 대표자: 황혜란
#
# 🏢 업체명: 벤처세제연구소(The V.TAX Lab)
#    - 대표자: 황혜린
#
# 🏢 업체명: (주)유니크인디자인
#    - 대표자: 황혜린
#
# 🏢 업체명: 해원컴퍼니
#    - 대표자: 황혜림
#
# 🏢 업체명: 엔에스
#    - 대표자: 황혜림
#
# 🏢 업체명: (주)트루피플
#    - 대표자: 황혜림
#
# 🏢 업체명: 이엠유 주식회사
#    - 대표자: 황혜미
#
# 🏢 업체명: (주)부국종합건설
#    - 대표자: 황혜민
#
# 🏢 업체명: 뷰티풀황
#    - 대표자: 황혜민
#
# 🏢 업체명: 오뉴푸드
#    - 대표자: 황혜민
#
# 🏢 업체명: 주식회사 엔아이
#    - 대표자: 황혜선
#
# 🏢 업체명: 주식회사 주안건설
#    - 대표자: 황혜선
#
# 🏢 업체명: 주식회사 화인기전
#    - 대표자: 황혜성
#
# 🏢 업체명: 세진싸이언스
#    - 대표자: 황혜숙
#
# 🏢 업체명: 두합전기개발(주)
#    - 대표자: 황혜신
#
# 🏢 업체명: (주)한결에이엠
#    - 대표자: 황혜연
#
# 🏢 업체명: 돌섬컴퍼니
#    - 대표자: 황혜영
#
# 🏢 업체명: 주식회사 돌섬
#    - 대표자: 황혜영
#
# 🏢 업체명: 조달마커
#    - 대표자: 황혜영
#
# 🏢 업체명: 주식회사 에이비구조건축사사무소
#    - 대표자: 황혜영
#
# 🏢 업체명: 석진건설주식회사
#    - 대표자: 황혜옥
#
# 🏢 업체명: 유한회사 동인건설
#    - 대표자: 황혜원
#
# 🏢 업체명: 주식회사 태강스테이트
#    - 대표자: 황혜정
#
# 🏢 업체명: 유한회사조은전력
#    - 대표자: 황혜정
#
# 🏢 업체명: 주식회사 제이앤제이인터내셔널
#    - 대표자: 황혜정
#
# 🏢 업체명: 주식회사 에어앤비
#    - 대표자: 황혜정
#
# 🏢 업체명: 대동전기
#    - 대표자: 황혜정
#
# 🏢 업체명: 주식회사 부원건설
#    - 대표자: 황혜진
#
# 🏢 업체명: 주식회사 우인
#    - 대표자: 황혜진
#
# 🏢 업체명: 주식회사 대경전설
#    - 대표자: 황혜진
#
# 🏢 업체명: 서현조경주식회사
#    - 대표자: 황혜진
#
# 🏢 업체명: 마고진
#    - 대표자: 황혜진
#
# 🏢 업체명: 원택건설 주식회사
#    - 대표자: 황호경
#
# 🏢 업체명: 태궁
#    - 대표자: 황호경
#
# 🏢 업체명: 샬롬전기안전(주)
#    - 대표자: 황호문
#
# 🏢 업체명: 예린이엔씨 주식회사
#    - 대표자: 황호분
#
# 🏢 업체명: 춘천사랑종합유통,필립스A/S
#    - 대표자: 황호석
#
# 🏢 업체명: 유한회사 로드팜건설
#    - 대표자: 황호석
#
# 🏢 업체명: 강서관광(주)
#    - 대표자: 황호선
#
# 🏢 업체명: (주)목림정보통신
#    - 대표자: 황호선
#
# 🏢 업체명: 주식회사 그느루
#    - 대표자: 황호성
#
# 🏢 업체명: 예성종합건설 주식회사
#    - 대표자: 황호수
#
# 🏢 업체명: 신화포장건설(주)
#    - 대표자: 황호승
#
# 🏢 업체명: (주)미산아이브
#    - 대표자: 황호연
#
# 🏢 업체명: 지원종합건설(주)
#    - 대표자: 황호영
#
# 🏢 업체명: 톰 패밀리
#    - 대표자: 황호영
#
# 🏢 업체명: (주)비전아이씨티
#    - 대표자: 황호은
#
# 🏢 업체명: (주)신안전력
#    - 대표자: 황호준
#
# 🏢 업체명: 정원팩토리 주식회사
#    - 대표자: 황호준
#
# 🏢 업체명: 시공전설(주)
#    - 대표자: 황호진
#
# 🏢 업체명: 유성씨앤에프(주)양주
#    - 대표자: 황호진
#
# 🏢 업체명: 주식회사 씽크피플
#    - 대표자: 황호진
#
# 🏢 업체명: 주식회사호진엔지니어링
#    - 대표자: 황호진
#
# 🏢 업체명: 주식회사 시공이엔씨
#    - 대표자: 황호진
#
# 🏢 업체명: 주식회사 서조
#    - 대표자: 황호철
#
# 🏢 업체명: 우리ENC
#    - 대표자: 황호태
#
# 🏢 업체명: 주식회사 산야종합건설
#    - 대표자: 황호하
#
# 🏢 업체명: 성우해운 주식회사
#    - 대표자: 황호현
#
# 🏢 업체명: 두원솔루션(주)
#    - 대표자: 황홍균
#
# 🏢 업체명: 대성전기
#    - 대표자: 황홍백
#
# 🏢 업체명: 주식회사 엔젤인
#    - 대표자: 황홍식
#
# 🏢 업체명: (주)한일산업개발
#    - 대표자: 황홍일
#
# 🏢 업체명: 주식회사 에이원건설산전
#    - 대표자: 황홍철
#
# 🏢 업체명: 차이홍배송대행
#    - 대표자: 황홍철
#
# 🏢 업체명: 신유로전력 주식회사
#    - 대표자: 황화익
#
# 🏢 업체명: 범우교구
#    - 대표자: 황화자
#
# 🏢 업체명: 유한회사 화정건설
#    - 대표자: 황화정
#
# 🏢 업체명: 황금산업주식회사
#    - 대표자: 황환명
#
# 🏢 업체명: 주식회사 하나건축사사무소
#    - 대표자: 황환문
#
# 🏢 업체명: 주식회사 이레소방엔지니어링
#    - 대표자: 황환성
#
# 🏢 업체명: (주)한덕산업
#    - 대표자: 황환일
#
# 🏢 업체명: 하나건설 주식회사
#    - 대표자: 황횡규
#
# 🏢 업체명: (유)지리산건설
#    - 대표자: 황효순
#
# 🏢 업체명: 주식회사 신성아이엠에스
#    - 대표자: 황효순
#
# 🏢 업체명: 주식회사 기대이앤씨
#    - 대표자: 황효일
#
# 🏢 업체명: 유한회사 태흥건설
#    - 대표자: 황효자
#
# 🏢 업체명: 레인보우
#    - 대표자: 황효정
#
# 🏢 업체명: 라온제나
#    - 대표자: 황효진
#
# 🏢 업체명: 스탠다드웰딩
#    - 대표자: 황후근
#
# 🏢 업체명: 지이엔지니어링(주)
#    - 대표자: 황후문
#
# 🏢 업체명: (주)엠아이알
#    - 대표자: 황후식
#
# 🏢 업체명: (주)서하
#    - 대표자: 황훈
#
# 🏢 업체명: 밀양시 산림조합
#    - 대표자: 황훈구
#
# 🏢 업체명: 해천이엔씨 주식회사
#    - 대표자: 황훈식
#
# 🏢 업체명: 주식회사 종합건축사사무소 에이세븐
#    - 대표자: 황흥렬
#
# 🏢 업체명: 주식회사 도송에너지
#    - 대표자: 황흥연
#
# 🏢 업체명: 청훈디자인(주)
#    - 대표자: 황흥태
#
# 🏢 업체명: 와이지일렉트릭
#    - 대표자: 황희남
#
# 🏢 업체명: 주식회사첨단공간정보
#    - 대표자: 황희령
#
# 🏢 업체명: (주)에코넥스
#    - 대표자: 황희민
#
# 🏢 업체명: 대환건설 주식회사
#    - 대표자: 황희상
#
# 🏢 업체명: 주식회사 라이드개발
#    - 대표자: 황희석
#
# 🏢 업체명: 주식회사 명성에이앤티(A&T)
#    - 대표자: 황희석
#
# 🏢 업체명: 송연건설(주)
#    - 대표자: 황희성
#
# 🏢 업체명: 드림라인
#    - 대표자: 황희성
#
# 🏢 업체명: 명도건설주식회사
#    - 대표자: 황희수
#
# 🏢 업체명: 이에스창조개발주식회사
#    - 대표자: 황희언
#
# 🏢 업체명: 대산환경(주)
#    - 대표자: 황희웅
#
# 🏢 업체명: 피닉스엔지니어링(주)
#    - 대표자: 황희원
#
# 🏢 업체명: 주식회사 에이치퓨처
#    - 대표자: 황희재
#
# 🏢 업체명: (주)서경건설
#    - 대표자: 황희정
#
# 🏢 업체명: 라라냐옹
#    - 대표자: 황희정
#
# 🏢 업체명: 주식회사 대종
#    - 대표자: 황희정
#
# 🏢 업체명: 주식회사 성공건설
#    - 대표자: 황희준
#
# 🏢 업체명: 주식회사 체인포스
#    - 대표자: 황희준
#
# 🏢 업체명: 나나테크
#    - 대표자: 황희진
#
# 🏢 업체명: 주식회사 신의건축개발
#    - 대표자: 황희진
#
# 🏢 업체명: 주식회사 동래우에스
#    - 대표자: 황희찬
#
# 🏢 업체명: 대백건설주식회사
#    - 대표자: 황희천
#
# 🏢 업체명: 주식회사 부경방재기술
#    - 대표자: 황희철
#
# 🏢 업체명: 케이티알기술  주식회사
#    - 대표자: 황희춘
#
# 🏢 업체명: 다이후쿠코리아 주식회사
#    - 대표자: 히라노 야수시
