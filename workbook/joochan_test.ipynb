# %%
from bs4 import BeautifulSoup
import requests
import numpy as np
import pandas as pd
from urllib.request import urlopen

# %%
def request_openAPI(page='1',
                    perPage='3000'):
# url = 'https://api.odcloud.kr/api/15050920/v1/uddi:36259a51-e4fe-42f7-b613-b47d00f8a4b6_201909091659?page=1&perPage=100&returnType=XML&serviceKey=416a0c4c87da58598c1fde059d56608bca0746c6d66fffb18def03dee40491a6'

    ### 조달 계약정보
    base_url     = 'https://api.odcloud.kr/api/'
    service_name = '15050920/v1/uddi:aae84b1a-927c-44ae-9884-fc95d49ba389'
    # page         = '1'
    # perPage      = '100'
    returnType   = 'XML'
    serviceKey   = '416a0c4c87da58598c1fde059d56608bca0746c6d66fffb18def03dee40491a6'
# https://api.odcloud.kr/api/15050920/v1/uddi:aae84b1a-927c-44ae-9884-fc95d49ba389?page=1&perPage=10&returnType=XML&serviceKey=416a0c4c87da58598c1fde059d56608bca0746c6d66fffb18def03dee40491a6

    url = f'{base_url}{service_name}?page={page}&perPage={perPage}&returnType={returnType}&serviceKey={serviceKey}'    
    print(url)
    
    xml = requests.get(url).text
    soup = BeautifulSoup(xml, 'xml')
    return soup

# %%
soup = request_openAPI(1,3000)
print(soup.prettify()[:10000])
# Out:
# https://api.odcloud.kr/api/15050920/v1/uddi:aae84b1a-927c-44ae-9884-fc95d49ba389?page=1&perPage=3000&returnType=XML&serviceKey=416a0c4c87da58598c1fde059d56608bca0746c6d66fffb18def03dee40491a6
# <?xml version="1.0" encoding="utf-8"?>
# <results>
#  <currentCount>
#   3000
#  </currentCount>
#  <data>
#   <item>
#    <col name="대표업체명">
#     (주)북차카
#    </col>
#    <col name="계약번호">
#     2021SCH0112
#    </col>
#    <col name="계약체결형태명">
#     총액계약
#    </col>
#    <col name="국내업체여부">
#     국내업체
#    </col>
#    <col name="대표업체대표자명">
#     서정환
#    </col>
#    <col name="총계약금액">
#     1.524932e+07
#    </col>
#    <col name="계약기간">
#     2021-09-01~2021-11-30
#    </col>
#    <col name="계약기관명">
#     국방부(부대)
#    </col>
#    <col name="수요기관담당부서명">
#     해군작전사령부
#    </col>
#    <col name="수요기관명">
#     국방부(부대)
#    </col>
#    <col name="예정가격">
#     1.7327952e+07
#    </col>
#    <col name="계약금액">
#     1.524932e+07
#    </col>
#    <col name="계약체결방법명">
#     수의계약
#    </col>
# ...
